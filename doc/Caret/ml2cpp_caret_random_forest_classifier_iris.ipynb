# %%
library(caret, quiet=TRUE);
library(base64enc)
library(httr)
# Out:
# Attaching package: ‘httr’
#
#
# The following object is masked from ‘package:caret’:
#
#     progress

# %% [markdown]
# # Build a Model

# %%
set.seed(1960)

create_model  =  function() {

    # https://cran.r-project.org/web/packages/randomForest/randomForest.pdf
    model  <- train(Species ~ ., data = iris, method = "rf" , ntree=64)
    
    return(model)
}

# %%
# dataset
model = create_model()

# %%
pred <- predict(model, as.matrix(iris[, -5]) , type="prob")
pred_labels <- predict(model, as.matrix(iris[, -5]) , type="raw")
sum(pred_labels != iris$Species)/length(pred_labels)
# Out:
# [1] 0

# %% [markdown]
# # SQL Code Generation

# %%
test_ws_sql_gen = function(mod) {
    WS_URL = "https://sklearn2sql.herokuapp.com/model"
    # WS_URL = "http://localhost:1888/model"
    model_serialized <- serialize(mod, NULL)
    b64_data = base64encode(model_serialized)
    data = list(Name = "caret_rpart_test_model", SerializedModel = b64_data , SQLDialect = "CPP" , Mode=" caret")
    r = POST(WS_URL, body = data, encode = "json")
    # print(r)
    content = content(r)
    # print(content)
    lSQL = content$model$SQLGenrationResult[[1]]$SQL # content["model"]["SQLGenrationResult"][0]["SQL"]
    return(lSQL);
}

# %%
lModelSQL = test_ws_sql_gen(model)
cat(lModelSQL)
# Out:
# namespace  {
#
# 	namespace RF_Tree_0 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 3 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.45) ? ( 1 ) : ( (Feature_2 <= 4.75) ? ( 3 ) : ( (Feature_3 <= 1.7) ? ( (Feature_2 <= 4.95) ? ( 7 ) : ( (Feature_0 <= 6.05) ? ( (Feature_2 <= 5.05) ? ( 11 ) : ( 12 ) ) : ( 10 ) ) ) : ( 6 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_0
#
#
# 	namespace RF_Tree_1 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.6) ? ( 1 ) : ( (Feature_0 <= 5.75) ? ( (Feature_0 <= 5.55) ? ( 5 ) : ( (Feature_3 <= 1.75) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_3 <= 1.7) ? ( (Feature_2 <= 5.25) ? ( 11 ) : ( 12 ) ) : ( 8 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_1
#
#
# 	namespace RF_Tree_2 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.8) ? ( 1 ) : ( (Feature_0 <= 7.05) ? ( (Feature_3 <= 1.65) ? ( (Feature_2 <= 5.25) ? ( 7 ) : ( 8 ) ) : ( (Feature_0 <= 6.6) ? ( 9 ) : ( (Feature_2 <= 5.05) ? ( 11 ) : ( 12 ) ) ) ) : ( 4 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_2
#
#
# 	namespace RF_Tree_3 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 9 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 10 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 16 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.8) ? ( 1 ) : ( (Feature_3 <= 1.65) ? ( (Feature_2 <= 5.0) ? ( 5 ) : ( (Feature_3 <= 1.55) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_0 <= 5.800000000000002) ? ( 11 ) : ( 12 ) ) : ( (Feature_1 <= 3.15) ? ( 13 ) : ( (Feature_2 <= 5.05) ? ( 15 ) : ( 16 ) ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_3
#
#
# 	namespace RF_Tree_4 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 16 ,  {0.0, 1.0, 0.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.45) ? ( 1 ) : ( (Feature_3 <= 1.65) ? ( (Feature_2 <= 4.95) ? ( 5 ) : ( (Feature_1 <= 2.45) ? ( 9 ) : ( (Feature_0 <= 6.6) ? ( 13 ) : ( 14 ) ) ) ) : ( (Feature_3 <= 1.85) ? ( (Feature_2 <= 4.85) ? ( (Feature_1 <= 3.1) ? ( 15 ) : ( 16 ) ) : ( 12 ) ) : ( 8 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_4
#
#
# 	namespace RF_Tree_5 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 3 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.45) ? ( 1 ) : ( (Feature_2 <= 4.85) ? ( 3 ) : ( (Feature_3 <= 1.7) ? ( (Feature_0 <= 6.05) ? ( 7 ) : ( 8 ) ) : ( 6 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_5
#
#
# 	namespace RF_Tree_6 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.75) ? ( 1 ) : ( (Feature_3 <= 1.65) ? ( (Feature_0 <= 7.1) ? ( (Feature_2 <= 4.95) ? ( 7 ) : ( 8 ) ) : ( 6 ) ) : ( 4 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_6
#
#
# 	namespace RF_Tree_7 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 14 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 15 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 16 ,  {0.0, 1.0, 0.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.8) ? ( 1 ) : ( (Feature_2 <= 4.75) ? ( (Feature_0 <= 4.95) ? ( (Feature_2 <= 3.9) ? ( 9 ) : ( 10 ) ) : ( 6 ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 5.35) ? ( (Feature_3 <= 1.55) ? ( (Feature_0 <= 6.55) ? ( 15 ) : ( 16 ) ) : ( 14 ) ) : ( 12 ) ) : ( 8 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_7
#
#
# 	namespace RF_Tree_8 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 15 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 16 ,  {0.0, 1.0, 0.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.7) ? ( 1 ) : ( (Feature_2 <= 4.75) ? ( (Feature_1 <= 2.55) ? ( (Feature_3 <= 1.6) ? ( 9 ) : ( 10 ) ) : ( 6 ) ) : ( (Feature_3 <= 1.7) ? ( (Feature_0 <= 7.050000000000002) ? ( (Feature_2 <= 4.95) ? ( 13 ) : ( (Feature_3 <= 1.55) ? ( 15 ) : ( 16 ) ) ) : ( 12 ) ) : ( 8 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_8
#
#
# 	namespace RF_Tree_9 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 3 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 16 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 1.75) ? ( (Feature_3 <= 0.8) ? ( 3 ) : ( (Feature_0 <= 7.0) ? ( (Feature_0 <= 4.95) ? ( (Feature_3 <= 1.35) ? ( 15 ) : ( 16 ) ) : ( 12 ) ) : ( 8 ) ) ) : ( (Feature_3 <= 1.85) ? ( (Feature_1 <= 3.1) ? ( 9 ) : ( (Feature_2 <= 5.4) ? ( 13 ) : ( 14 ) ) ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_9
#
#
# 	namespace RF_Tree_10 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 13 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 16 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 17 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 19 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 20 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 21 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 22 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.45) ? ( 1 ) : ( (Feature_3 <= 1.55) ? ( (Feature_3 <= 1.35) ? ( 5 ) : ( (Feature_1 <= 2.65) ? ( (Feature_2 <= 5.05) ? ( 15 ) : ( 16 ) ) : ( 10 ) ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 4.75) ? ( 11 ) : ( (Feature_1 <= 2.85) ? ( 17 ) : ( (Feature_0 <= 6.95) ? ( 21 ) : ( 22 ) ) ) ) : ( (Feature_1 <= 3.15) ? ( 13 ) : ( (Feature_2 <= 5.1) ? ( 19 ) : ( 20 ) ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_10
#
#
# 	namespace RF_Tree_11 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 16 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.35) ? ( 1 ) : ( (Feature_3 <= 1.65) ? ( (Feature_0 <= 7.1) ? ( (Feature_3 <= 1.35) ? ( 9 ) : ( (Feature_2 <= 4.95) ? ( 13 ) : ( 14 ) ) ) : ( 6 ) ) : ( (Feature_2 <= 4.85) ? ( (Feature_3 <= 1.75) ? ( 11 ) : ( (Feature_0 <= 6.050000000000002) ? ( 15 ) : ( 16 ) ) ) : ( 8 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_11
#
#
# 	namespace RF_Tree_12 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 16 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.8) ? ( 1 ) : ( (Feature_3 <= 1.75) ? ( (Feature_1 <= 2.25) ? ( (Feature_2 <= 4.25) ? ( 9 ) : ( 10 ) ) : ( (Feature_2 <= 5.05) ? ( 11 ) : ( (Feature_0 <= 6.15) ? ( 15 ) : ( 16 ) ) ) ) : ( (Feature_2 <= 4.85) ? ( (Feature_0 <= 5.95) ? ( 13 ) : ( 14 ) ) : ( 8 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_12
#
#
# 	namespace RF_Tree_13 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 14 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 15 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 16 ,  {0.0, 1.0, 0.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.45) ? ( 1 ) : ( (Feature_2 <= 4.95) ? ( (Feature_0 <= 5.95) ? ( 5 ) : ( (Feature_3 <= 1.7) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_0 <= 6.95) ? ( (Feature_0 <= 6.5) ? ( (Feature_3 <= 1.55) ? ( 15 ) : ( 16 ) ) : ( 14 ) ) : ( 12 ) ) : ( 8 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_13
#
#
# 	namespace RF_Tree_14 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.8) ? ( 1 ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 5.05) ? ( (Feature_2 <= 4.85) ? ( 7 ) : ( (Feature_1 <= 2.6) ? ( 11 ) : ( 12 ) ) ) : ( (Feature_0 <= 6.05) ? ( 9 ) : ( 10 ) ) ) : ( 4 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_14
#
#
# 	namespace RF_Tree_15 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 10 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.45) ? ( 1 ) : ( (Feature_3 <= 1.65) ? ( (Feature_0 <= 6.05) ? ( 5 ) : ( (Feature_1 <= 2.85) ? ( (Feature_2 <= 4.949999999999998) ? ( 13 ) : ( 14 ) ) : ( 10 ) ) ) : ( (Feature_1 <= 3.15) ? ( 7 ) : ( (Feature_2 <= 5.05) ? ( 11 ) : ( 12 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_15
#
#
# 	namespace RF_Tree_16 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 3 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 16 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 18 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 19 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 21 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 22 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_0 <= 5.75) ? ( (Feature_3 <= 0.75) ? ( 3 ) : ( (Feature_0 <= 4.95) ? ( (Feature_2 <= 3.9) ? ( 11 ) : ( 12 ) ) : ( (Feature_3 <= 1.75) ? ( 13 ) : ( 14 ) ) ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 5.3) ? ( (Feature_0 <= 6.05) ? ( (Feature_3 <= 1.55) ? ( (Feature_3 <= 1.25) ? ( 19 ) : ( (Feature_2 <= 4.75) ? ( 21 ) : ( 22 ) ) ) : ( 18 ) ) : ( 16 ) ) : ( 10 ) ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_16
#
#
# 	namespace RF_Tree_17 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 16 ,  {0.0, 1.0, 0.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.45) ? ( 1 ) : ( (Feature_3 <= 1.55) ? ( (Feature_1 <= 2.25) ? ( (Feature_2 <= 4.75) ? ( 9 ) : ( 10 ) ) : ( (Feature_0 <= 6.05) ? ( 11 ) : ( (Feature_1 <= 2.7) ? ( 15 ) : ( 16 ) ) ) ) : ( (Feature_3 <= 1.65) ? ( (Feature_0 <= 6.6) ? ( 13 ) : ( 14 ) ) : ( 8 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_17
#
#
# 	namespace RF_Tree_18 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 3 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 9 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 13 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 14 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 15 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 17 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 18 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 19 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 20 ,  {0.0, 1.0, 0.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_0 <= 5.45) ? ( (Feature_3 <= 0.8) ? ( 3 ) : ( (Feature_2 <= 4.2) ? ( 7 ) : ( (Feature_1 <= 2.75) ? ( 13 ) : ( 14 ) ) ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 2.6) ? ( 9 ) : ( (Feature_2 <= 4.95) ? ( 15 ) : ( (Feature_3 <= 1.55) ? ( 19 ) : ( 20 ) ) ) ) : ( (Feature_0 <= 5.95) ? ( (Feature_1 <= 3.1) ? ( 17 ) : ( 18 ) ) : ( 12 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_18
#
#
# 	namespace RF_Tree_19 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 3 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 4.85) ? ( (Feature_2 <= 2.6) ? ( 3 ) : ( 4 ) ) : ( (Feature_3 <= 1.7) ? ( (Feature_2 <= 5.0) ? ( 7 ) : ( (Feature_0 <= 6.05) ? ( 9 ) : ( 10 ) ) ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# ...
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_60
#
#
# 	namespace RF_Tree_61 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 10 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.6) ? ( 1 ) : ( (Feature_3 <= 1.65) ? ( (Feature_2 <= 4.95) ? ( 5 ) : ( (Feature_3 <= 1.55) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 4.75) ? ( 11 ) : ( 12 ) ) : ( 8 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_61
#
#
# 	namespace RF_Tree_62 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 3 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 7 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 9 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_0 <= 5.55) ? ( (Feature_2 <= 2.45) ? ( 3 ) : ( 4 ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 2.5) ? ( 7 ) : ( (Feature_2 <= 5.05) ? ( 11 ) : ( 12 ) ) ) : ( (Feature_2 <= 4.85) ? ( 9 ) : ( 10 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_62
#
#
# 	namespace RF_Tree_63 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 3 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 13 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 14 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 15 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 17 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 19 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 20 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_0 <= 5.75) ? ( (Feature_2 <= 2.6) ? ( 3 ) : ( (Feature_0 <= 5.65) ? ( 7 ) : ( (Feature_1 <= 2.65) ? ( 13 ) : ( 14 ) ) ) ) : ( (Feature_2 <= 4.75) ? ( (Feature_1 <= 3.7) ? ( 9 ) : ( 10 ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_1 <= 2.75) ? ( 15 ) : ( (Feature_0 <= 6.5) ? ( 17 ) : ( (Feature_0 <= 7.0) ? ( 19 ) : ( 20 ) ) ) ) : ( 12 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_63
#
#
# 	std::vector<std::string> get_input_names(){
# 		std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 		return lFeatures;
# 	}
#
# 	std::vector<std::string> get_classes(){
# 		std::vector<std::string> lClasses = { "setosa", "versicolor", "virginica" };
#
# 		return lClasses;
# 	}
#
# 	std::vector<std::string> get_output_names(){
# 		std::vector<std::string> lOutputs = {
# 			"Score_setosa", "Score_versicolor", "Score_virginica",
# 			"Proba_setosa", "Proba_versicolor", "Proba_virginica",
# 			"LogProba_setosa", "LogProba_versicolor", "LogProba_virginica",
# 			"Decision", "DecisionProba" };
#
# 		return lOutputs;
# 	}
#
# 	tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 		auto lClasses = get_classes();
#
# 		std::vector<tTable> lTreeScores = {
# 			RF_Tree_0::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_1::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_2::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_3::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_4::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_5::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_6::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_7::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_8::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_9::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_10::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_11::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_12::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_13::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_14::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_15::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_16::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_17::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_18::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_19::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_20::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_21::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_22::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_23::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_24::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_25::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_26::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_27::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_28::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_29::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_30::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_31::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_32::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_33::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_34::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_35::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_36::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_37::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_38::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_39::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_40::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_41::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_42::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_43::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_44::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_45::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_46::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_47::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_48::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_49::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_50::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_51::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_52::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_53::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_54::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_55::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_56::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_57::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_58::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_59::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_60::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_61::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_62::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_63::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3)
# 		};
#
# 		tTable lAggregatedTable = aggregate_rf_scores(lTreeScores, {"Proba", "Score"});
#
#
# 		tTable lTable = lAggregatedTable;
#
# 		int lBestClass = get_arg_max( lTable["Proba"] );
# 		auto lDecision = lClasses[lBestClass];
# 		lTable["Decision"] = { lDecision } ;
# 		lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 		recompute_log_probas( lTable );
#
# 		return lTable;
# 	}
#
# 	tTable compute_model_outputs_from_table( tTable const & iTable) {
# 		tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 		return lTable;
# 	}
#
# } // eof namespace

# %% [markdown]
# # Execute the CPP Code

# %%
    write_text_to_file = function(iCPPCode, oCPPFile) {
        fileConn<-file(oCPPFile)
        writeLines(c(iCPPCode), fileConn)
        close(fileConn)
    }

    add_cpp_main_function = function(iCPPCode, iCSVFile) {
        lCPPCode = "#include \"Generic.i\"\n\n"
        lCPPCode = paste(lCPPCode,  iCPPCode, sep="")
        lCPPCode = paste(lCPPCode, "\n\nint main() {\n", sep="")
        lCPPCode = paste(lCPPCode, "\tscore_csv_file(\"",  iCSVFile, "\");\n", sep="")
        lCPPCode = paste(lCPPCode, "\treturn 0;\n}\n", sep="")
        return(lCPPCode)
    }

    compile_cpp_code_as_executable = function(iName) {
        lCommand = paste("-Wall -Wno-unused-function -std=c++17 -g -o ", iName,  ".exe ",  iName,  ".cpp", sep="")
        cat(paste("EXECUTING " , "'",  lCommand,  "'", sep=""))
        result = system2("g++", args = lCommand)
        # print(result)
    }

    execute_cpp_model = function(iName, iCSVFile) {
        lOutName = paste(iName, ".out", sep="")
        result2 = system2(paste(iName, ".exe", sep="") ,  args = iCSVFile, stdout=lOutName)
        # cat(result2)
        return(result2)
    }
        
    execute_cpp_code = function(iCPPCode, iCSVFile) {
        lTimeStr = format(Sys.time(), "%Y-%m-%d_%H_%M_%S")
        lName = paste("/tmp/ml2cpp_r_", "sample_" , lTimeStr, sep="");
        lCPPCode = add_cpp_main_function(iCPPCode, iCSVFile)
        write_text_to_file(lCPPCode, paste(lName, ".cpp", sep=""))
        compile_cpp_code_as_executable(lName)
        result = execute_cpp_model(lName, iCSVFile)
        lOutName = paste(lName, ".out", sep="")
        return(lOutName)
    }

# %%
dataset = iris[,-5]

df_cpp_in = as.data.frame(dataset)
# cat(names(df_cpp_in))

names(df_cpp_in) = sprintf("Feature_%d",0:(ncol(df_cpp_in)-1))

write.csv(df_cpp_in, "/tmp/iris2.csv", row.names = FALSE, quote = FALSE)

lOutName = execute_cpp_code(lModelSQL, "/tmp/iris2.csv")
lOutName
# Out:
# EXECUTING '-Wall -Wno-unused-function -std=c++17 -g -o /tmp/ml2cpp_r_sample_2020-09-29_18_18_36.exe /tmp/ml2cpp_r_sample_2020-09-29_18_18_36.cpp'
# [1] "/tmp/ml2cpp_r_sample_2020-09-29_18_18_36.out"

# %%
df_cpp_out <- read.csv(file = lOutName)
df_cpp_out$KEY = seq.int(nrow(df_cpp_out))
head(df_cpp_out)
# Out:
#   idx Score_setosa Score_versicolor Score_virginica Proba_setosa
# 1 0   NA           NA               NA              1
# 2 1   NA           NA               NA              1
# 3 2   NA           NA               NA              1
# 4 3   NA           NA               NA              1
# 5 4   NA           NA               NA              1
# 6 5   NA           NA               NA              1
#   Proba_versicolor Proba_virginica LogProba_setosa LogProba_versicolor
# 1 0                0               0               -Inf
# 2 0                0               0               -Inf
# 3 0                0               0               -Inf
# 4 0                0               0               -Inf
# 5 0                0               0               -Inf
# 6 0                0               0               -Inf
#   LogProba_virginica Decision DecisionProba KEY
# 1 -Inf               setosa   1             1
# 2 -Inf               setosa   1             2
# 3 -Inf               setosa   1             3
# 4 -Inf               setosa   1             4
# 5 -Inf               setosa   1             5
# 6 -Inf               setosa   1             6

# %% [markdown]
# # R Caret RandomForest Output

# %%
pred_proba  =  predict(model, as.matrix(iris[,-5]), type = "prob")
df_r_out = data.frame(pred_proba)
names(df_r_out) = sprintf("Proba_%s",model$levels)

df_r_out$KEY = seq.int(nrow(df_r_out))
df_r_out$Score_setosa  =  NA
df_r_out$Score_versicolor  =  NA
df_r_out$Score_virginica  =  NA
df_r_out$LogProba_setosa  =  log(df_r_out$Proba_setosa)
df_r_out$LogProba_versicolor =  log(df_r_out$Proba_versicolor)
df_r_out$LogProba_virginica  =  log(df_r_out$Proba_virginica)
df_r_out$Decision =   predict(model, as.matrix(iris[,-5]), type = "raw")
df_r_out$DecisionProba =  apply(pred_proba, 1, function(x) max(x))
head(df_r_out)
# Out:
#   Proba_setosa Proba_versicolor Proba_virginica KEY Score_setosa
# 1 1            0                0               1   NA
# 2 1            0                0               2   NA
# 3 1            0                0               3   NA
# 4 1            0                0               4   NA
# 5 1            0                0               5   NA
# 6 1            0                0               6   NA
#   Score_versicolor Score_virginica LogProba_setosa LogProba_versicolor
# 1 NA               NA              0               -Inf
# 2 NA               NA              0               -Inf
# 3 NA               NA              0               -Inf
# 4 NA               NA              0               -Inf
# 5 NA               NA              0               -Inf
# 6 NA               NA              0               -Inf
#   LogProba_virginica Decision DecisionProba
# 1 -Inf               setosa   1
# 2 -Inf               setosa   1
# 3 -Inf               setosa   1
# 4 -Inf               setosa   1
# 5 -Inf               setosa   1
# 6 -Inf               setosa   1

# %% [markdown]
# # Compare R and SQL output

# %%
df_merge = merge(x = df_r_out, y = df_cpp_out, by = "KEY", all = TRUE, , suffixes = c("_1","_2"))
head(df_merge)
# Out:
#   KEY Proba_setosa_1 Proba_versicolor_1 Proba_virginica_1 Score_setosa_1
# 1 1   1              0                  0                 NA
# 2 2   1              0                  0                 NA
# 3 3   1              0                  0                 NA
# 4 4   1              0                  0                 NA
# 5 5   1              0                  0                 NA
# 6 6   1              0                  0                 NA
#   Score_versicolor_1 Score_virginica_1 LogProba_setosa_1 LogProba_versicolor_1
# 1 NA                 NA                0                 -Inf
# 2 NA                 NA                0                 -Inf
# 3 NA                 NA                0                 -Inf
# 4 NA                 NA                0                 -Inf
# 5 NA                 NA                0                 -Inf
# 6 NA                 NA                0                 -Inf
#   LogProba_virginica_1 ⋯ Score_versicolor_2 Score_virginica_2 Proba_setosa_2
# 1 -Inf                 ⋯ NA                 NA                1
# 2 -Inf                 ⋯ NA                 NA                1
# 3 -Inf                 ⋯ NA                 NA                1
# 4 -Inf                 ⋯ NA                 NA                1
# 5 -Inf                 ⋯ NA                 NA                1
# 6 -Inf                 ⋯ NA                 NA                1
#   Proba_versicolor_2 Proba_virginica_2 LogProba_setosa_2 LogProba_versicolor_2
# 1 0                  0                 0                 -Inf
# 2 0                  0                 0                 -Inf
# 3 0                  0                 0                 -Inf
# 4 0                  0                 0                 -Inf
# 5 0                  0                 0                 -Inf
# 6 0                  0                 0                 -Inf
#   LogProba_virginica_2 Decision_2 DecisionProba_2
# 1 -Inf                 setosa     1
# 2 -Inf                 setosa     1
# 3 -Inf                 setosa     1
# 4 -Inf                 setosa     1
# 5 -Inf                 setosa     1
# 6 -Inf                 setosa     1

# %%
diffs_df = df_merge[df_merge$Decision_1 != df_merge$Decision_2,]
head(diffs_df)
# Out:
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
#      KEY Proba_setosa_1 Proba_versicolor_1 Proba_virginica_1 Score_setosa_1
#      Score_versicolor_1 Score_virginica_1 LogProba_setosa_1
#      LogProba_versicolor_1 LogProba_virginica_1 ⋯ Score_versicolor_2
#      Score_virginica_2 Proba_setosa_2 Proba_versicolor_2 Proba_virginica_2
#      LogProba_setosa_2 LogProba_versicolor_2 LogProba_virginica_2 Decision_2
#      DecisionProba_2

# %%
stopifnot(nrow(diffs_df) == 0)

# %%
summary(df_cpp_out)
# Out:
#       idx         Score_setosa   Score_versicolor Score_virginica
#  Min.   :  0.00   Mode:logical   Mode:logical     Mode:logical
#  1st Qu.: 37.25   NA's:150       NA's:150         NA's:150
#  Median : 74.50
#  Mean   : 74.50
#  3rd Qu.:111.75
#  Max.   :149.00
#   Proba_setosa    Proba_versicolor Proba_virginica  LogProba_setosa
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :-Inf
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:-Inf
#  Median :0.0000   Median :0.0000   Median :0.0000   Median :-Inf
#  Mean   :0.3332   Mean   :0.3353   Mean   :0.3315   Mean   :-Inf
#  3rd Qu.:1.0000   3rd Qu.:0.9805   3rd Qu.:0.9844   3rd Qu.:   0
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :   0
#  LogProba_versicolor LogProba_virginica   Decision         DecisionProba
#  Min.   :    -Inf    Min.   :    -Inf   Length:150         Min.   :0.5938
#  1st Qu.:    -Inf    1st Qu.:    -Inf   Class :character   1st Qu.:1.0000
#  Median :    -Inf    Median :    -Inf   Mode  :character   Median :1.0000
#  Mean   :    -Inf    Mean   :    -Inf                      Mean   :0.9768
#  3rd Qu.:-0.01975    3rd Qu.:-0.01575                      3rd Qu.:1.0000
#  Max.   : 0.00000    Max.   : 0.00000                      Max.   :1.0000
#       KEY
#  Min.   :  1.00
#  1st Qu.: 38.25
#  Median : 75.50
#  Mean   : 75.50
#  3rd Qu.:112.75
#  Max.   :150.00

# %%
summary(df_r_out)
# Out:
#   Proba_setosa    Proba_versicolor Proba_virginica       KEY
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :  1.00
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.: 38.25
#  Median :0.0000   Median :0.0000   Median :0.0000   Median : 75.50
#  Mean   :0.3332   Mean   :0.3353   Mean   :0.3315   Mean   : 75.50
#  3rd Qu.:1.0000   3rd Qu.:0.9805   3rd Qu.:0.9844   3rd Qu.:112.75
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :150.00
#  Score_setosa   Score_versicolor Score_virginica LogProba_setosa
#  Mode:logical   Mode:logical     Mode:logical    Min.   :-Inf
#  NA's:150       NA's:150         NA's:150        1st Qu.:-Inf
#                                                  Median :-Inf
#                                                  Mean   :-Inf
#                                                  3rd Qu.:   0
#                                                  Max.   :   0
#  LogProba_versicolor LogProba_virginica       Decision  DecisionProba
#  Min.   :    -Inf    Min.   :    -Inf   setosa    :50   Min.   :0.5938
#  1st Qu.:    -Inf    1st Qu.:    -Inf   versicolor:50   1st Qu.:1.0000
#  Median :    -Inf    Median :    -Inf   virginica :50   Median :1.0000
#  Mean   :    -Inf    Mean   :    -Inf                   Mean   :0.9768
#  3rd Qu.:-0.01975    3rd Qu.:-0.01575                   3rd Qu.:1.0000
#  Max.   : 0.00000    Max.   : 0.00000                   Max.   :1.0000
