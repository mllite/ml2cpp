# %%
library(caret, quiet = TRUE)
library(base64enc)
library(httr, quiet = TRUE)

library(mlbench)
# Out:
# Attaching package: ‘httr’
#
#
# The following object is masked from ‘package:caret’:
#
#     progress

# %% [markdown]
# # Build a Model

# %%
options(digits = 15)

## multiclass classification in iris dataset:

data(BostonHousing)
BostonHousing$chas = as.numeric(BostonHousing$chas)

set.seed(1960)

dataset = BostonHousing[, -14] 

create_model  =  function() {

    model <- train(medv ~ ., data = BostonHousing, method = "rf", maxnodes=6, ntree=64)    

    return(model)
}

# %%
model = create_model()
# cat(model$feature_names)
# print(model)

# %%
pred_labels <- predict(model, BostonHousing[, -14] , type="raw")
df = data.frame(BostonHousing[,14])
names(df) = c("medv")
df$Estimator = pred_labels
df$Error = df$Estimator - df$medv
MAPE = mean(abs(df$Error / df$medv))
summary(df)
MAPE
# Out:
#       medv                 Estimator                 Error
#  Min.   : 5.0000000000   Min.   :13.0500498569   Min.   :-21.78936421840000
#  1st Qu.:17.0250000000   1st Qu.:17.6834445932   1st Qu.: -2.00326562836000
#  Median :21.2000000000   Median :21.1847038432   Median :  0.36179596996200
#  Mean   :22.5328063241   Mean   :22.5269983586   Mean   : -0.00580796550462
#  3rd Qu.:25.0000000000   3rd Qu.:24.3222606421   3rd Qu.:  2.25276588731000
#  Max.   :50.0000000000   Max.   :44.6482565751   Max.   : 12.61393227700000
# [1] 0.147494625824529

# %% [markdown]
# # SQL Code Generation

# %%
test_ws_sql_gen = function(mod) {
    WS_URL = "https://sklearn2sql.herokuapp.com/model"
    # WS_URL = "http://localhost:1888/model"
    model_serialized <- serialize(mod, NULL)
    b64_data = base64encode(model_serialized)
    data = list(Name = "xgboost_test_model", SerializedModel = b64_data , SQLDialect = "CPP" , Mode="caret")
    r = POST(WS_URL, body = data, encode = "json")
    # print(r)
    content = content(r)
    # print(content)
    lSQL = content$model$SQLGenrationResult[[1]]$SQL # content["model"]["SQLGenrationResult"][0]["SQL"]
    return(lSQL);
}

# %%
lModelSQL = test_ws_sql_gen(model)
cat(lModelSQL)
# Out:
# namespace  {
#
# 	namespace EXT_SubModel_0 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {31.03333333333333 }} ,
# 				{ 6 ,  {46.00689655172414 }} ,
# 				{ 7 ,  {50.0 }} ,
# 				{ 8 ,  {22.60267857142857 }} ,
# 				{ 9 ,  {21.56086956521739 }} ,
# 				{ 10 ,  {14.327096774193544 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.754) ? ( (Feature_12 <= 14.395) ? ( (Feature_12 <= 4.025) ? ( 7 ) : ( 8 ) ) : ( (Feature_4 <= 0.531) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_5 <= 7.445) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_0
#
#
# 	namespace EXT_SubModel_1 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {21.773205741626796 }} ,
# 				{ 6 ,  {14.276315789473689 }} ,
# 				{ 7 ,  {32.04871794871795 }} ,
# 				{ 8 ,  {26.475 }} ,
# 				{ 9 ,  {47.008 }} ,
# 				{ 10 ,  {21.9 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_12 <= 7.65) ? ( (Feature_5 <= 7.4369999999999985) ? ( (Feature_12 <= 4.83) ? ( 7 ) : ( 8 ) ) : ( (Feature_4 <= 0.6825) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_12 <= 15.0) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_1
#
#
# 	namespace EXT_SubModel_2 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {21.622274881516585 }} ,
# 				{ 6 ,  {14.634337349397592 }} ,
# 				{ 7 ,  {50.0 }} ,
# 				{ 8 ,  {27.643137254901962 }} ,
# 				{ 9 ,  {41.66 }} ,
# 				{ 10 ,  {48.11578947368422 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_12 <= 7.58) ? ( (Feature_5 <= 7.445) ? ( (Feature_7 <= 1.557) ? ( 7 ) : ( 8 ) ) : ( (Feature_5 <= 7.7835) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_12 <= 15.0) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_2
#
#
# 	namespace EXT_SubModel_3 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {30.151764705882353 }} ,
# 				{ 6 ,  {45.66 }} ,
# 				{ 7 ,  {18.936170212765962 }} ,
# 				{ 8 ,  {12.037333333333333 }} ,
# 				{ 9 ,  {24.659375 }} ,
# 				{ 10 ,  {20.219512195121954 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.676) ? ( (Feature_7 <= 2.2057) ? ( (Feature_12 <= 17.62) ? ( 7 ) : ( 8 ) ) : ( (Feature_12 <= 7.78) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_5 <= 7.4235) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_3
#
#
# 	namespace EXT_SubModel_4 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {33.35 }} ,
# 				{ 6 ,  {45.45757575757576 }} ,
# 				{ 7 ,  {26.053521126760568 }} ,
# 				{ 8 ,  {20.663934426229503 }} ,
# 				{ 9 ,  {18.837735849056607 }} ,
# 				{ 10 ,  {13.411111111111104 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.941) ? ( (Feature_12 <= 14.395) ? ( (Feature_12 <= 9.715000000000002) ? ( 7 ) : ( 8 ) ) : ( (Feature_4 <= 0.5825) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_5 <= 7.435) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_4
#
#
# 	namespace EXT_SubModel_5 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {19.49863636363636 }} ,
# 				{ 6 ,  {11.442045454545456 }} ,
# 				{ 7 ,  {50.0 }} ,
# 				{ 8 ,  {25.50890410958904 }} ,
# 				{ 9 ,  {45.52083333333333 }} ,
# 				{ 10 ,  {35.97391304347826 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_12 <= 9.63) ? ( (Feature_5 <= 7.1275) ? ( (Feature_7 <= 1.557) ? ( 7 ) : ( 8 ) ) : ( (Feature_12 <= 4.175) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_12 <= 19.645) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_5
#
#
# 	namespace EXT_SubModel_6 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {32.55098039215685 }} ,
# 				{ 6 ,  {45.3909090909091 }} ,
# 				{ 7 ,  {22.7504 }} ,
# 				{ 8 ,  {17.821590909090904 }} ,
# 				{ 9 ,  {13.604545454545455 }} ,
# 				{ 10 ,  {8.7 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.941) ? ( (Feature_0 <= 8.37969) ? ( (Feature_6 <= 89.9) ? ( 7 ) : ( 8 ) ) : ( (Feature_0 <= 15.57415) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_5 <= 7.4369999999999985) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_6
#
#
# 	namespace EXT_SubModel_7 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {31.8025974025974 }} ,
# 				{ 6 ,  {44.141025641025635 }} ,
# 				{ 7 ,  {50.0 }} ,
# 				{ 8 ,  {22.323636363636364 }} ,
# 				{ 9 ,  {19.26851851851852 }} ,
# 				{ 10 ,  {13.126315789473686 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.797) ? ( (Feature_12 <= 14.28) ? ( (Feature_12 <= 3.51) ? ( 7 ) : ( 8 ) ) : ( (Feature_4 <= 0.5834999999999999) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_5 <= 7.4369999999999985) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_7
#
#
# 	namespace EXT_SubModel_8 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {39.242168674698796 }} ,
# 				{ 6 ,  {22.1625 }} ,
# 				{ 7 ,  {50.0 }} ,
# 				{ 8 ,  {22.910091743119267 }} ,
# 				{ 9 ,  {17.346017699115045 }} ,
# 				{ 10 ,  {12.342682926829266 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.92) ? ( (Feature_12 <= 14.399999999999999) ? ( (Feature_7 <= 1.38485) ? ( 7 ) : ( 8 ) ) : ( (Feature_4 <= 0.6615) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_10 <= 19.7) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_8
#
#
# 	namespace EXT_SubModel_9 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {23.19659090909091 }} ,
# 				{ 6 ,  {14.566225165562914 }} ,
# 				{ 7 ,  {33.480000000000004 }} ,
# 				{ 8 ,  {47.452941176470574 }} ,
# 				{ 9 ,  {35.244 }} ,
# 				{ 10 ,  {26.263636363636365 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_2 <= 4.01) ? ( (Feature_12 <= 4.505) ? ( (Feature_5 <= 7.239) ? ( 7 ) : ( 8 ) ) : ( (Feature_9 <= 267.0) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_12 <= 15.0) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_9
#
#
# 	namespace EXT_SubModel_10 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {23.719377162629762 }} ,
# 				{ 6 ,  {15.075842696629222 }} ,
# 				{ 7 ,  {31.38333333333333 }} ,
# 				{ 8 ,  {50.0 }} ,
# 				{ 9 ,  {48.290476190476205 }} ,
# 				{ 10 ,  {43.525 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_12 <= 4.495) ? ( (Feature_5 <= 7.319499999999999) ? ( (Feature_4 <= 0.5675) ? ( 7 ) : ( 8 ) ) : ( (Feature_5 <= 8.253) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_12 <= 14.35) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_10
#
#
# 	namespace EXT_SubModel_11 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {18.994392523364485 }} ,
# 				{ 6 ,  {13.594871794871795 }} ,
# 				{ 7 ,  {32.56078431372549 }} ,
# 				{ 8 ,  {45.23913043478261 }} ,
# 				{ 9 ,  {36.86363636363636 }} ,
# 				{ 10 ,  {25.553488372093025 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_12 <= 9.95) ? ( (Feature_12 <= 5.155) ? ( (Feature_5 <= 7.405999999999999) ? ( 7 ) : ( 8 ) ) : ( (Feature_10 <= 13.85) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_0 <= 6.88166) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_11
#
#
# 	namespace EXT_SubModel_12 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {42.70833333333333 }} ,
# 				{ 6 ,  {19.209160305343516 }} ,
# 				{ 7 ,  {24.81212121212121 }} ,
# 				{ 8 ,  {33.1 }} ,
# 				{ 9 ,  {48.55714285714286 }} ,
# 				{ 10 ,  {39.066666666666656 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_2 <= 3.985) ? ( (Feature_5 <= 7.435) ? ( (Feature_5 <= 6.712) ? ( 7 ) : ( 8 ) ) : ( (Feature_11 <= 395.54) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_12 <= 4.665) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_12
#
#
# 	namespace EXT_SubModel_13 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {19.400925925925925 }} ,
# 				{ 6 ,  {12.37291666666666 }} ,
# 				{ 7 ,  {34.95909090909091 }} ,
# 				{ 8 ,  {46.49285714285714 }} ,
# 				{ 9 ,  {23.608823529411765 }} ,
# 				{ 10 ,  {30.510714285714286 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_12 <= 9.95) ? ( (Feature_12 <= 4.475) ? ( (Feature_5 <= 7.319499999999999) ? ( 7 ) : ( 8 ) ) : ( (Feature_5 <= 6.722) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_0 <= 5.769209999999999) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_13
#
#
# 	namespace EXT_SubModel_14 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {32.69722222222223 }} ,
# 				{ 6 ,  {47.374074074074066 }} ,
# 				{ 7 ,  {25.536538461538452 }} ,
# 				{ 8 ,  {18.755251141552517 }} ,
# 				{ 9 ,  {16.72222222222222 }} ,
# 				{ 10 ,  {10.764406779661014 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.978) ? ( (Feature_0 <= 9.285595) ? ( (Feature_12 <= 9.95) ? ( 7 ) : ( 8 ) ) : ( (Feature_7 <= 1.4147500000000002) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_5 <= 7.4369999999999985) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_14
#
#
# 	namespace EXT_SubModel_15 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {20.071320754716975 }} ,
# 				{ 6 ,  {13.360000000000005 }} ,
# 				{ 7 ,  {26.50909090909091 }} ,
# 				{ 8 ,  {33.32564102564103 }} ,
# 				{ 9 ,  {47.05454545454546 }} ,
# 				{ 10 ,  {39.15000000000001 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_12 <= 7.865) ? ( (Feature_5 <= 7.445) ? ( (Feature_5 <= 6.941) ? ( 7 ) : ( 8 ) ) : ( (Feature_12 <= 6.245) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_0 <= 5.84803) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_15
#
#
# 	namespace EXT_SubModel_16 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {38.68313253012049 }} ,
# 				{ 6 ,  {24.26 }} ,
# 				{ 7 ,  {50.0 }} ,
# 				{ 8 ,  {22.435526315789474 }} ,
# 				{ 9 ,  {16.950505050505054 }} ,
# 				{ 10 ,  {11.875308641975305 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.941) ? ( (Feature_12 <= 14.399999999999999) ? ( (Feature_7 <= 1.38485) ? ( 7 ) : ( 8 ) ) : ( (Feature_12 <= 19.9) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_10 <= 19.7) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_16
#
#
# 	namespace EXT_SubModel_17 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {36.065573770491795 }} ,
# 				{ 6 ,  {45.57058823529411 }} ,
# 				{ 7 ,  {25.748125 }} ,
# 				{ 8 ,  {19.02307692307692 }} ,
# 				{ 9 ,  {17.74444444444445 }} ,
# 				{ 10 ,  {10.708474576271186 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.974) ? ( (Feature_4 <= 0.6635) ? ( (Feature_12 <= 9.675) ? ( 7 ) : ( 8 ) ) : ( (Feature_0 <= 7.164630000000001) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_6 <= 86.59999999999998) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_17
#
#
# 	namespace EXT_SubModel_18 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {32.127906976744185 }} ,
# 				{ 6 ,  {47.05600000000001 }} ,
# 				{ 7 ,  {50.0 }} ,
# 				{ 8 ,  {22.98346456692913 }} ,
# 				{ 9 ,  {17.374782608695654 }} ,
# 				{ 10 ,  {11.932835820895527 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.92) ? ( (Feature_12 <= 14.405) ? ( (Feature_7 <= 1.38485) ? ( 7 ) : ( 8 ) ) : ( (Feature_0 <= 7.46495) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_5 <= 7.4369999999999985) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# ...
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_62
#
#
# 	namespace EXT_SubModel_63 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 5 ,  {31.05681818181818 }} ,
# 				{ 6 ,  {45.296774193548394 }} ,
# 				{ 7 ,  {50.0 }} ,
# 				{ 8 ,  {22.123287671232877 }} ,
# 				{ 9 ,  {17.144791666666666 }} ,
# 				{ 10 ,  {12.03857142857142 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.6665) ? ( (Feature_12 <= 14.405) ? ( (Feature_7 <= 1.22715) ? ( 7 ) : ( 8 ) ) : ( (Feature_0 <= 6.029745) ? ( 9 ) : ( 10 ) ) ) : ( (Feature_5 <= 7.454499999999999) ? ( 5 ) : ( 6 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_63
#
#
# 	std::vector<std::string> get_input_names(){
# 		std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 		return lFeatures;
# 	}
#
# 	std::vector<std::string> get_output_names(){
# 		std::vector<std::string> lOutputs = { "Estimator" };
#
# 		return lOutputs;
# 	}
#
# 	tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 		std::vector<tTable> lTreeScores = {
# 			EXT_SubModel_0::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_1::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_2::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_3::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_4::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_5::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_6::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_7::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_8::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_9::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_10::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_11::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_12::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_13::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_14::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_15::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_16::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_17::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_18::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_19::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_20::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_21::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_22::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_23::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_24::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_25::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_26::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_27::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_28::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_29::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_30::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_31::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_32::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_33::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_34::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_35::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_36::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_37::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_38::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_39::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_40::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_41::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_42::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_43::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_44::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_45::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_46::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_47::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_48::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_49::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_50::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_51::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_52::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_53::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_54::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_55::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_56::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_57::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_58::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_59::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_60::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_61::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_62::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_63::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12)
# 		};
#
# 		tTable lAggregatedTable = aggregate_rf_scores(lTreeScores, {"Estimator"});
#
#
# 		tTable lTable = lAggregatedTable;
#
#
# 		return lTable;
# 	}
#
# 	tTable compute_model_outputs_from_table( tTable const & iTable) {
# 		tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 		return lTable;
# 	}
#
# } // eof namespace

# %% [markdown]
# # Execute the CPP Code

# %%
    write_text_to_file = function(iCPPCode, oCPPFile) {
        fileConn<-file(oCPPFile)
        writeLines(c(iCPPCode), fileConn)
        close(fileConn)
    }

    add_cpp_main_function = function(iCPPCode, iCSVFile) {
        lCPPCode = "#include \"Generic.i\"\n\n"
        lCPPCode = paste(lCPPCode,  iCPPCode, sep="")
        lCPPCode = paste(lCPPCode, "\n\nint main() {\n", sep="")
        lCPPCode = paste(lCPPCode, "\tscore_csv_file(\"",  iCSVFile, "\");\n", sep="")
        lCPPCode = paste(lCPPCode, "\treturn 0;\n}\n", sep="")
        return(lCPPCode)
    }

    compile_cpp_code_as_executable = function(iName) {
        lCommand = paste("-Wall -Wno-unused-function -std=c++17 -g -o ", iName,  ".exe ",  iName,  ".cpp", sep="")
        cat(paste("EXECUTING " , "'",  lCommand,  "'", sep=""))
        result = system2("g++", args = lCommand)
        # print(result)
    }


    execute_cpp_model = function(iName, iCSVFile) {
        lOutName = paste(iName, ".out", sep="")
        result2 = system2(paste(iName, ".exe", sep="") ,  args = iCSVFile, stdout=lOutName)
        cat(result2)
        return(result2)
    }
        
    execute_cpp_code = function(iCPPCode, iCSVFile) {
        lTimeStr = format(Sys.time(), "%Y-%m-%d_%H_%M_%S")
        lName = paste("/tmp/ml2cpp_r_", "sample_" , lTimeStr, sep="");
        lCPPCode = add_cpp_main_function(iCPPCode, iCSVFile)
        write_text_to_file(lCPPCode, paste(lName, ".cpp", sep=""))
        compile_cpp_code_as_executable(lName)
        result = execute_cpp_model(lName, iCSVFile)
        lOutName = paste(lName, ".out", sep="")
        return(lOutName)
    }

# %%
df_cpp_in = as.data.frame(dataset)
# cat(names(df_cpp_in))

names(df_cpp_in) = sprintf("Feature_%d",0:(ncol(df_cpp_in)-1))

write.csv(df_cpp_in, "/tmp/boston2.csv", quote = FALSE)

lOutName = execute_cpp_code(lModelSQL, "/tmp/boston2.csv")
lOutName
# Out:
# EXECUTING '-Wall -Wno-unused-function -std=c++17 -g -o /tmp/ml2cpp_r_sample_2020-09-29_18_32_13.exe /tmp/ml2cpp_r_sample_2020-09-29_18_32_13.cpp'0
# [1] "/tmp/ml2cpp_r_sample_2020-09-29_18_32_13.out"

# %%
df_cpp_out <- read.csv(file = lOutName)
df_cpp_out$KEY = seq.int(nrow(df_cpp_out))
head(df_cpp_out)
# Out:
#   idx Estimator        KEY
# 1 0   25.7096870641091 1
# 2 1   23.0852487090328 2
# 3 2   34.5743804306574 3
# 4 3   34.1208432556770 4
# 5 4   31.9095949658386 5
# 6 5   25.3071515060204 6

# %%
# df_sql_out

# %% [markdown]
# # R RandomForest Output

# %%
estimator  =  predict(model, dataset, type = "raw")
df_r_out = data.frame(estimator)
names(df_r_out) = c("Estimator")

df_r_out$KEY = seq.int(nrow(dataset))
head(df_r_out)
# Out:
#   Estimator        KEY
# 1 25.7096870641091 1
# 2 23.0852487090328 2
# 3 34.5743804306574 3
# 4 34.1208432556770 4
# 5 31.9095949658386 5
# 6 25.3071515060204 6

# %% [markdown]
# # Compare R and SQL output

# %%
df_merge = merge(x = df_r_out, y = df_cpp_out, by = "KEY", all = TRUE, , suffixes = c("_1","_2"))
head(df_merge)
# Out:
#   KEY Estimator_1      idx Estimator_2
# 1 1   25.7096870641091 0   25.7096870641091
# 2 2   23.0852487090328 1   23.0852487090328
# 3 3   34.5743804306574 2   34.5743804306574
# 4 4   34.1208432556770 3   34.1208432556770
# 5 5   31.9095949658386 4   31.9095949658386
# 6 6   25.3071515060204 5   25.3071515060204

# %%
df_merge$Error = df_merge$Estimator_1 - df_merge$Estimator_2
df_merge$AbsError = abs(df_merge$Error)
head(df_merge)
# Out:
#   KEY Estimator_1      idx Estimator_2      Error
# 1 1   25.7096870641091 0   25.7096870641091  3.55271367880050e-15
# 2 2   23.0852487090328 1   23.0852487090328 -3.55271367880050e-15
# 3 3   34.5743804306574 2   34.5743804306574  0.00000000000000e+00
# 4 4   34.1208432556770 3   34.1208432556770 -2.13162820728030e-14
# 5 5   31.9095949658386 4   31.9095949658386  1.42108547152020e-14
# 6 6   25.3071515060204 5   25.3071515060204 -1.06581410364015e-14
#   AbsError
# 1 3.55271367880050e-15
# 2 3.55271367880050e-15
# 3 0.00000000000000e+00
# 4 2.13162820728030e-14
# 5 1.42108547152020e-14
# 6 1.06581410364015e-14

# %%
df_merge_largest_errors = df_merge[df_merge$AbsError > 0.0000001,]
df_merge_largest_errors
# Out:
#     KEY Estimator_1      idx Estimator_2      Error
# 176 176 25.5512241404877 175 25.4609248739061 0.0902992665816349
#     AbsError
# 176 0.0902992665816349

# %%
nrow(df_merge_largest_errors)
stopifnot(nrow(df_merge_largest_errors) <= 2)
# Out:
# [1] 1

# %%
summary(df_cpp_out)
# Out:
#       idx           Estimator                  KEY
#  Min.   :  0.00   Min.   :13.0500498569   Min.   :  1.00
#  1st Qu.:126.25   1st Qu.:17.6834445932   1st Qu.:127.25
#  Median :252.50   Median :21.1847038432   Median :253.50
#  Mean   :252.50   Mean   :22.5268199016   Mean   :253.50
#  3rd Qu.:378.75   3rd Qu.:24.3222606421   3rd Qu.:379.75
#  Max.   :505.00   Max.   :44.6482565751   Max.   :506.00

# %%
summary(df_r_out)
# Out:
#    Estimator                  KEY
#  Min.   :13.0500498569   Min.   :  1.00
#  1st Qu.:17.6834445932   1st Qu.:127.25
#  Median :21.1847038432   Median :253.50
#  Mean   :22.5269983586   Mean   :253.50
#  3rd Qu.:24.3222606421   3rd Qu.:379.75
#  Max.   :44.6482565751   Max.   :506.00

# %%
summary(df_merge)
# Out:
#       KEY          Estimator_1                 idx
#  Min.   :  1.00   Min.   :13.0500498569   Min.   :  0.00
#  1st Qu.:127.25   1st Qu.:17.6834445932   1st Qu.:126.25
#  Median :253.50   Median :21.1847038432   Median :252.50
#  Mean   :253.50   Mean   :22.5269983586   Mean   :252.50
#  3rd Qu.:379.75   3rd Qu.:24.3222606421   3rd Qu.:378.75
#  Max.   :506.00   Max.   :44.6482565751   Max.   :505.00
#   Estimator_2                Error
#  Min.   :13.0500498569   Min.   :-3.55000000000e-14
#  1st Qu.:17.6834445932   1st Qu.:-3.60000000000e-15
#  Median :21.1847038432   Median : 0.00000000000e+00
#  Mean   :22.5268199016   Mean   : 1.78457048581e-04
#  3rd Qu.:24.3222606421   3rd Qu.: 3.60000000000e-15
#  Max.   :44.6482565751   Max.   : 9.02992665816e-02
#     AbsError
#  Min.   :0.00000000000e+00
#  1st Qu.:3.60000000000e-15
#  Median :3.60000000000e-15
#  Mean   :1.78457048586e-04
#  3rd Qu.:7.10000000000e-15
#  Max.   :9.02992665816e-02
