# %% [markdown]
# # ML2CPP

# %% [markdown]
# ## Preparing the dataset

# %%
from sklearn import datasets
import numpy as np
import pandas as pd

def populate_table(tablename, feature_names):
    iris = datasets.load_iris()
    X = iris.data  
    N = X.shape[0]
    y = iris.target.reshape(N,1)
    k = np.arange(N).reshape(N, 1)
    k_X_y = np.concatenate((k, X, y) , axis=1)
    lTable=pd.DataFrame(k_X_y)
    # print(lTable.head())
    lTable.columns = ['idx'] + feature_names + ['TGT'];
    lTable['TGT'] = lTable['TGT'].apply(int)
    lTable['idx'] = lTable['idx'].apply(int)
    lTable.to_csv(tablename , float_format='%.14g')

# %%
metadata = {"primary_key" : "KEY",
            "features" : ['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm', 'petal_width_cm'],
            "targets" : ["TGT"],
            "table" : "iris"}

# %%
populate_table("/tmp/iris.csv" , metadata["features"])

# %%
df = pd.read_csv("/tmp/iris.csv")
df.sample(12, random_state=1960)
# Out:
#      Unnamed: 0  idx  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# 114         114  114              5.8             2.8              5.1
# 74           74   74              6.4             2.9              4.3
# 9             9    9              4.9             3.1              1.5
# 88           88   88              5.6             3.0              4.1
# 25           25   25              5.0             3.0              1.6
# 5             5    5              5.4             3.9              1.7
# 48           48   48              5.3             3.7              1.5
# 117         117  117              7.7             3.8              6.7
# 83           83   83              6.0             2.7              5.1
# 105         105  105              7.6             3.0              6.6
# 27           27   27              5.2             3.5              1.5
# 64           64   64              5.6             2.9              3.6
#
#      petal_width_cm  TGT
# 114             2.4    2
# 74              1.3    1
# 9               0.1    0
# 88              1.3    1
# 25              0.2    0
# 5               0.4    0
# 48              0.2    0
# 117             2.2    2
# 83              1.6    1
# 105             2.1    2
# 27              0.2    0
# 64              1.3    1

# %% [markdown]
# ## Training a Model

# %%
# train any scikit model on the iris dataset
from sklearn.pipeline import FeatureUnion

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.impute import SimpleImputer

clf = FeatureUnion([('imputer', SimpleImputer()), 
                    ('std_scaler', StandardScaler()), 
                    ('robust_scaler', RobustScaler()), 
                    ('kbins', KBinsDiscretizer())])
clf.fit(df[metadata['features']].values, df[metadata['targets']].values)
# Out:
# FeatureUnion(transformer_list=[('imputer', SimpleImputer()),
#                                ('std_scaler', StandardScaler()),
#                                ('robust_scaler', RobustScaler()),
#                                ('kbins', KBinsDiscretizer())])

# %% [markdown]
# ## Deploying the Model

# %%
def generate_cpp_for_model(model):
    import pickle, json, requests, base64
    b64_data = base64.b64encode(pickle.dumps(model)).decode('utf-8')
    # send the model th the web service
    json_data={"Name":"model_cpp_sample", 
               "PickleData":b64_data , 
               "SQLDialect":"CPP",
               "FeatureNames" : metadata['features']}
    r = requests.post("https://sklearn2sql.herokuapp.com/model", json=json_data)
    content = r.json()
    lCPP = content["model"]["SQLGenrationResult"][0]["SQL"]
    # print(lCPP);
    return lCPP


lCPPCode = generate_cpp_for_model(clf);

# %%
print(lCPPCode)
# Out:
# namespace  {
#
# 	namespace imputer {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "imputer_output_1", "imputer_output_2", "imputer_output_3", "imputer_output_4" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
#
# 			tTable lTable;
#
# 			lTable["imputer_output_1"] = { ((Feature_0 == std::any()) ?  ( 5.843333333333334 ) : ( Feature_0)) };
# 			lTable["imputer_output_2"] = { ((Feature_1 == std::any()) ?  ( 3.0573333333333337 ) : ( Feature_1)) };
# 			lTable["imputer_output_3"] = { ((Feature_2 == std::any()) ?  ( 3.7580000000000005 ) : ( Feature_2)) };
# 			lTable["imputer_output_4"] = { ((Feature_3 == std::any()) ?  ( 1.1993333333333336 ) : ( Feature_3)) };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace imputer
#
#
# 	namespace std_scaler {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "std_scaler_output_1", "std_scaler_output_2", "std_scaler_output_3", "std_scaler_output_4" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
#
# 			tTable lTable;
#
# 			lTable["std_scaler_output_1"] = { ( ( Feature_0 - 5.843333333333334 ) / 0.8253012917851409 ) };
# 			lTable["std_scaler_output_2"] = { ( ( Feature_1 - 3.0573333333333337 ) / 0.4344109677354946 ) };
# 			lTable["std_scaler_output_3"] = { ( ( Feature_2 - 3.7580000000000005 ) / 1.759404065775303 ) };
# 			lTable["std_scaler_output_4"] = { ( ( Feature_3 - 1.1993333333333336 ) / 0.7596926279021594 ) };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace std_scaler
#
#
# 	namespace robust_scaler {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "robust_scaler_output_1", "robust_scaler_output_2", "robust_scaler_output_3", "robust_scaler_output_4" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
#
# 			tTable lTable;
#
# 			lTable["robust_scaler_output_1"] = { ((Feature_0 - 5.8) / 1.3000000000000007) };
# 			lTable["robust_scaler_output_2"] = { ((Feature_1 - 3.0) / 0.5) };
# 			lTable["robust_scaler_output_3"] = { ((Feature_2 - 4.35) / 3.4999999999999996) };
# 			lTable["robust_scaler_output_4"] = { ((Feature_3 - 1.3) / 1.5) };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace robust_scaler
#
#
# 	namespace kbins {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "kbins_output_1", "kbins_output_2", "kbins_output_3", "kbins_output_4", "kbins_output_5", "kbins_output_6", "kbins_output_7", "kbins_output_8", "kbins_output_9", "kbins_output_10", "kbins_output_11", "kbins_output_12", "kbins_output_13", "kbins_output_14", "kbins_output_15", "kbins_output_16", "kbins_output_17", "kbins_output_18", "kbins_output_19", "kbins_output_20" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
#
# 			tTable lTable;
#
# 			lTable["kbins_output_1"] = { (( Feature_0 < 5.0 ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_2"] = { (( ( Feature_0 < 5.6 ) && ( 5.0 <= Feature_0 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_3"] = { (( ( Feature_0 < 6.1 ) && ( 5.6 <= Feature_0 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_4"] = { (( ( Feature_0 < 6.5200000000000005 ) && ( 6.1 <= Feature_0 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_5"] = { (( 6.5200000000000005 <= Feature_0 ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_6"] = { (( Feature_1 < 2.7 ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_7"] = { (( ( Feature_1 < 3.0 ) && ( 2.7 <= Feature_1 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_8"] = { (( ( Feature_1 < 3.1 ) && ( 3.0 <= Feature_1 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_9"] = { (( ( Feature_1 < 3.4 ) && ( 3.1 <= Feature_1 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_10"] = { (( 3.4 <= Feature_1 ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_11"] = { (( Feature_2 < 1.5 ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_12"] = { (( ( Feature_2 < 3.9000000000000004 ) && ( 1.5 <= Feature_2 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_13"] = { (( ( Feature_2 < 4.639999999999999 ) && ( 3.9000000000000004 <= Feature_2 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_14"] = { (( ( Feature_2 < 5.32 ) && ( 4.639999999999999 <= Feature_2 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_15"] = { (( 5.32 <= Feature_2 ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_16"] = { (( Feature_3 < 0.2 ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_17"] = { (( ( Feature_3 < 1.1600000000000001 ) && ( 0.2 <= Feature_3 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_18"] = { (( ( Feature_3 < 1.5 ) && ( 1.1600000000000001 <= Feature_3 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_19"] = { (( ( Feature_3 < 1.9 ) && ( 1.5 <= Feature_3 ) ) ? ( 1.0 ) : ( 0.0 )) };
# 			lTable["kbins_output_20"] = { (( 1.9 <= Feature_3 ) ? ( 1.0 ) : ( 0.0 )) };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace kbins
#
#
# 	std::vector<std::string> get_input_names(){
# 		std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 		return lFeatures;
# 	}
#
# 	std::vector<std::string> get_output_names(){
# 		std::vector<std::string> lOutputs = { "imputer::imputer_output_1", "imputer::imputer_output_2", "imputer::imputer_output_3", "imputer::imputer_output_4", "std_scaler::std_scaler_output_1", "std_scaler::std_scaler_output_2", "std_scaler::std_scaler_output_3", "std_scaler::std_scaler_output_4", "robust_scaler::robust_scaler_output_1", "robust_scaler::robust_scaler_output_2", "robust_scaler::robust_scaler_output_3", "robust_scaler::robust_scaler_output_4", "kbins::kbins_output_1", "kbins::kbins_output_2", "kbins::kbins_output_3", "kbins::kbins_output_4", "kbins::kbins_output_5", "kbins::kbins_output_6", "kbins::kbins_output_7", "kbins::kbins_output_8", "kbins::kbins_output_9", "kbins::kbins_output_10", "kbins::kbins_output_11", "kbins::kbins_output_12", "kbins::kbins_output_13", "kbins::kbins_output_14", "kbins::kbins_output_15", "kbins::kbins_output_16", "kbins::kbins_output_17", "kbins::kbins_output_18", "kbins::kbins_output_19", "kbins::kbins_output_20" };
#
# 		return lOutputs;
# 	}
#
# 	tTable compute_features(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
#
# 		tTable lTable;
#
# 		tTable lFeatures_imputer = imputer::compute_features(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 		tTable lFeatures_std_scaler = std_scaler::compute_features(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 		tTable lFeatures_robust_scaler = robust_scaler::compute_features(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 		tTable lFeatures_kbins = kbins::compute_features(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 		lTable["imputer::imputer_output_1"] = { lFeatures_imputer[ "imputer_output_1" ][0] };
# 		lTable["imputer::imputer_output_2"] = { lFeatures_imputer[ "imputer_output_2" ][0] };
# 		lTable["imputer::imputer_output_3"] = { lFeatures_imputer[ "imputer_output_3" ][0] };
# 		lTable["imputer::imputer_output_4"] = { lFeatures_imputer[ "imputer_output_4" ][0] };
# 		lTable["std_scaler::std_scaler_output_1"] = { lFeatures_std_scaler[ "std_scaler_output_1" ][0] };
# 		lTable["std_scaler::std_scaler_output_2"] = { lFeatures_std_scaler[ "std_scaler_output_2" ][0] };
# 		lTable["std_scaler::std_scaler_output_3"] = { lFeatures_std_scaler[ "std_scaler_output_3" ][0] };
# 		lTable["std_scaler::std_scaler_output_4"] = { lFeatures_std_scaler[ "std_scaler_output_4" ][0] };
# 		lTable["robust_scaler::robust_scaler_output_1"] = { lFeatures_robust_scaler[ "robust_scaler_output_1" ][0] };
# 		lTable["robust_scaler::robust_scaler_output_2"] = { lFeatures_robust_scaler[ "robust_scaler_output_2" ][0] };
# 		lTable["robust_scaler::robust_scaler_output_3"] = { lFeatures_robust_scaler[ "robust_scaler_output_3" ][0] };
# 		lTable["robust_scaler::robust_scaler_output_4"] = { lFeatures_robust_scaler[ "robust_scaler_output_4" ][0] };
# 		lTable["kbins::kbins_output_1"] = { lFeatures_kbins[ "kbins_output_1" ][0] };
# 		lTable["kbins::kbins_output_2"] = { lFeatures_kbins[ "kbins_output_2" ][0] };
# 		lTable["kbins::kbins_output_3"] = { lFeatures_kbins[ "kbins_output_3" ][0] };
# 		lTable["kbins::kbins_output_4"] = { lFeatures_kbins[ "kbins_output_4" ][0] };
# 		lTable["kbins::kbins_output_5"] = { lFeatures_kbins[ "kbins_output_5" ][0] };
# 		lTable["kbins::kbins_output_6"] = { lFeatures_kbins[ "kbins_output_6" ][0] };
# 		lTable["kbins::kbins_output_7"] = { lFeatures_kbins[ "kbins_output_7" ][0] };
# 		lTable["kbins::kbins_output_8"] = { lFeatures_kbins[ "kbins_output_8" ][0] };
# 		lTable["kbins::kbins_output_9"] = { lFeatures_kbins[ "kbins_output_9" ][0] };
# 		lTable["kbins::kbins_output_10"] = { lFeatures_kbins[ "kbins_output_10" ][0] };
# 		lTable["kbins::kbins_output_11"] = { lFeatures_kbins[ "kbins_output_11" ][0] };
# 		lTable["kbins::kbins_output_12"] = { lFeatures_kbins[ "kbins_output_12" ][0] };
# 		lTable["kbins::kbins_output_13"] = { lFeatures_kbins[ "kbins_output_13" ][0] };
# 		lTable["kbins::kbins_output_14"] = { lFeatures_kbins[ "kbins_output_14" ][0] };
# 		lTable["kbins::kbins_output_15"] = { lFeatures_kbins[ "kbins_output_15" ][0] };
# 		lTable["kbins::kbins_output_16"] = { lFeatures_kbins[ "kbins_output_16" ][0] };
# 		lTable["kbins::kbins_output_17"] = { lFeatures_kbins[ "kbins_output_17" ][0] };
# 		lTable["kbins::kbins_output_18"] = { lFeatures_kbins[ "kbins_output_18" ][0] };
# 		lTable["kbins::kbins_output_19"] = { lFeatures_kbins[ "kbins_output_19" ][0] };
# 		lTable["kbins::kbins_output_20"] = { lFeatures_kbins[ "kbins_output_20" ][0] };
#
# 		return lTable;
# 	}
#
# 	tTable compute_model_outputs_from_table( tTable const & iTable) {
# 		tTable lTable = compute_features(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 		return lTable;
# 	}
#
# } // eof namespace

# %%
    def write_text_to_file(iCPPCode, oCPPFile):          
        with open(oCPPFile, "w") as text_file:
            text_file.write(iCPPCode)

    def add_cpp_main_function(iCPPCode, iCSVFile):
        lCPPCode = "#include \"Generic.i\"\n\n"
        lCPPCode = lCPPCode + iCPPCode
        lCPPCode = lCPPCode + "\tint main() {\n"
        lCPPCode = lCPPCode + "\t\tscore_csv_file(\"" + iCSVFile +"\");\n"
        lCPPCode = lCPPCode + "\treturn 0;\n}\n"
        return lCPPCode

    def compile_cpp_code_as_executable(iName):
        import subprocess
        lCommand = ["g++", "-Wall", "-Wno-unused-function", "-std=c++17" , "-g" ,  "-o", iName + ".exe",  iName + ".cpp"]
        print("EXECUTING" , "'" + " ".join(lCommand) + "'")
        result = subprocess.check_output(lCommand)
        # print(result)

    def execute_cpp_model(iName, iCSVFile):
        import subprocess
        result2 = subprocess.check_output([iName + ".exe",  iCSVFile])
        result2 = result2.decode()
        print(result2[:1000])
        print(result2[-1000:])
        return result2
        
    def execute_cpp_code(iCPPCode, iCSVFile):
        lName = "/tmp/sklearn2sql_cpp_" + str(id(clf));
        lCPPCode = add_cpp_main_function(iCPPCode, iCSVFile)
        write_text_to_file(lCPPCode, lName + ".cpp")
        compile_cpp_code_as_executable(lName)
        result = execute_cpp_model(lName, iCSVFile)
        write_text_to_file(str(result), lName + ".out")
        return lName + ".out"

# %%
populate_table("/tmp/iris2.csv" , ["Feature_0", "Feature_1", "Feature_2", "Feature_3"])
lCPPOutput = execute_cpp_code(lCPPCode , "/tmp/iris2.csv")
cpp_output = pd.read_csv(lCPPOutput)
# Out:
# EXECUTING 'g++ -Wall -Wno-unused-function -std=c++17 -g -o /tmp/sklearn2sql_cpp_139961001187072.exe /tmp/sklearn2sql_cpp_139961001187072.cpp'
# idx,imputer::imputer_output_1,imputer::imputer_output_2,imputer::imputer_output_3,imputer::imputer_output_4,std_scaler::std_scaler_output_1,std_scaler::std_scaler_output_2,std_scaler::std_scaler_output_3,std_scaler::std_scaler_output_4,robust_scaler::robust_scaler_output_1,robust_scaler::robust_scaler_output_2,robust_scaler::robust_scaler_output_3,robust_scaler::robust_scaler_output_4,kbins::kbins_output_1,kbins::kbins_output_2,kbins::kbins_output_3,kbins::kbins_output_4,kbins::kbins_output_5,kbins::kbins_output_6,kbins::kbins_output_7,kbins::kbins_output_8,kbins::kbins_output_9,kbins::kbins_output_10,kbins::kbins_output_11,kbins::kbins_output_12,kbins::kbins_output_13,kbins::kbins_output_14,kbins::kbins_output_15,kbins::kbins_output_16,kbins::kbins_output_17,kbins::kbins_output_18,kbins::kbins_output_19,kbins::kbins_output_20
# 0,5.10000000000000,3.50000000000000,1.40000000000000,0.20000000000000,-0.90068117029781,1.01900435197161,-1.34022652662276,-1.31544429500774,-0.53846153846154,1.
# 58571296,0.93327054992136,1.44883157508858,0.30769230769231,0.80000000000000,0.30000000000000,0.66666666666667,0.00000000000000,0.00000000000000,0.00000000000000,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,1.00000000000000
# 149,5.90000000000000,3.00000000000000,5.10000000000000,1.80000000000000,0.06866179325140,-0.13197947932162,0.76275826918055,0.79067065363707,0.07692307692308,0.00000000000000,0.21428571428571,0.33333333333333,0.00000000000000,0.00000000000000,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,1.00000000000000,0.00000000000000

# %%
cpp_output.sample(12, random_state=1960)
# Out:
#      idx  imputer::imputer_output_1  imputer::imputer_output_2  \
# 114  114                        5.8                        2.8
# 74    74                        6.4                        2.9
# 9      9                        4.9                        3.1
# 88    88                        5.6                        3.0
# 25    25                        5.0                        3.0
# 5      5                        5.4                        3.9
# 48    48                        5.3                        3.7
# 117  117                        7.7                        3.8
# 83    83                        6.0                        2.7
# 105  105                        7.6                        3.0
# 27    27                        5.2                        3.5
# 64    64                        5.6                        2.9
#
#      imputer::imputer_output_3  imputer::imputer_output_4  \
# 114                        5.1                        2.4
# 74                         4.3                        1.3
# 9                          1.5                        0.1
# 88                         4.1                        1.3
# 25                         1.6                        0.2
# 5                          1.7                        0.4
# 48                         1.5                        0.2
# 117                        6.7                        2.2
# 83                         5.1                        1.6
# 105                        6.6                        2.1
# 27                         1.5                        0.2
# 64                         3.6                        1.3
#
#      std_scaler::std_scaler_output_1  std_scaler::std_scaler_output_2  \
# 114                        -0.052506                        -0.592373
# 74                          0.674501                        -0.362176
# 9                          -1.143017                         0.098217
# 88                         -0.294842                        -0.131979
# 25                         -1.021849                        -0.131979
# 5                          -0.537178                         1.939791
# 48                         -0.658345                         1.479398
# 117                         2.249683                         1.709595
# 83                          0.189830                        -0.822570
# 105                         2.128516                        -0.131979
# 27                         -0.779513                         1.019004
# 64                         -0.294842                        -0.362176
#
#      std_scaler::std_scaler_output_3  std_scaler::std_scaler_output_4  \
# 114                         0.762758                         1.580464
# 74                          0.308059                         0.132510
# 9                          -1.283389                        -1.447076
# 88                          0.194384                         0.132510
# 25                         -1.226552                        -1.315444
# 5                          -1.169714                        -1.052180
# 48                         -1.283389                        -1.315444
# 117                         1.672157                         1.317199
# 83                          0.762758                         0.527406
# 105                         1.615320                         1.185567
# 27                         -1.283389                        -1.315444
# 64                         -0.089803                         0.132510
#
#      robust_scaler::robust_scaler_output_1  ...  kbins::kbins_output_11  \
# 114                               0.000000  ...                     0.0
# 74                                0.461538  ...                     0.0
# 9                                -0.692308  ...                     0.0
# 88                               -0.153846  ...                     0.0
# 25                               -0.615385  ...                     0.0
# 5                                -0.307692  ...                     0.0
# 48                               -0.384615  ...                     0.0
# 117                               1.461538  ...                     0.0
# 83                                0.153846  ...                     0.0
# 105                               1.384615  ...                     0.0
# 27                               -0.461538  ...                     0.0
# 64                               -0.153846  ...                     0.0
#
#      kbins::kbins_output_12  kbins::kbins_output_13  kbins::kbins_output_14  \
# 114                     0.0                     0.0                     1.0
# 74                      0.0                     1.0                     0.0
# 9                       1.0                     0.0                     0.0
# 88                      0.0                     1.0                     0.0
# 25                      1.0                     0.0                     0.0
# 5                       1.0                     0.0                     0.0
# 48                      1.0                     0.0                     0.0
# 117                     0.0                     0.0                     0.0
# 83                      0.0                     0.0                     1.0
# 105                     0.0                     0.0                     0.0
# 27                      1.0                     0.0                     0.0
# 64                      1.0                     0.0                     0.0
#
#      kbins::kbins_output_15  kbins::kbins_output_16  kbins::kbins_output_17  \
# 114                     0.0                     0.0                     0.0
# 74                      0.0                     0.0                     0.0
# 9                       0.0                     1.0                     0.0
# 88                      0.0                     0.0                     0.0
# 25                      0.0                     0.0                     1.0
# 5                       0.0                     0.0                     1.0
# 48                      0.0                     0.0                     1.0
# 117                     1.0                     0.0                     0.0
# 83                      0.0                     0.0                     0.0
# 105                     1.0                     0.0                     0.0
# 27                      0.0                     0.0                     1.0
# 64                      0.0                     0.0                     0.0
#
#      kbins::kbins_output_18  kbins::kbins_output_19  kbins::kbins_output_20
# 114                     0.0                     0.0                     1.0
# 74                      1.0                     0.0                     0.0
# 9                       0.0                     0.0                     0.0
# 88                      1.0                     0.0                     0.0
# 25                      0.0                     0.0                     0.0
# 5                       0.0                     0.0                     0.0
# 48                      0.0                     0.0                     0.0
# 117                     0.0                     0.0                     1.0
# 83                      0.0                     1.0                     0.0
# 105                     0.0                     0.0                     1.0
# 27                      0.0                     0.0                     0.0
# 64                      1.0                     0.0                     0.0
#
# [12 rows x 33 columns]

# %%
skl_outputs = pd.DataFrame()
X = df[metadata['features']].values
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['idx']);

skl_output_transform = pd.DataFrame(clf.transform(X).todense(), columns=cpp_output.columns[1:]);
skl_output = pd.concat([skl_output_key, skl_output_transform] , axis=1)
skl_output.sample(12, random_state=1960)
# Out:
#      idx  imputer::imputer_output_1  imputer::imputer_output_2  \
# 114  114                        5.8                        2.8
# 74    74                        6.4                        2.9
# 9      9                        4.9                        3.1
# 88    88                        5.6                        3.0
# 25    25                        5.0                        3.0
# 5      5                        5.4                        3.9
# 48    48                        5.3                        3.7
# 117  117                        7.7                        3.8
# 83    83                        6.0                        2.7
# 105  105                        7.6                        3.0
# 27    27                        5.2                        3.5
# 64    64                        5.6                        2.9
#
#      imputer::imputer_output_3  imputer::imputer_output_4  \
# 114                        5.1                        2.4
# 74                         4.3                        1.3
# 9                          1.5                        0.1
# 88                         4.1                        1.3
# 25                         1.6                        0.2
# 5                          1.7                        0.4
# 48                         1.5                        0.2
# 117                        6.7                        2.2
# 83                         5.1                        1.6
# 105                        6.6                        2.1
# 27                         1.5                        0.2
# 64                         3.6                        1.3
#
#      std_scaler::std_scaler_output_1  std_scaler::std_scaler_output_2  \
# 114                        -0.052506                        -0.592373
# 74                          0.674501                        -0.362176
# 9                          -1.143017                         0.098217
# 88                         -0.294842                        -0.131979
# 25                         -1.021849                        -0.131979
# 5                          -0.537178                         1.939791
# 48                         -0.658345                         1.479398
# 117                         2.249683                         1.709595
# 83                          0.189830                        -0.822570
# 105                         2.128516                        -0.131979
# 27                         -0.779513                         1.019004
# 64                         -0.294842                        -0.362176
#
#      std_scaler::std_scaler_output_3  std_scaler::std_scaler_output_4  \
# 114                         0.762758                         1.580464
# 74                          0.308059                         0.132510
# 9                          -1.283389                        -1.447076
# 88                          0.194384                         0.132510
# 25                         -1.226552                        -1.315444
# 5                          -1.169714                        -1.052180
# 48                         -1.283389                        -1.315444
# 117                         1.672157                         1.317199
# 83                          0.762758                         0.527406
# 105                         1.615320                         1.185567
# 27                         -1.283389                        -1.315444
# 64                         -0.089803                         0.132510
#
#      robust_scaler::robust_scaler_output_1  ...  kbins::kbins_output_11  \
# 114                               0.000000  ...                     0.0
# 74                                0.461538  ...                     0.0
# 9                                -0.692308  ...                     0.0
# 88                               -0.153846  ...                     0.0
# 25                               -0.615385  ...                     0.0
# 5                                -0.307692  ...                     0.0
# 48                               -0.384615  ...                     0.0
# 117                               1.461538  ...                     0.0
# 83                                0.153846  ...                     0.0
# 105                               1.384615  ...                     0.0
# 27                               -0.461538  ...                     0.0
# 64                               -0.153846  ...                     0.0
#
#      kbins::kbins_output_12  kbins::kbins_output_13  kbins::kbins_output_14  \
# 114                     0.0                     0.0                     1.0
# 74                      0.0                     1.0                     0.0
# 9                       1.0                     0.0                     0.0
# 88                      0.0                     1.0                     0.0
# 25                      1.0                     0.0                     0.0
# 5                       1.0                     0.0                     0.0
# 48                      1.0                     0.0                     0.0
# 117                     0.0                     0.0                     0.0
# 83                      0.0                     0.0                     1.0
# 105                     0.0                     0.0                     0.0
# 27                      1.0                     0.0                     0.0
# 64                      1.0                     0.0                     0.0
#
#      kbins::kbins_output_15  kbins::kbins_output_16  kbins::kbins_output_17  \
# 114                     0.0                     0.0                     0.0
# 74                      0.0                     0.0                     0.0
# 9                       0.0                     1.0                     0.0
# 88                      0.0                     0.0                     0.0
# 25                      0.0                     0.0                     1.0
# 5                       0.0                     0.0                     1.0
# 48                      0.0                     0.0                     1.0
# 117                     1.0                     0.0                     0.0
# 83                      0.0                     0.0                     0.0
# 105                     1.0                     0.0                     0.0
# 27                      0.0                     0.0                     1.0
# 64                      0.0                     0.0                     0.0
#
#      kbins::kbins_output_18  kbins::kbins_output_19  kbins::kbins_output_20
# 114                     0.0                     0.0                     1.0
# 74                      1.0                     0.0                     0.0
# 9                       0.0                     0.0                     0.0
# 88                      1.0                     0.0                     0.0
# 25                      0.0                     0.0                     0.0
# 5                       0.0                     0.0                     0.0
# 48                      0.0                     0.0                     0.0
# 117                     0.0                     0.0                     1.0
# 83                      0.0                     1.0                     0.0
# 105                     0.0                     0.0                     1.0
# 27                      0.0                     0.0                     0.0
# 64                      1.0                     0.0                     0.0
#
# [12 rows x 33 columns]

# %%
cpp_skl_join = skl_output.join(cpp_output , how='left', on='idx', lsuffix='_skl', rsuffix='_cpp')

# %%
cpp_skl_join.sample(12, random_state=1960)
# Out:
#      idx_skl  imputer::imputer_output_1_skl  imputer::imputer_output_2_skl  \
# 114      114                            5.8                            2.8
# 74        74                            6.4                            2.9
# 9          9                            4.9                            3.1
# 88        88                            5.6                            3.0
# 25        25                            5.0                            3.0
# 5          5                            5.4                            3.9
# 48        48                            5.3                            3.7
# 117      117                            7.7                            3.8
# 83        83                            6.0                            2.7
# 105      105                            7.6                            3.0
# 27        27                            5.2                            3.5
# 64        64                            5.6                            2.9
#
#      imputer::imputer_output_3_skl  imputer::imputer_output_4_skl  \
# 114                            5.1                            2.4
# 74                             4.3                            1.3
# 9                              1.5                            0.1
# 88                             4.1                            1.3
# 25                             1.6                            0.2
# 5                              1.7                            0.4
# 48                             1.5                            0.2
# 117                            6.7                            2.2
# 83                             5.1                            1.6
# 105                            6.6                            2.1
# 27                             1.5                            0.2
# 64                             3.6                            1.3
#
#      std_scaler::std_scaler_output_1_skl  std_scaler::std_scaler_output_2_skl  \
# 114                            -0.052506                            -0.592373
# 74                              0.674501                            -0.362176
# 9                              -1.143017                             0.098217
# 88                             -0.294842                            -0.131979
# 25                             -1.021849                            -0.131979
# 5                              -0.537178                             1.939791
# 48                             -0.658345                             1.479398
# 117                             2.249683                             1.709595
# 83                              0.189830                            -0.822570
# 105                             2.128516                            -0.131979
# 27                             -0.779513                             1.019004
# 64                             -0.294842                            -0.362176
#
#      std_scaler::std_scaler_output_3_skl  std_scaler::std_scaler_output_4_skl  \
# 114                             0.762758                             1.580464
# 74                              0.308059                             0.132510
# 9                              -1.283389                            -1.447076
# 88                              0.194384                             0.132510
# 25                             -1.226552                            -1.315444
# 5                              -1.169714                            -1.052180
# 48                             -1.283389                            -1.315444
# 117                             1.672157                             1.317199
# 83                              0.762758                             0.527406
# 105                             1.615320                             1.185567
# 27                             -1.283389                            -1.315444
# 64                             -0.089803                             0.132510
#
#      robust_scaler::robust_scaler_output_1_skl  ...  \
# 114                                   0.000000  ...
# 74                                    0.461538  ...
# 9                                    -0.692308  ...
# 88                                   -0.153846  ...
# 25                                   -0.615385  ...
# 5                                    -0.307692  ...
# 48                                   -0.384615  ...
# 117                                   1.461538  ...
# 83                                    0.153846  ...
# 105                                   1.384615  ...
# 27                                   -0.461538  ...
# 64                                   -0.153846  ...
#
#      kbins::kbins_output_11_cpp  kbins::kbins_output_12_cpp  \
# 114                         0.0                         0.0
# 74                          0.0                         0.0
# 9                           0.0                         1.0
# 88                          0.0                         0.0
# 25                          0.0                         1.0
# 5                           0.0                         1.0
# 48                          0.0                         1.0
# 117                         0.0                         0.0
# 83                          0.0                         0.0
# 105                         0.0                         0.0
# 27                          0.0                         1.0
# 64                          0.0                         1.0
#
#      kbins::kbins_output_13_cpp  kbins::kbins_output_14_cpp  \
# 114                         0.0                         1.0
# 74                          1.0                         0.0
# 9                           0.0                         0.0
# 88                          1.0                         0.0
# 25                          0.0                         0.0
# 5                           0.0                         0.0
# 48                          0.0                         0.0
# 117                         0.0                         0.0
# 83                          0.0                         1.0
# 105                         0.0                         0.0
# 27                          0.0                         0.0
# 64                          0.0                         0.0
#
#      kbins::kbins_output_15_cpp  kbins::kbins_output_16_cpp  \
# 114                         0.0                         0.0
# 74                          0.0                         0.0
# 9                           0.0                         1.0
# 88                          0.0                         0.0
# 25                          0.0                         0.0
# 5                           0.0                         0.0
# 48                          0.0                         0.0
# 117                         1.0                         0.0
# 83                          0.0                         0.0
# 105                         1.0                         0.0
# 27                          0.0                         0.0
# 64                          0.0                         0.0
#
#      kbins::kbins_output_17_cpp  kbins::kbins_output_18_cpp  \
# 114                         0.0                         0.0
# 74                          0.0                         1.0
# 9                           0.0                         0.0
# 88                          0.0                         1.0
# 25                          1.0                         0.0
# 5                           1.0                         0.0
# 48                          1.0                         0.0
# 117                         0.0                         0.0
# 83                          0.0                         0.0
# 105                         0.0                         0.0
# 27                          1.0                         0.0
# 64                          0.0                         1.0
#
#      kbins::kbins_output_19_cpp  kbins::kbins_output_20_cpp
# 114                         0.0                         1.0
# 74                          0.0                         0.0
# 9                           0.0                         0.0
# 88                          0.0                         0.0
# 25                          0.0                         0.0
# 5                           0.0                         0.0
# 48                          0.0                         0.0
# 117                         0.0                         1.0
# 83                          1.0                         0.0
# 105                         0.0                         1.0
# 27                          0.0                         0.0
# 64                          0.0                         0.0
#
# [12 rows x 66 columns]

# %%
for col in cpp_output.columns:
    lDiff = cpp_skl_join[col + "_skl"] - cpp_skl_join[col + "_cpp"]
    print(lDiff.describe())
# Out:
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    1.500000e+02
# mean    -2.066865e-16
# std      2.732826e-15
# min     -4.662937e-15
# 25%     -2.942091e-15
# 50%     -4.163336e-16
# 75%      2.373102e-15
# max      4.884981e-15
# dtype: float64
# count    1.500000e+02
# mean    -7.393160e-16
# std      2.972491e-15
# min     -4.690692e-15
# 25%     -3.108624e-15
# 50%     -1.221245e-15
# 75%      1.817990e-15
# max      4.884981e-15
# dtype: float64
# count    1.500000e+02
# mean     7.017535e-17
# std      3.067320e-15
# min     -4.940492e-15
# 25%     -2.442491e-15
# 50%      6.661338e-16
# 75%      2.886580e-15
# max      5.107026e-15
# dtype: float64
# count    1.500000e+02
# mean    -2.413289e-16
# std      2.261244e-15
# min     -4.884981e-15
# 25%     -1.675960e-15
# 50%     -2.220446e-16
# 75%      9.992007e-16
# max      4.329870e-15
# dtype: float64
# count    1.500000e+02
# mean     3.345472e-16
# std      2.887301e-15
# min     -4.884981e-15
# 25%     -1.665335e-15
# 50%      5.828671e-16
# 75%      2.886580e-15
# max      4.884981e-15
# dtype: float64
# count    1.500000e+02
# mean    -1.517305e-17
# std      2.768393e-16
# min     -8.881784e-16
# 25%     -2.220446e-16
# 50%      0.000000e+00
# 75%      2.220446e-16
# max      8.881784e-16
# dtype: float64
# count    1.500000e+02
# mean    -1.948904e-16
# std      3.003135e-15
# min     -4.236195e-15
# 25%     -2.803313e-15
# 50%     -5.551115e-17
# 75%      2.886580e-15
# max      4.489464e-15
# dtype: float64
# count    1.500000e+02
# mean    -2.849572e-16
# std      2.806044e-15
# min     -3.552714e-15
# 25%     -3.441691e-15
# 50%      0.000000e+00
# 75%      3.302913e-15
# max      3.441691e-15
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.000000
# mean      -0.020000
# std        0.140469
# min       -1.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.000000
# dtype: float64
# count    150.000000
# mean       0.020000
# std        0.140469
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
# count    150.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# dtype: float64
