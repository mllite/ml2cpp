# %% [markdown]
# # ML2CPP

# %% [markdown]
# ## Preparing the dataset

# %%
from sklearn import datasets
import numpy as np
import pandas as pd

boston = datasets.load_boston()

def populate_table(tablename, feature_names):
    X = boston.data  
    y = boston.target
    N = X.shape[0]
    y = y.reshape(N,1)
    k = np.arange(N).reshape(N, 1)
    k_X_y = np.concatenate((k, X, y) , axis=1)
    lTable=pd.DataFrame(k_X_y)
    # print(lTable.head())
    lTable.columns = ['idx'] + feature_names + ['TGT'];
    lTable['TGT'] = lTable['TGT'].apply(int)
    lTable['idx'] = lTable['idx'].apply(int)
    lTable.to_csv(tablename , float_format='%.14g')

# %%
metadata = {"primary_key" : "KEY",
            "features" : list(boston.feature_names),
            "targets" : ["TGT"],
            "table" : "iris"}

# %%
populate_table("/tmp/boston.csv" , metadata["features"])

# %%
df = pd.read_csv("/tmp/boston.csv")
df.sample(12, random_state=1960)
# Out:
#      Unnamed: 0  idx      CRIM    ZN  INDUS  CHAS    NOX     RM    AGE  \
# 230         230  230   0.53700   0.0   6.20     0  0.504  5.981   68.1
# 112         112  112   0.12329   0.0  10.01     0  0.547  5.913   92.9
# 125         125  125   0.16902   0.0  25.65     0  0.581  5.986   88.4
# 9             9    9   0.17004  12.5   7.87     0  0.524  6.004   85.9
# 213         213  213   0.14052   0.0  10.59     0  0.489  6.375   32.3
# 109         109  109   0.26363   0.0   8.56     0  0.520  6.229   91.2
# 127         127  127   0.25915   0.0  21.89     0  0.624  5.693   96.0
# 244         244  244   0.20608  22.0   5.86     0  0.431  5.593   76.5
# 406         406  406  20.71620   0.0  18.10     0  0.659  4.138  100.0
# 490         490  490   0.20746   0.0  27.74     0  0.609  5.093   98.0
# 245         245  245   0.19133  22.0   5.86     0  0.431  5.605   70.2
# 133         133  133   0.32982   0.0  21.89     0  0.624  5.822   95.4
#
#         DIS  RAD  TAX  PTRATIO       B  LSTAT  TGT
# 230  3.6715    8  307     17.4  378.35  11.65   24
# 112  2.3534    6  432     17.8  394.95  16.21   18
# 125  1.9929    2  188     19.1  385.02  14.81   21
# 9    6.5921    5  311     15.2  386.71  17.10   18
# 213  3.9454    4  277     18.6  385.81   9.38   28
# 109  2.5451    5  384     20.9  391.23  15.55   19
# 127  1.7883    4  437     21.2  392.11  17.19   16
# 244  7.9549    7  330     19.1  372.49  12.50   17
# 406  1.1781   24  666     20.2  370.22  23.34   11
# 490  1.8226    4  711     20.1  318.43  29.68    8
# 245  7.9549    7  330     19.1  389.13  18.46   18
# 133  2.4699    4  437     21.2  388.69  15.03   18

# %% [markdown]
# ## Training a Model

# %%
# train any scikit model on the iris dataset
from sklearn.neural_network import MLPRegressor
clf = MLPRegressor()
clf.fit(df[metadata['features']].values, df[metadata['targets']].values)
# Out:
# /home/antoine/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /home/antoine/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor()

# %% [markdown]
# ## Deploying the Model

# %%
def generate_cpp_for_model(model):
    import pickle, json, requests, base64
    b64_data = base64.b64encode(pickle.dumps(model)).decode('utf-8')
    # send the model th the web service
    json_data={"Name":"model_cpp_sample", 
               "PickleData":b64_data , 
               "SQLDialect":"CPP",
               "FeatureNames" : metadata['features']}
    r = requests.post("https://sklearn2sql.herokuapp.com/model", json=json_data)
    content = r.json()
    lCPP = content["model"]["SQLGenrationResult"][0]["SQL"]
    # print(lCPP);
    return lCPP


lCPPCode = generate_cpp_for_model(clf);

# %%
print(lCPPCode)
# Out:
# namespace  {
#
# 	namespace InputLayer {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "input_0", "input_1", "input_2", "input_3", "input_4", "input_5", "input_6", "input_7", "input_8", "input_9", "input_10", "input_11", "input_12" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
#
# 			tTable lTable;
#
# 			lTable["input_0"] = { Feature_0 };
# 			lTable["input_1"] = { Feature_1 };
# 			lTable["input_2"] = { Feature_2 };
# 			lTable["input_3"] = { Feature_3 };
# 			lTable["input_4"] = { Feature_4 };
# 			lTable["input_5"] = { Feature_5 };
# 			lTable["input_6"] = { Feature_6 };
# 			lTable["input_7"] = { Feature_7 };
# 			lTable["input_8"] = { Feature_8 };
# 			lTable["input_9"] = { Feature_9 };
# 			lTable["input_10"] = { Feature_10 };
# 			lTable["input_11"] = { Feature_11 };
# 			lTable["input_12"] = { Feature_12 };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace InputLayer
#
#
# 	namespace HiddenLayer_1 {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "input_0", "input_1", "input_2", "input_3", "input_4", "input_5", "input_6", "input_7", "input_8", "input_9", "input_10", "input_11", "input_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "output_1_0", "output_1_1", "output_1_2", "output_1_3", "output_1_4", "output_1_5", "output_1_6", "output_1_7", "output_1_8", "output_1_9", "output_1_10", "output_1_11", "output_1_12", "output_1_13", "output_1_14", "output_1_15", "output_1_16", "output_1_17", "output_1_18", "output_1_19", "output_1_20", "output_1_21", "output_1_22", "output_1_23", "output_1_24", "output_1_25", "output_1_26", "output_1_27", "output_1_28", "output_1_29", "output_1_30", "output_1_31", "output_1_32", "output_1_33", "output_1_34", "output_1_35", "output_1_36", "output_1_37", "output_1_38", "output_1_39", "output_1_40", "output_1_41", "output_1_42", "output_1_43", "output_1_44", "output_1_45", "output_1_46", "output_1_47", "output_1_48", "output_1_49", "output_1_50", "output_1_51", "output_1_52", "output_1_53", "output_1_54", "output_1_55", "output_1_56", "output_1_57", "output_1_58", "output_1_59", "output_1_60", "output_1_61", "output_1_62", "output_1_63", "output_1_64", "output_1_65", "output_1_66", "output_1_67", "output_1_68", "output_1_69", "output_1_70", "output_1_71", "output_1_72", "output_1_73", "output_1_74", "output_1_75", "output_1_76", "output_1_77", "output_1_78", "output_1_79", "output_1_80", "output_1_81", "output_1_82", "output_1_83", "output_1_84", "output_1_85", "output_1_86", "output_1_87", "output_1_88", "output_1_89", "output_1_90", "output_1_91", "output_1_92", "output_1_93", "output_1_94", "output_1_95", "output_1_96", "output_1_97", "output_1_98", "output_1_99" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any input_0, std::any input_1, std::any input_2, std::any input_3, std::any input_4, std::any input_5, std::any input_6, std::any input_7, std::any input_8, std::any input_9, std::any input_10, std::any input_11, std::any input_12) {
#
# 			tTable lTable;
#
# 			double output_1_0_BA = -0.032987100022231326 * input_0 + 0.11024371560804495 * input_1 + 0.02450101166316219 * input_2 + -0.5528828030193484 * input_3 + -0.02400577497288832 * input_4 + -0.2421414549493817 * input_5 + 0.19799462798442696 * input_6 + -0.1317007093210323 * input_7 + 0.04976172963304075 * input_8 + -0.019517935233474486 * input_9 + 0.11292589004117452 * input_10 + 0.03552135932881894 * input_11 + 0.12963492380886973 * input_12 + -0.08708956255264155;
#
# 			double output_1_1_BA = -0.02192827539127603 * input_0 + 0.02912489940391856 * input_1 + -0.12994978126165946 * input_2 + -0.242942153401354 * input_3 + 0.18466668969077848 * input_4 + -0.15588918362026938 * input_5 + 0.05232128547120777 * input_6 + 0.01564696549481502 * input_7 + 0.02475175301344839 * input_8 + -0.09412588967562042 * input_9 + -0.07783834644981585 * input_10 + 0.17589322786037948 * input_11 + 0.18364473399347359 * input_12 + 0.1738345862061468;
#
# 			double output_1_2_BA = -0.11983611999530103 * input_0 + 0.16941776731650493 * input_1 + 0.10428393151693979 * input_2 + 0.19644012532268798 * input_3 + 0.054734906437068215 * input_4 + 0.09735111854601496 * input_5 + -0.1323286461515054 * input_6 + 0.11004159527153445 * input_7 + 0.23597708183570845 * input_8 + 0.1865664239144823 * input_9 + -0.03444123669538488 * input_10 + 0.1065122051819724 * input_11 + -0.15548713859140903 * input_12 + 0.23598582393207262;
#
# 			double output_1_3_BA = -0.6197947218512518 * input_0 + 0.14791311147472683 * input_1 + 0.013779891453246547 * input_2 + -0.5282650274023077 * input_3 + 0.05153041676988859 * input_4 + -0.24708084701439897 * input_5 + 0.2549100970402695 * input_6 + 0.32274333801094907 * input_7 + -0.007467029175791093 * input_8 + -0.10869344762557243 * input_9 + 0.28888307358408244 * input_10 + 0.06258614273725918 * input_11 + 0.3529688231173521 * input_12 + -0.1023085839201634;
#
# 			double output_1_4_BA = -0.1502641410270467 * input_0 + -2.8451070068759074e-12 * input_1 + -0.12461267571382068 * input_2 + 0.003842772688442497 * input_3 + -0.004484459523188975 * input_4 + 0.1266395527210073 * input_5 + -0.14255934912588153 * input_6 + 0.21887750141730183 * input_7 + 0.16640825680927113 * input_8 + 0.029326920986157457 * input_9 + -0.05598347518443164 * input_10 + -0.16491712149987384 * input_11 + -0.10610975380500112 * input_12 + -0.18521260131561385;
#
# 			double output_1_5_BA = -0.015537363628877261 * input_0 + -0.035600374804853126 * input_1 + -0.17449795066498985 * input_2 + -0.07194096217056425 * input_3 + -0.2191281645500447 * input_4 + -0.20976260483610437 * input_5 + 0.12907151258227317 * input_6 + -0.09255794149392009 * input_7 + -0.13279991218306597 * input_8 + -0.12343597342118406 * input_9 + -0.0730766482021848 * input_10 + 0.06945796618406737 * input_11 + 0.1601865741334231 * input_12 + -0.204908243498664;
#
# 			double output_1_6_BA = 0.042936097246598415 * input_0 + -0.16773074681100053 * input_1 + -0.12381569328662342 * input_2 + -0.3954331212836432 * input_3 + -0.14149943874457102 * input_4 + 0.007111861102630183 * input_5 + 0.12643782141994503 * input_6 + 0.16523077637047767 * input_7 + 0.1050894031109673 * input_8 + 0.08126977529124291 * input_9 + 0.22462559256204065 * input_10 + 0.19817495231923896 * input_11 + -0.16081738805964402 * input_12 + -0.012454779959351691;
#
# 			double output_1_7_BA = 0.21488636850968582 * input_0 + 0.10229304729454557 * input_1 + -0.1357034896010288 * input_2 + -0.05547198309904542 * input_3 + -0.16844495987119937 * input_4 + -0.00941396698954307 * input_5 + 0.033862794113835123 * input_6 + 0.07828903635409153 * input_7 + -0.0022931625587715655 * input_8 + 0.0871806145275999 * input_9 + -0.16280266608446764 * input_10 + -0.1117211324900237 * input_11 + 0.23012398938921325 * input_12 + 0.03922183683146549;
#
# 			double output_1_8_BA = 0.047899241731330686 * input_0 + 0.10418169920049127 * input_1 + 0.04587884559665123 * input_2 + 0.6108420531393003 * input_3 + 0.10641970554550687 * input_4 + 0.4284240465990527 * input_5 + 0.1209808023694702 * input_6 + -0.494459270029786 * input_7 + 0.03626658279383077 * input_8 + -0.007372728319901517 * input_9 + -0.19714109318290132 * input_10 + 0.01338095467492713 * input_11 + -0.6986673862044936 * input_12 + 0.01297455351543825;
#
# 			double output_1_9_BA = -0.024378376459396583 * input_0 + 0.20365808227085885 * input_1 + -0.17991926978200365 * input_2 + 0.07476245965975527 * input_3 + -0.16577471303749786 * input_4 + 0.05769350882776761 * input_5 + 0.15903082661667078 * input_6 + -0.1747430587777718 * input_7 + 0.1609290032738874 * input_8 + 0.016097303094740282 * input_9 + 0.07203994276437012 * input_10 + 0.07251088162615932 * input_11 + -0.07219881690102369 * input_12 + -0.03137089200446388;
#
# 			double output_1_10_BA = -0.03245756505488429 * input_0 + -0.03276503244272456 * input_1 + -0.10213490009362067 * input_2 + -0.09145240420186357 * input_3 + 0.17758063080604128 * input_4 + -0.12136358606404012 * input_5 + -0.152626160469492 * input_6 + 0.01899512050682712 * input_7 + 0.13782607438750855 * input_8 + 0.1395771776339686 * input_9 + 0.18508530568184905 * input_10 + -0.054087951293239525 * input_11 + 0.2325148713767352 * input_12 + -0.16939254891024821;
#
# 			double output_1_11_BA = -0.17955048654413827 * input_0 + -0.09657745270000213 * input_1 + -0.018235334312849773 * input_2 + 0.27711201859492535 * input_3 + -0.04022365898733396 * input_4 + -0.21304213157259888 * input_5 + 0.01510088760424292 * input_6 + 0.19937410557156243 * input_7 + -0.1485403330205147 * input_8 + 0.14319312383136037 * input_9 + 0.06708235351368651 * input_10 + -0.16754769057315727 * input_11 + -0.08389598145257689 * input_12 + 0.054968708031629974;
#
# 			double output_1_12_BA = -0.12318913657342044 * input_0 + -0.0370157835306004 * input_1 + 0.11114328345761798 * input_2 + 0.2480773580622739 * input_3 + -0.06286135552702976 * input_4 + -0.13244315430670964 * input_5 + -0.12449954860530414 * input_6 + 0.07292315925560575 * input_7 + 0.23568540994238263 * input_8 + 0.20278208050735422 * input_9 + -0.011416239792470695 * input_10 + -0.04502233849992818 * input_11 + -0.12300120086871906 * input_12 + -0.16561176847943299;
#
# 			double output_1_13_BA = 0.20118701054707855 * input_0 + -0.0638978689078117 * input_1 + 0.07622631354921375 * input_2 + -0.33614612862202725 * input_3 + 0.146320882124857 * input_4 + 0.03191163801020497 * input_5 + 0.17645075301469376 * input_6 + -0.08959578835850944 * input_7 + -0.02468845816024505 * input_8 + -0.01115123091138138 * input_9 + -0.1689263501874762 * input_10 + 0.013496038312587088 * input_11 + 0.07657695118566231 * input_12 + -0.07444563469415222;
#
# 			double output_1_14_BA = -0.051599243309152075 * input_0 + -0.11596441284990312 * input_1 + 0.08616084088329491 * input_2 + -0.2525373233126484 * input_3 + -0.13891537135861098 * input_4 + -0.010359476395405732 * input_5 + 0.0009928323869016229 * input_6 + -0.17056034389234778 * input_7 + -0.13318175242154742 * input_8 + 0.21893382292629648 * input_9 + 0.12690636062821598 * input_10 + 0.05084738315234279 * input_11 + 0.0853483554713426 * input_12 + 0.16837847440355375;
#
# 			double output_1_15_BA = -0.1444164911697319 * input_0 + -0.11352557239933915 * input_1 + 0.00027710220019229833 * input_2 + -0.34417964255661826 * input_3 + -0.22578666664281788 * input_4 + -0.18543713127855307 * input_5 + 0.2334938359931499 * input_6 + 0.26226456120142894 * input_7 + -0.16537649405135454 * input_8 + 0.06426626173460694 * input_9 + -0.04706235353254222 * input_10 + 0.08580857413410296 * input_11 + 0.13450099915403416 * input_12 + 0.004750422692688658;
#
# 			double output_1_16_BA = -0.1933968648465499 * input_0 + 2.416610617950593e-11 * input_1 + -0.1757484315156135 * input_2 + 0.45497464654633846 * input_3 + 0.13241377252462216 * input_4 + 0.014799125009900532 * input_5 + -0.024779830531280498 * input_6 + -0.022685248146950776 * input_7 + -0.05353246845479454 * input_8 + 0.14699644801306216 * input_9 + -0.19906984791936289 * input_10 + -0.2009145244260654 * input_11 + -0.21838462927546368 * input_12 + 0.054911779561313656;
#
# 			double output_1_17_BA = 0.04128909582382473 * input_0 + -2.710748655400873e-15 * input_1 + 0.10089647476706211 * input_2 + 0.08774025782306985 * input_3 + 0.10746902883892191 * input_4 + -0.12037915998104591 * input_5 + -0.1473015052606453 * input_6 + -0.09092143282573895 * input_7 + -0.12320764207653284 * input_8 + 0.11635817455778363 * input_9 + -0.21088156800903476 * input_10 + -0.16843520743534496 * input_11 + -0.07985049201746801 * input_12 + -0.06298222108331737;
#
# 			double output_1_18_BA = 0.04463154562960399 * input_0 + -0.09229402939300879 * input_1 + 0.4082477096126016 * input_2 + -0.3106865986277795 * input_3 + 0.00300541082044251 * input_4 + -0.3803498340717415 * input_5 + 0.025865556953350126 * input_6 + 0.33230543061958734 * input_7 + -0.16632401184340267 * input_8 + -0.12792405753160493 * input_9 + 0.35144762064395985 * input_10 + 0.08490679024607622 * input_11 + 0.14678127894721635 * input_12 + -0.15851147665475537;
#
# 			double output_1_19_BA = -0.1565699117894382 * input_0 + -0.019370408752704682 * input_1 + 0.1364649415320933 * input_2 + 0.4431553606166744 * input_3 + -0.21498182527667578 * input_4 + 0.2124325377615473 * input_5 + 0.12534240670657792 * input_6 + 0.08718427451035884 * input_7 + 0.21143327357758757 * input_8 + -0.034063741247706364 * input_9 + 0.0886975243603214 * input_10 + 0.18906767773261782 * input_11 + 0.05269995839527076 * input_12 + -0.03997044329005282;
#
# 			double output_1_20_BA = 2.9759079496271295e-05 * input_0 + -0.001504969781829736 * input_1 + -1.788040709223697e-05 * input_2 + -3.496138221974526e-06 * input_3 + -2.367332027790224e-12 * input_4 + 6.2873773464377e-07 * input_5 + 1.2907069045819797e-05 * input_6 + -0.003189662036186227 * input_7 + 5.430988457980194e-13 * input_8 + -0.002760926511169752 * input_9 + 0.005112004055584509 * input_10 + -1.935353241982556e-08 * input_11 + -2.3547912326953434e-07 * input_12 + -0.07821246293798687;
#
# 			double output_1_21_BA = 0.00780171713734506 * input_0 + 0.006980063436041042 * input_1 + 0.010092547195642032 * input_2 + 0.018276041068443192 * input_3 + 0.012610673043972984 * input_4 + 0.01329846784308678 * input_5 + 0.008360061326378065 * input_6 + 0.00771300089725276 * input_7 + 0.010051167532155686 * input_8 + 0.009511049668209027 * input_9 + 0.009064129106138684 * input_10 + 0.008350899315798663 * input_11 + 0.008122741292596413 * input_12 + 0.07365159718423354;
#
# 			double output_1_22_BA = 0.10741462179591493 * input_0 + -0.13203149082593124 * input_1 + 0.11238111389188343 * input_2 + -0.452429059146205 * input_3 + -0.07979375567383097 * input_4 + -0.17699283117011272 * input_5 + 0.032189442215805136 * input_6 + 0.08982516374911331 * input_7 + -0.17451005472192277 * input_8 + 0.12468799583246436 * input_9 + 0.06941042257482227 * input_10 + 0.11798718815602578 * input_11 + -0.11493058126269041 * input_12 + -0.0991666070904488;
#
# 			double output_1_23_BA = -0.07157938022942197 * input_0 + 0.09834218677559278 * input_1 + -0.14573528130577146 * input_2 + -0.1430594293251749 * input_3 + 0.011351085307978515 * input_4 + 0.012255691840039802 * input_5 + 0.03679292993025621 * input_6 + 0.028309798995631158 * input_7 + 0.030803726172964115 * input_8 + 0.17612635759666048 * input_9 + 0.2230090485481295 * input_10 + -0.2141011651249553 * input_11 + 0.1444841231245921 * input_12 + -0.10956705200084518;
#
# 			double output_1_24_BA = -0.1675630227207416 * input_0 + 0.10282084675103444 * input_1 + 0.05640534538164573 * input_2 + -0.4486508548357422 * input_3 + 0.14489910802544675 * input_4 + 0.02592596529120244 * input_5 + -0.043192753931823535 * input_6 + 0.14615083684146632 * input_7 + 0.07508466325308837 * input_8 + 0.09411528059501913 * input_9 + 0.18246282808864575 * input_10 + 0.0028107175584162545 * input_11 + -0.034323138210870505 * input_12 + 0.18250357470539352;
#
# 			double output_1_25_BA = -0.020875956570347496 * input_0 + 0.07879106100133772 * input_1 + -0.1652348547867604 * input_2 + 0.2265384456739619 * input_3 + 0.11581960275465589 * input_4 + -0.11479981878330972 * input_5 + 0.10641931696222291 * input_6 + 0.11532043213532303 * input_7 + -0.20873710986133476 * input_8 + 0.2094016410839904 * input_9 + -0.07631409774438526 * input_10 + -0.0877155540560865 * input_11 + -0.12902711070125317 * input_12 + -0.05688948698009155;
#
# 			double output_1_26_BA = 0.0009761723989501027 * input_0 + -0.06797831755261355 * input_1 + 0.07789274358942708 * input_2 + 0.6565518669960342 * input_3 + -0.01408004690378208 * input_4 + 0.37547380322609186 * input_5 + -0.1339251533112531 * input_6 + -0.37708974491994623 * input_7 + 0.1540696717907936 * input_8 + 0.011324311791357754 * input_9 + -0.07103275925271668 * input_10 + 0.034282056234578286 * input_11 + -0.6288495420620519 * input_12 + -0.03880128470835656;
#
# 			double output_1_27_BA = -0.06420575653802392 * input_0 + 0.142952301598197 * input_1 + 0.1487108489926762 * input_2 + -0.24128300958316146 * input_3 + 0.060218611714114856 * input_4 + -0.14771744043779828 * input_5 + 0.21162213157748813 * input_6 + -0.05940317503664211 * input_7 + 0.1935097014398819 * input_8 + 0.15963153801879906 * input_9 + 0.016424880216063004 * input_10 + -0.19797515456461467 * input_11 + -0.17677493735788916 * input_12 + 0.1998375974940548;
#
# 			double output_1_28_BA = -0.012907437055346886 * input_0 + -0.06148025308454529 * input_1 + 0.13948269932952015 * input_2 + 0.2142041582462883 * input_3 + -0.031081703026782648 * input_4 + -0.08834424902830244 * input_5 + -0.10046948388191256 * input_6 + 0.1456717011415373 * input_7 + 0.1549538377715908 * input_8 + 0.11357320672937116 * input_9 + 0.1508932781328203 * input_10 + 0.22755703314213407 * input_11 + -0.032332125252374194 * input_12 + -0.07581003541943643;
#
# 			double output_1_29_BA = 0.09655202104005216 * input_0 + 0.16723660289683934 * input_1 + 0.0909210668786567 * input_2 + -0.06382541560608426 * input_3 + -0.10654849804780854 * input_4 + -0.06331792624392572 * input_5 + 0.02876090354306121 * input_6 + 0.2573666883240309 * input_7 + -0.15043492957057075 * input_8 + 0.08684064426981314 * input_9 + 0.005290525908814944 * input_10 + -0.01021891511168956 * input_11 + 0.07381080066000345 * input_12 + 0.01458153298895422;
#
# 			double output_1_30_BA = -0.010783502206281756 * input_0 + -0.2777617749395644 * input_1 + -0.036818187963850245 * input_2 + -0.04211727285598751 * input_3 + -0.19401714694739908 * input_4 + -0.26209937039773257 * input_5 + 0.2199692469994729 * input_6 + -0.12312267414673675 * input_7 + -0.15435577214909085 * input_8 + 0.11613859998152554 * input_9 + -0.06764858396394338 * input_10 + -0.09249923536650144 * input_11 + -0.09934960751095603 * input_12 + -0.1836888778138709;
#
# 			double output_1_31_BA = 0.08567879419174747 * input_0 + 0.016438047461814004 * input_1 + 0.2034078271681248 * input_2 + 0.4600710508534809 * input_3 + -0.054856908014546873 * input_4 + 0.15202828869575805 * input_5 + 0.1761946209263411 * input_6 + -0.18895896224829037 * input_7 + -0.0294863491844569 * input_8 + -0.0077972551332591246 * input_9 + 0.04137467810109956 * input_10 + -0.020224173834551273 * input_11 + -0.5532373001881712 * input_12 + -0.12248302594014024;
#
# 			double output_1_32_BA = 0.21170912850637416 * input_0 + -0.21552056822064342 * input_1 + -0.20023342293884563 * input_2 + -0.21936707801911304 * input_3 + 0.05084658676641174 * input_4 + -0.08865725171376213 * input_5 + -0.05365744787188799 * input_6 + -0.12606509614091202 * input_7 + 0.09519109109307032 * input_8 + 0.20397595736349208 * input_9 + 0.0974891782296675 * input_10 + -0.16278022170014983 * input_11 + 0.026489838133086918 * input_12 + 0.16896663441020698;
#
# 			double output_1_33_BA = -0.11481277188415674 * input_0 + 0.19865941402955328 * input_1 + 0.08150327892544021 * input_2 + -0.3517479789735156 * input_3 + 0.1272613506847862 * input_4 + -0.03655946230909096 * input_5 + -0.1454013431458109 * input_6 + 0.16181197852166151 * input_7 + 0.157800865377512 * input_8 + 0.20497914286467522 * input_9 + -0.2170256462706962 * input_10 + -0.07182787455190971 * input_11 + 0.14201306231083452 * input_12 + -0.11572024974116196;
#
# 			double output_1_34_BA = -7.018713342714106e-11 * input_0 + 6.937816073880232e-11 * input_1 + -0.003629978706525876 * input_2 + -0.0006349164134191739 * input_3 + 0.0003755300943334966 * input_4 + -2.658996971166242e-12 * input_5 + -1.2678541550920888e-06 * input_6 + 0.0019100762840530978 * input_7 + 0.000886797036568626 * input_8 + -0.00433749939992148 * input_9 + -3.1786532809693694e-11 * input_10 + 1.69839380669168e-05 * input_11 + -0.0052397361254809365 * input_12 + 0.06658177245431202;
#
# 			double output_1_35_BA = -0.06043329192562658 * input_0 + -0.10484858727639787 * input_1 + -0.11676015609413898 * input_2 + 0.03742949409294739 * input_3 + -0.03134552301976309 * input_4 + 0.11500207970525854 * input_5 + -0.13523309857456325 * input_6 + -0.041704538287260715 * input_7 + -0.2251584475053263 * input_8 + 0.2107018792903664 * input_9 + 0.1052218870252739 * input_10 + -0.18611882027953636 * input_11 + -0.04779321721315073 * input_12 + -0.011000831888397894;
#
# 			double output_1_36_BA = -0.005079217922091725 * input_0 + 0.0006975062998907447 * input_1 + 0.00012282478778638216 * input_2 + 0.0003468612079004298 * input_3 + -1.7026945442156277e-14 * input_4 + 0.00017306748418308555 * input_5 + -0.0016178445701913787 * input_6 + -0.0020962401814507664 * input_7 + -2.702871827799457e-05 * input_8 + -1.1516943014132611e-09 * input_9 + 0.001377575617577485 * input_10 + -0.0068102603345507945 * input_11 + -0.005087944388657483 * input_12 + -0.20726380759504667;
#
# 			double output_1_37_BA = 0.07981310827259543 * input_0 + 0.032340588749919894 * input_1 + -0.11214113197891727 * input_2 + -0.13338408393310647 * input_3 + 0.1332330544476064 * input_4 + -0.2125742113836437 * input_5 + -0.06643544716294245 * input_6 + 0.19528672657007845 * input_7 + -0.0032276215665378856 * input_8 + -0.16040760216647984 * input_9 + -0.051869487521182124 * input_10 + 0.19401152296477822 * input_11 + -0.13524701355481714 * input_12 + 0.06262406226504189;
#
# 			double output_1_38_BA = 4.5901811668086354e-06 * input_0 + -0.00036183134339865696 * input_1 + 9.028616562246272e-15 * input_2 + 3.607590659067578e-07 * input_3 + -0.0003499399433367418 * input_4 + 2.413765180743292e-06 * input_5 + 9.787955111421691e-11 * input_6 + -9.042747309709e-05 * input_7 + 0.00298197077222058 * input_8 + -0.0022192822016219626 * input_9 + 5.989320896601591e-06 * input_10 + -0.0002387447193042689 * input_11 + -9.041708297963677e-09 * input_12 + 0.18815114481336087;
#
# 			double output_1_39_BA = -0.10196200044389858 * input_0 + 0.028033251422030663 * input_1 + -0.09112746899458027 * input_2 + -0.2513827443718583 * input_3 + 0.21585339270504095 * input_4 + -0.2525367119604981 * input_5 + 0.12116254231989948 * input_6 + 0.22759539958705421 * input_7 + -0.12642861023858454 * input_8 + 0.1414267122490848 * input_9 + -0.12407092536294113 * input_10 + -0.07492377285129158 * input_11 + -0.07934086132868373 * input_12 + 0.14666437535352847;
#
# 			double output_1_40_BA = -0.10780438034528972 * input_0 + 0.07285489570028775 * input_1 + -0.17055023663283123 * input_2 + 0.3508936443895757 * input_3 + 0.0006198844000691766 * input_4 + 0.21608581192932788 * input_5 + 0.17081435502344844 * input_6 + 0.07254041198866457 * input_7 + -0.19977462807009508 * input_8 + 0.21381950674283465 * input_9 + 0.0972081593407614 * input_10 + -0.22700447286043818 * input_11 + -0.024150293362256162 * input_12 + -0.07073472825840389;
#
# 			double output_1_41_BA = -0.08963862478122597 * input_0 + -0.21122529224023628 * input_1 + -0.10715908324972119 * input_2 + 0.06359503722768033 * input_3 + 0.09988574378944315 * input_4 + 0.14968869800442597 * input_5 + -0.028467176876280444 * input_6 + 0.025341086580634622 * input_7 + 0.18004864335582868 * input_8 + 0.02337922538117641 * input_9 + 0.16093241122737298 * input_10 + -0.012420351685028214 * input_11 + -0.10952567656957247 * input_12 + -0.14993526603339682;
#
# 			double output_1_42_BA = -3.0251668510699506e-11 * input_0 + -4.1821811204984274e-05 * input_1 + 0.0004639552518013738 * input_2 + -0.0017078503456281714 * input_3 + 5.90583436502404e-15 * input_4 + 1.132686601742673e-12 * input_5 + 2.0598695344564037e-05 * input_6 + -0.00017985697392113503 * input_7 + 1.7889005311576346e-06 * input_8 + -0.0021008351572164474 * input_9 + -1.5897926966910868e-06 * input_10 + -6.669500953650117e-08 * input_11 + 0.001679564255818333 * input_12 + -0.09436962923776379;
#
# 			double output_1_43_BA = -0.07690510321965811 * input_0 + 0.08715612061952638 * input_1 + 0.04827815204209512 * input_2 + 0.35354525337573717 * input_3 + -0.11084614146295162 * input_4 + 0.06124689257747922 * input_5 + -0.07010886327344483 * input_6 + -0.13508259122109778 * input_7 + 0.0890442321341006 * input_8 + 0.07616394289183653 * input_9 + -0.20989196687486933 * input_10 + -0.02188672872668097 * input_11 + -0.33358230380230497 * input_12 + -0.20984329435049787;
#
# 			double output_1_44_BA = 0.12072570438157881 * input_0 + -0.1813183962816615 * input_1 + 0.03224568591484517 * input_2 + -0.3485358278690521 * input_3 + 0.04994564020376838 * input_4 + -0.23547663375628636 * input_5 + -0.17398274249789866 * input_6 + 0.02371959378211989 * input_7 + 0.08767807004326732 * input_8 + 0.1728784991915065 * input_9 + -0.16741428987794643 * input_10 + 0.008887449299417219 * input_11 + 0.16467321088684336 * input_12 + 0.06073861205587784;
#
# 			double output_1_45_BA = 0.038264523502868644 * input_0 + -3.7476064981045994e-05 * input_1 + -0.013425674752320559 * input_2 + 0.00019626462324364848 * input_3 + -0.060567839423339445 * input_4 + -0.06824167426505298 * input_5 + 0.007369044268279203 * input_6 + -0.03764538367210164 * input_7 + -0.020929135443607447 * input_8 + -0.02553045892396041 * input_9 + 0.040010749581880126 * input_10 + -0.014885219345524735 * input_11 + -0.025824685585651465 * input_12 + 0.16236643804593318;
#
# 			double output_1_46_BA = -0.1626922290295602 * input_0 + -0.011959143056728674 * input_1 + 0.10571059268991806 * input_2 + 0.051060057555527734 * input_3 + -0.05080603520444869 * input_4 + -0.047773193870129516 * input_5 + -0.08677884309510278 * input_6 + 0.10368406766316449 * input_7 + -0.0035840779378521967 * input_8 + 0.13136953230970666 * input_9 + -0.20382928079532092 * input_10 + 0.2078434284616774 * input_11 + 0.028417688091186014 * input_12 + 0.0801886568142026;
#
# 			double output_1_47_BA = -0.0005482821299409647 * input_0 + -2.8731391023963428e-11 * input_1 + 6.581750913746455e-07 * input_2 + -2.0991618111873035e-05 * input_3 + -7.681967298942791e-06 * input_4 + 1.95558820835794e-10 * input_5 + 2.9565486910425898e-05 * input_6 + 0.0003318600525454277 * input_7 + -2.105249176756611e-09 * input_8 + -0.0025208451095928568 * input_9 + -0.003784993504891483 * input_10 + 2.3178004601638657e-08 * input_11 + 8.154527904948329e-12 * input_12 + 0.21218283544152328;
#
# 			double output_1_48_BA = -0.1884538218673821 * input_0 + 0.10387846366975531 * input_1 + 0.011414629047274968 * input_2 + -0.42778192754137506 * input_3 + 0.21483174315268616 * input_4 + -0.0792009945587532 * input_5 + 0.13935214692220504 * input_6 + 0.0014647402047464951 * input_7 + 0.016441880757394573 * input_8 + 0.09924347616104931 * input_9 + 0.042674308712216474 * input_10 + -0.137889004199121 * input_11 + 0.2670768053761589 * input_12 + -0.12326884728749798;
#
# 			double output_1_49_BA = -0.02890670025634885 * input_0 + 0.10168005276640109 * input_1 + -0.05474333097886361 * input_2 + 0.07329707902976844 * input_3 + -0.09350294553860157 * input_4 + 0.09433143705555341 * input_5 + 0.0874677466262543 * input_6 + -0.21830316388804374 * input_7 + 0.10572733214206884 * input_8 + 0.024676322185909094 * input_9 + 0.09933854177767001 * input_10 + 0.0699216549088804 * input_11 + -0.22102522812282235 * input_12 + -0.017378229695880324;
#
# 			double output_1_50_BA = 0.1115966332074698 * input_0 + -0.00039517519322065367 * input_1 + 0.06521948705672077 * input_2 + -0.06593786194800726 * input_3 + 0.017657421072978713 * input_4 + -0.08168178941555469 * input_5 + -0.016690465258769625 * input_6 + 0.07864050735340516 * input_7 + -0.06774346489887421 * input_8 + 0.18025902781626235 * input_9 + -0.08831193868608857 * input_10 + -0.21850443346803528 * input_11 + 0.12509663625204745 * input_12 + -0.17948579514340043;
#
# 			double output_1_51_BA = 0.16003993362279076 * input_0 + 0.04812441958253369 * input_1 + 0.10182537320473035 * input_2 + 0.06410926866555158 * input_3 + -0.003563721233285731 * input_4 + 0.0036376752150243078 * input_5 + 0.20201043321521486 * input_6 + -0.033465466124679155 * input_7 + -0.11210830997293617 * input_8 + 0.027926468742745854 * input_9 + 0.16666653619567587 * input_10 + 0.2143380578850387 * input_11 + -0.04104646306603289 * input_12 + 0.21587036407782575;
#
# 			double output_1_52_BA = -0.15439220261545286 * input_0 + 0.019149893179489886 * input_1 + -0.06366792089898035 * input_2 + 0.38098135193980337 * input_3 + -0.09048455543780902 * input_4 + 0.08334413804600826 * input_5 + 0.015607123449851124 * input_6 + -0.15047393771561668 * input_7 + -0.19833043783539367 * input_8 + -0.0435381059267448 * input_9 + 0.07819891927475238 * input_10 + 0.1339079218788851 * input_11 + 0.06774247989097852 * input_12 + 0.12688339966343076;
#
# 			double output_1_53_BA = -0.0324221726370131 * input_0 + -0.09620109008519209 * input_1 + -0.01722940324693607 * input_2 + 0.297934870351535 * input_3 + -0.02638611534154234 * input_4 + 0.152576711074128 * input_5 + -0.020181549177307277 * input_6 + 0.13185426256387323 * input_7 + 0.02312998873881732 * input_8 + 0.17646493773741892 * input_9 + 0.1927927753962685 * input_10 + -0.07240077260663891 * input_11 + 0.06292788780555915 * input_12 + 0.16290368141267625;
#
# 			double output_1_54_BA = -0.1472374474004933 * input_0 + -0.00012230992199070955 * input_1 + -0.15241897738500618 * input_2 + -0.0020526542232922225 * input_3 + -0.05044192931071032 * input_4 + 0.07105297372662293 * input_5 + -0.06144424231533419 * input_6 + 0.24971668791734916 * input_7 + 0.22640836655517804 * input_8 + 0.04763455863576617 * input_9 + 0.14351428195149343 * input_10 + -0.17183590139534888 * input_11 + -0.23780187753044976 * input_12 + 0.24462622280778226;
#
# 			double output_1_55_BA = -0.003654499757362762 * input_0 + -0.0005171465784248552 * input_1 + 0.0012917737630666495 * input_2 + -1.3710307852150497e-16 * input_3 + 0.005303008819035134 * input_4 + 1.9012826543949615e-07 * input_5 + -5.4186573798431e-09 * input_6 + 9.146749412790805e-09 * input_7 + 0.00012910713481909095 * input_8 + -0.0012176654106456916 * input_9 + 0.0004235157865740156 * input_10 + -1.2781623936409649e-09 * input_11 + 0.0016293423151597837 * input_12 + -0.19931623437604867;
#
# 			double output_1_56_BA = -1.6987544985301135e-07 * input_0 + 0.00044495792634987203 * input_1 + 0.0016135911427753754 * input_2 + 3.1025813765791853e-09 * input_3 + -0.004269527208250248 * input_4 + -1.1680054166335837e-12 * input_5 + 0.0037124646197251414 * input_6 + 0.0038371238042311418 * input_7 + 0.000877431558362246 * input_8 + -0.0012515228193845482 * input_9 + -0.0008505822524334661 * input_10 + -0.0028621009010289696 * input_11 + -5.4261135456228856e-05 * input_12 + 0.12253709188182277;
#
# 			double output_1_57_BA = 0.016210258445044 * input_0 + 0.002316654797319494 * input_1 + -0.012329388442458176 * input_2 + -1.5082084231390852e-08 * input_3 + -0.000731486550177669 * input_4 + -0.03885002262383812 * input_5 + 0.00909633241576451 * input_6 + 0.09912196916192746 * input_7 + 0.06600943138971245 * input_8 + -0.015113919429493814 * input_9 + 0.05411136983719515 * input_10 + -0.051569391005892834 * input_11 + -0.10953895539125823 * input_12 + 0.08317067633595125;
#
# 			double output_1_58_BA = -0.10749342733390867 * input_0 + 0.18014258970753427 * input_1 + 0.12420448580103317 * input_2 + 0.15499205490021165 * input_3 + -0.1819964853804262 * input_4 + 0.09549919147545718 * input_5 + -0.09075807606481222 * input_6 + 0.08496566422184672 * input_7 + -0.04777913681251906 * input_8 + 0.061898823179814016 * input_9 + 0.050080933075899774 * input_10 + -0.13650391607283133 * input_11 + 0.08855377414590389 * input_12 + -0.1382352672768083;
#
# 			double output_1_59_BA = 0.04697590120958948 * input_0 + -0.22505023026398124 * input_1 + 0.14842487256747564 * input_2 + -0.30455936419531454 * input_3 + 0.17169814101773828 * input_4 + -0.11428866151561909 * input_5 + -0.17871960782647262 * input_6 + 0.03583720336905329 * input_7 + -0.006209867359689125 * input_8 + -0.0420134992712674 * input_9 + 0.17761410080271273 * input_10 + 0.21149939916573018 * input_11 + -0.024921039053648904 * input_12 + -0.05768836634560463;
#
# 			double output_1_60_BA = -0.1855569327011012 * input_0 + -0.19924551848053826 * input_1 + -0.14342098642948659 * input_2 + -0.08213259008494918 * input_3 + 0.006600589570254439 * input_4 + -0.009518033379065314 * input_5 + 0.14348964688889512 * input_6 + -0.09287798116191785 * input_7 + 0.1294801116635218 * input_8 + 0.00025544219441742003 * input_9 + -0.22299609770704096 * input_10 + 0.027937855142891092 * input_11 + -0.12408597141132059 * input_12 + -0.13733812897182363;
#
# 			double output_1_61_BA = -0.0179062899889793 * input_0 + -0.0023844888875011916 * input_1 + 0.026091656752327816 * input_2 + 1.1147371450444448e-08 * input_3 + -0.027641476664276382 * input_4 + -0.06273198336643779 * input_5 + -0.006562634924493831 * input_6 + -0.01968132064248452 * input_7 + -0.015238888824929726 * input_8 + -0.020326831768032603 * input_9 + -0.013230652957020696 * input_10 + -0.019952567292812376 * input_11 + -0.03349154049382897 * input_12 + -0.00946966602091199;
#
# 			double output_1_62_BA = 0.04286088578126148 * input_0 + 0.19937191259615014 * input_1 + -0.046431112663426304 * input_2 + 0.2516405730935985 * input_3 + -0.1865376151183576 * input_4 + 0.05875389896807637 * input_5 + 0.14201996379086518 * input_6 + 0.17955999779797807 * input_7 + 0.0012368367822045575 * input_8 + 0.1301164559331986 * input_9 + -0.0666707140843205 * input_10 + -0.17317903839391577 * input_11 + -0.07570466520919047 * input_12 + 0.2235243212725593;
#
# 			double output_1_63_BA = 0.07385026882459539 * input_0 + -1.0272471383247568e-05 * input_1 + -0.0368250674867036 * input_2 + -0.03898855521411187 * input_3 + -0.05706389833712782 * input_4 + 0.19407512656431553 * input_5 + 0.00959439126101481 * input_6 + -0.058935429530374464 * input_7 + -0.06554595503110996 * input_8 + 0.041818750608322804 * input_9 + 0.17163388791845627 * input_10 + -0.10141413425484887 * input_11 + -0.19371846732003903 * input_12 + 0.04536517534102305;
#
# 			double output_1_64_BA = -0.21134144645119968 * input_0 + -0.21699879908569256 * input_1 + 0.20234065327238865 * input_2 + -0.05695765923342616 * input_3 + -0.07651310987908926 * input_4 + -0.016841057310757235 * input_5 + -0.030596980307841068 * input_6 + -0.07460030455965354 * input_7 + 0.04019235978305407 * input_8 + 0.14635238882088306 * input_9 + 0.07791348120854553 * input_10 + 0.03569470848471035 * input_11 + 0.1972899021663644 * input_12 + 0.003104294489381733;
#
# 			double output_1_65_BA = -0.15089531558055944 * input_0 + -0.16449238434261654 * input_1 + -0.12420429145756784 * input_2 + 0.30280013936142197 * input_3 + -0.04781326097276291 * input_4 + -0.06749931602660145 * input_5 + -0.2267237656540732 * input_6 + -0.01589131353310423 * input_7 + 0.09075538453553743 * input_8 + -0.029417049869820935 * input_9 + -0.06682650505845948 * input_10 + 0.11138408602889929 * input_11 + 0.02913841837515733 * input_12 + 0.169840806203174;
#
# 			double output_1_66_BA = 6.057918129766691e-09 * input_0 + 5.3526910265678814e-05 * input_1 + -0.0025031380268617886 * input_2 + -1.4065492578646393e-12 * input_3 + 0.0005082139712432113 * input_4 + 5.418855124964046e-06 * input_5 + 0.004300275442805731 * input_6 + -0.0033479775621683525 * input_7 + -1.998053748381683e-12 * input_8 + -0.0064130935031556984 * input_9 + 2.1866528044575077e-13 * input_10 + -8.926686452531536e-11 * input_11 + 2.2488534751304984e-11 * input_12 + 0.09389796770904518;
#
# 			double output_1_67_BA = 0.0006618082972971249 * input_0 + -0.08655192234788904 * input_1 + 0.024490330196991605 * input_2 + -0.16018843979981345 * input_3 + -0.15437735883291065 * input_4 + -0.15728479991387354 * input_5 + -0.07187634482907423 * input_6 + 0.14787288532936915 * input_7 + 0.14338152798722947 * input_8 + 0.2057850877358485 * input_9 + -0.13532972076744512 * input_10 + 0.01756837883375267 * input_11 + 0.221392285268526 * input_12 + 0.1944618352995148;
#
# 			double output_1_68_BA = -0.005815846799782199 * input_0 + 2.126576679857838e-11 * input_1 + -2.6005450006736294e-12 * input_2 + -0.003948374976986835 * input_3 + -1.3685985943333375e-05 * input_4 + 0.0009142145474042746 * input_5 + -1.0801418558114788e-05 * input_6 + 4.109391587323358e-14 * input_7 + -0.0018315704903040836 * input_8 + -1.866478649030649e-06 * input_9 + 2.0901281074715253e-10 * input_10 + -0.006027982083415897 * input_11 + 1.6120203841851964e-08 * input_12 + -0.2178275431690722;
#
# 			double output_1_69_BA = -0.07566111992781108 * input_0 + 0.03281658473994772 * input_1 + 0.07136794392544596 * input_2 + 0.11659458635153958 * input_3 + 0.1126056480748994 * input_4 + 0.09779693502607593 * input_5 + -0.09293538839438031 * input_6 + -0.15985014598594333 * input_7 + 0.08921085487018432 * input_8 + 0.23628804193963007 * input_9 + -0.10938217154273676 * input_10 + -0.1990027291753591 * input_11 + -0.03135086579967567 * input_12 + 0.1804862794606886;
#
# 			double output_1_70_BA = 0.3469472979475484 * input_0 + 0.0432309830153359 * input_1 + -0.03432355960647015 * input_2 + 0.32720147120221715 * input_3 + -0.18339834692263973 * input_4 + -0.06456227374261127 * input_5 + -0.04217901929173152 * input_6 + 0.1288386901031906 * input_7 + -0.04923019014547662 * input_8 + -0.15886853319034017 * input_9 + -0.13658806622597852 * input_10 + 0.1269544642592507 * input_11 + 0.011110659938145197 * input_12 + -0.043026193343508434;
#
# 			double output_1_71_BA = -0.050209684442960825 * input_0 + 0.03021965458401839 * input_1 + -0.20947494587990279 * input_2 + 0.05852971545147175 * input_3 + -0.18599247635128924 * input_4 + 0.08956572056930898 * input_5 + 0.028066633776071718 * input_6 + 0.0746410115553239 * input_7 + 0.22170756071287434 * input_8 + -0.09231845315125613 * input_9 + 0.14395384097172162 * input_10 + 0.18327941043734225 * input_11 + -0.028399266338740823 * input_12 + 0.09126970388019003;
#
# 			double output_1_72_BA = -0.15829799013021148 * input_0 + -0.022893722902584693 * input_1 + 0.21311019530043074 * input_2 + 0.3666558050879411 * input_3 + -0.18682052553819226 * input_4 + 0.08955593213596504 * input_5 + 0.18785550652533237 * input_6 + -0.08688525499443414 * input_7 + -0.12842433097743117 * input_8 + 0.0149871690732248 * input_9 + 0.12691764964251237 * input_10 + 0.13697895764579338 * input_11 + -0.1862648947334704 * input_12 + -0.0013754128296864338;
#
# 			double output_1_73_BA = 0.12592564397055014 * input_0 + 0.03648378330071278 * input_1 + 0.09464933222226071 * input_2 + -0.0657258351875382 * input_3 + 0.04380053987756857 * input_4 + -0.0008361911861079378 * input_5 + -0.15894101516314826 * input_6 + -0.14215894742617988 * input_7 + -0.15652949616798256 * input_8 + 0.21044374346981182 * input_9 + 0.12182799646392987 * input_10 + -0.036552968794152665 * input_11 + -0.04382339973738769 * input_12 + 0.05035315849236896;
#
# 			double output_1_74_BA = 0.12895264766838446 * input_0 + -0.19265597886342628 * input_1 + 0.04953312981960227 * input_2 + 0.3054452716419039 * input_3 + 0.2222649097427388 * input_4 + 0.19504996276978348 * input_5 + 0.13544494062173457 * input_6 + -0.22821691647276096 * input_7 + 0.07153723566864424 * input_8 + 0.09880031836824762 * input_9 + -0.07414945977665519 * input_10 + 0.08127276982389278 * input_11 + 0.07579920548527867 * input_12 + -0.09690848238664383;
#
# 			double output_1_75_BA = 0.009292218442402947 * input_0 + 0.1503895203902076 * input_1 + 0.12445099650372925 * input_2 + -0.2536096791256403 * input_3 + 0.10919064546560282 * input_4 + -0.24551756645031156 * input_5 + -0.1886317217608266 * input_6 + -0.07993532000278329 * input_7 + -0.12118763007399488 * input_8 + 0.020732368104805155 * input_9 + -0.02496260054170099 * input_10 + 0.1868556172975506 * input_11 + 0.2518364298855985 * input_12 + -0.16676520808114928;
#
# 			double output_1_76_BA = 0.21749918916640779 * input_0 + -0.05123505730142527 * input_1 + 0.02449141927740434 * input_2 + 0.16945508732046188 * input_3 + -0.12876641835146874 * input_4 + 0.2057986379715177 * input_5 + -0.032154543431202776 * input_6 + 0.12493222639145984 * input_7 + 0.1471809326998724 * input_8 + 0.1787082057259286 * input_9 + 0.09652618052601723 * input_10 + -0.022795648637122228 * input_11 + -0.12155143378303836 * input_12 + 0.12576517276936416;
#
# 			double output_1_77_BA = -0.12354196961099932 * input_0 + 0.19196084627664226 * input_1 + -0.046665641208521305 * input_2 + 0.2267270290733276 * input_3 + -0.1698900866752756 * input_4 + 0.22428356421293155 * input_5 + 0.011310865924403956 * input_6 + -0.03701952316880878 * input_7 + 0.15156404552889977 * input_8 + -0.050559346652386705 * input_9 + -0.0028094661593169976 * input_10 + 0.14179324845796842 * input_11 + -0.12588856587558878 * input_12 + -0.16225480424140964;
#
# 			double output_1_78_BA = -2.1822208193755495e-12 * input_0 + -0.004747339258921573 * input_1 + -0.00020422143492268918 * input_2 + -0.0014469616880168905 * input_3 + -0.005360664199630566 * input_4 + 2.6367767111158197e-06 * input_5 + 0.0037053580160569424 * input_6 + 5.531598258145949e-06 * input_7 + -0.0005232092173100173 * input_8 + -0.004348687711661935 * input_9 + 8.041430969881624e-05 * input_10 + -0.00022606894805270994 * input_11 + 5.041879605954002e-05 * input_12 + -0.23026080747817212;
#
# 			double output_1_79_BA = -8.807749279708535e-16 * input_0 + 0.005551829230777855 * input_1 + -0.004728868782511787 * input_2 + 0.000126782566973036 * input_3 + 3.259882735429742e-07 * input_4 + 1.677720272912909e-06 * input_5 + 2.3430142654067488e-12 * input_6 + -5.54748902742716e-10 * input_7 + 0.0005800432793171245 * input_8 + -0.005776075997513828 * input_9 + 0.0006021233826383621 * input_10 + -9.599411694105434e-05 * input_11 + 5.78161431279984e-09 * input_12 + 0.21082840319323282;
#
# 			double output_1_80_BA = -0.09002193844908926 * input_0 + -0.12802496472931882 * input_1 + -0.023903363764537035 * input_2 + 0.23455981375541826 * input_3 + -0.0043256385161563075 * input_4 + 0.11766015679349366 * input_5 + 0.20385986901605763 * input_6 + -0.06380213342800954 * input_7 + -0.14039958238170927 * input_8 + 0.18028534959310208 * input_9 + -0.21228102999112966 * input_10 + -0.19984906786205256 * input_11 + -0.251760313769737 * input_12 + -0.1799444733951853;
#
# 			double output_1_81_BA = -0.03923096924838959 * input_0 + -0.10676532655693452 * input_1 + -0.08667615188499765 * input_2 + -0.3046146449017765 * input_3 + 0.02443467053437117 * input_4 + 0.123826100597233 * input_5 + 0.23943524284390524 * input_6 + 0.020836881045402704 * input_7 + -0.12602143579069422 * input_8 + 0.08451639337029326 * input_9 + -0.027687767833791954 * input_10 + -0.02826148217294283 * input_11 + -0.04626339469536703 * input_12 + -0.06390020814144921;
#
# 			double output_1_82_BA = -0.09842549006907067 * input_0 + -0.010490534609592707 * input_1 + -0.012459200466411385 * input_2 + 0.628056328555263 * input_3 + 0.1666129162341492 * input_4 + 0.2594605770085735 * input_5 + -0.17050346668030467 * input_6 + -0.12020559469811358 * input_7 + -0.14490999838642935 * input_8 + 0.04264827512772312 * input_9 + -0.0750193880380816 * input_10 + 0.12551188944117672 * input_11 + -0.17465564258943722 * input_12 + -0.1249842287798008;
#
# 			double output_1_83_BA = -0.0006309279814541508 * input_0 + -1.982368853507698e-06 * input_1 + 6.2493003451589e-11 * input_2 + -4.133995603966658e-06 * input_3 + -2.1661702029408142e-05 * input_4 + -0.006647508692302604 * input_5 + 5.3220312259286525e-05 * input_6 + 4.5662881125440195e-06 * input_7 + 1.6833168491961206e-08 * input_8 + -0.00169064878539904 * input_9 + 2.5140987755642638e-11 * input_10 + 2.5292408690660028e-15 * input_11 + 1.5459459991658158e-06 * input_12 + -0.20918739026346597;
#
# 			double output_1_84_BA = 0.005241564144698186 * input_0 + 0.005779316971788495 * input_1 + -0.20620783830714481 * input_2 + 0.16007253096991583 * input_3 + 0.04889356370859889 * input_4 + 0.005532900543033148 * input_5 + 0.22507817596859786 * input_6 + 0.05797709975399821 * input_7 + 0.11480667112531673 * input_8 + 0.0024872169208705083 * input_9 + -0.0018673444381337152 * input_10 + -0.13618505724049204 * input_11 + 0.05102206168662444 * input_12 + -0.20401005660539046;
#
# 			double output_1_85_BA = -1.128491513366942e-06 * input_0 + -0.005352592493723602 * input_1 + -2.1820386493384484e-13 * input_2 + 0.004344691456612834 * input_3 + -0.00023518809380183202 * input_4 + -1.3135198054149409e-06 * input_5 + -0.0033037585910940547 * input_6 + 0.00035193477751768395 * input_7 + 0.0015245874736533529 * input_8 + 1.9698187381293177e-15 * input_9 + 9.874752644213835e-13 * input_10 + -0.00041851042291379467 * input_11 + -0.002349808723049818 * input_12 + -0.1730844615265857;
#
# 			double output_1_86_BA = -0.08845384858997712 * input_0 + -0.22705141717631455 * input_1 + 0.19654333926801518 * input_2 + -0.2823473007434554 * input_3 + 0.013019664904866364 * input_4 + -0.14857464710937066 * input_5 + -0.09693348640010067 * input_6 + -0.010556773573162783 * input_7 + -0.15328071895833048 * input_8 + 0.16153019613779196 * input_9 + -0.13112315678716802 * input_10 + -0.01407955997215155 * input_11 + -0.07719715642458737 * input_12 + -0.12878273673749469;
#
# 			double output_1_87_BA = 0.01858575833630606 * input_0 + 1.6516604340827632e-09 * input_1 + -0.002127109252074875 * input_2 + -0.03322217487131786 * input_3 + 0.023087830397596744 * input_4 + -0.19913092860508563 * input_5 + 0.17613795343637434 * input_6 + 0.10340822793032906 * input_7 + 0.06317335360007287 * input_8 + 0.12788971328251847 * input_9 + 0.17447928996562947 * input_10 + -0.205056109212213 * input_11 + -0.14105926695782328 * input_12 + 0.16853024431375777;
#
# 			double output_1_88_BA = 0.19644373604801105 * input_0 + -0.007290576422102011 * input_1 + -0.15753982556190418 * input_2 + -0.46881051494765485 * input_3 + -0.0954959986466489 * input_4 + -0.09000815270746708 * input_5 + -0.13170404503128533 * input_6 + -0.13749756628609683 * input_7 + -0.07237864728080821 * input_8 + 0.12728429751027917 * input_9 + -0.06956381696058336 * input_10 + 0.18879478037471642 * input_11 + -0.07832333482295706 * input_12 + -0.06376179909318862;
#
# 			double output_1_89_BA = -0.039785973955531545 * input_0 + -0.2068675346769624 * input_1 + -0.008822965435546013 * input_2 + 0.10884247073572442 * input_3 + -0.031718128892338104 * input_4 + -0.02426384954994009 * input_5 + -0.23617955340749444 * input_6 + -0.06688449274222918 * input_7 + -0.15964333923227333 * input_8 + 0.1006671495481123 * input_9 + -0.2315517873570496 * input_10 + 0.07858734225108605 * input_11 + 0.12031983899330068 * input_12 + 0.19559234659874877;
#
# 			double output_1_90_BA = 0.0029599386539985095 * input_0 + -0.0007206471082769442 * input_1 + 0.0023226722363017143 * input_2 + -4.7710786679848084e-05 * input_3 + -0.0015576029111027353 * input_4 + 0.005639346980691942 * input_5 + -1.4720858642253348e-07 * input_6 + -0.0005380865080491428 * input_7 + -0.000567381147995726 * input_8 + -0.004038581388416757 * input_9 + 0.00030495297976478367 * input_10 + 1.4490117294750638e-07 * input_11 + -0.005207460826221999 * input_12 + -0.12484878188442065;
#
# ...
# 			lTable["output_1_46"] = { relu(output_1_46_BA) };
# 			lTable["output_1_47"] = { relu(output_1_47_BA) };
# 			lTable["output_1_48"] = { relu(output_1_48_BA) };
# 			lTable["output_1_49"] = { relu(output_1_49_BA) };
# 			lTable["output_1_50"] = { relu(output_1_50_BA) };
# 			lTable["output_1_51"] = { relu(output_1_51_BA) };
# 			lTable["output_1_52"] = { relu(output_1_52_BA) };
# 			lTable["output_1_53"] = { relu(output_1_53_BA) };
# 			lTable["output_1_54"] = { relu(output_1_54_BA) };
# 			lTable["output_1_55"] = { relu(output_1_55_BA) };
# 			lTable["output_1_56"] = { relu(output_1_56_BA) };
# 			lTable["output_1_57"] = { relu(output_1_57_BA) };
# 			lTable["output_1_58"] = { relu(output_1_58_BA) };
# 			lTable["output_1_59"] = { relu(output_1_59_BA) };
# 			lTable["output_1_60"] = { relu(output_1_60_BA) };
# 			lTable["output_1_61"] = { relu(output_1_61_BA) };
# 			lTable["output_1_62"] = { relu(output_1_62_BA) };
# 			lTable["output_1_63"] = { relu(output_1_63_BA) };
# 			lTable["output_1_64"] = { relu(output_1_64_BA) };
# 			lTable["output_1_65"] = { relu(output_1_65_BA) };
# 			lTable["output_1_66"] = { relu(output_1_66_BA) };
# 			lTable["output_1_67"] = { relu(output_1_67_BA) };
# 			lTable["output_1_68"] = { relu(output_1_68_BA) };
# 			lTable["output_1_69"] = { relu(output_1_69_BA) };
# 			lTable["output_1_70"] = { relu(output_1_70_BA) };
# 			lTable["output_1_71"] = { relu(output_1_71_BA) };
# 			lTable["output_1_72"] = { relu(output_1_72_BA) };
# 			lTable["output_1_73"] = { relu(output_1_73_BA) };
# 			lTable["output_1_74"] = { relu(output_1_74_BA) };
# 			lTable["output_1_75"] = { relu(output_1_75_BA) };
# 			lTable["output_1_76"] = { relu(output_1_76_BA) };
# 			lTable["output_1_77"] = { relu(output_1_77_BA) };
# 			lTable["output_1_78"] = { relu(output_1_78_BA) };
# 			lTable["output_1_79"] = { relu(output_1_79_BA) };
# 			lTable["output_1_80"] = { relu(output_1_80_BA) };
# 			lTable["output_1_81"] = { relu(output_1_81_BA) };
# 			lTable["output_1_82"] = { relu(output_1_82_BA) };
# 			lTable["output_1_83"] = { relu(output_1_83_BA) };
# 			lTable["output_1_84"] = { relu(output_1_84_BA) };
# 			lTable["output_1_85"] = { relu(output_1_85_BA) };
# 			lTable["output_1_86"] = { relu(output_1_86_BA) };
# 			lTable["output_1_87"] = { relu(output_1_87_BA) };
# 			lTable["output_1_88"] = { relu(output_1_88_BA) };
# 			lTable["output_1_89"] = { relu(output_1_89_BA) };
# 			lTable["output_1_90"] = { relu(output_1_90_BA) };
# 			lTable["output_1_91"] = { relu(output_1_91_BA) };
# 			lTable["output_1_92"] = { relu(output_1_92_BA) };
# 			lTable["output_1_93"] = { relu(output_1_93_BA) };
# 			lTable["output_1_94"] = { relu(output_1_94_BA) };
# 			lTable["output_1_95"] = { relu(output_1_95_BA) };
# 			lTable["output_1_96"] = { relu(output_1_96_BA) };
# 			lTable["output_1_97"] = { relu(output_1_97_BA) };
# 			lTable["output_1_98"] = { relu(output_1_98_BA) };
# 			lTable["output_1_99"] = { relu(output_1_99_BA) };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("input_0")[0], iTable.at("input_1")[0], iTable.at("input_2")[0], iTable.at("input_3")[0], iTable.at("input_4")[0], iTable.at("input_5")[0], iTable.at("input_6")[0], iTable.at("input_7")[0], iTable.at("input_8")[0], iTable.at("input_9")[0], iTable.at("input_10")[0], iTable.at("input_11")[0], iTable.at("input_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace HiddenLayer_1
#
#
# 	namespace OutputLayer {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "output_1_0", "output_1_1", "output_1_2", "output_1_3", "output_1_4", "output_1_5", "output_1_6", "output_1_7", "output_1_8", "output_1_9", "output_1_10", "output_1_11", "output_1_12", "output_1_13", "output_1_14", "output_1_15", "output_1_16", "output_1_17", "output_1_18", "output_1_19", "output_1_20", "output_1_21", "output_1_22", "output_1_23", "output_1_24", "output_1_25", "output_1_26", "output_1_27", "output_1_28", "output_1_29", "output_1_30", "output_1_31", "output_1_32", "output_1_33", "output_1_34", "output_1_35", "output_1_36", "output_1_37", "output_1_38", "output_1_39", "output_1_40", "output_1_41", "output_1_42", "output_1_43", "output_1_44", "output_1_45", "output_1_46", "output_1_47", "output_1_48", "output_1_49", "output_1_50", "output_1_51", "output_1_52", "output_1_53", "output_1_54", "output_1_55", "output_1_56", "output_1_57", "output_1_58", "output_1_59", "output_1_60", "output_1_61", "output_1_62", "output_1_63", "output_1_64", "output_1_65", "output_1_66", "output_1_67", "output_1_68", "output_1_69", "output_1_70", "output_1_71", "output_1_72", "output_1_73", "output_1_74", "output_1_75", "output_1_76", "output_1_77", "output_1_78", "output_1_79", "output_1_80", "output_1_81", "output_1_82", "output_1_83", "output_1_84", "output_1_85", "output_1_86", "output_1_87", "output_1_88", "output_1_89", "output_1_90", "output_1_91", "output_1_92", "output_1_93", "output_1_94", "output_1_95", "output_1_96", "output_1_97", "output_1_98", "output_1_99" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any output_1_0, std::any output_1_1, std::any output_1_2, std::any output_1_3, std::any output_1_4, std::any output_1_5, std::any output_1_6, std::any output_1_7, std::any output_1_8, std::any output_1_9, std::any output_1_10, std::any output_1_11, std::any output_1_12, std::any output_1_13, std::any output_1_14, std::any output_1_15, std::any output_1_16, std::any output_1_17, std::any output_1_18, std::any output_1_19, std::any output_1_20, std::any output_1_21, std::any output_1_22, std::any output_1_23, std::any output_1_24, std::any output_1_25, std::any output_1_26, std::any output_1_27, std::any output_1_28, std::any output_1_29, std::any output_1_30, std::any output_1_31, std::any output_1_32, std::any output_1_33, std::any output_1_34, std::any output_1_35, std::any output_1_36, std::any output_1_37, std::any output_1_38, std::any output_1_39, std::any output_1_40, std::any output_1_41, std::any output_1_42, std::any output_1_43, std::any output_1_44, std::any output_1_45, std::any output_1_46, std::any output_1_47, std::any output_1_48, std::any output_1_49, std::any output_1_50, std::any output_1_51, std::any output_1_52, std::any output_1_53, std::any output_1_54, std::any output_1_55, std::any output_1_56, std::any output_1_57, std::any output_1_58, std::any output_1_59, std::any output_1_60, std::any output_1_61, std::any output_1_62, std::any output_1_63, std::any output_1_64, std::any output_1_65, std::any output_1_66, std::any output_1_67, std::any output_1_68, std::any output_1_69, std::any output_1_70, std::any output_1_71, std::any output_1_72, std::any output_1_73, std::any output_1_74, std::any output_1_75, std::any output_1_76, std::any output_1_77, std::any output_1_78, std::any output_1_79, std::any output_1_80, std::any output_1_81, std::any output_1_82, std::any output_1_83, std::any output_1_84, std::any output_1_85, std::any output_1_86, std::any output_1_87, std::any output_1_88, std::any output_1_89, std::any output_1_90, std::any output_1_91, std::any output_1_92, std::any output_1_93, std::any output_1_94, std::any output_1_95, std::any output_1_96, std::any output_1_97, std::any output_1_98, std::any output_1_99) {
#
# 			tTable lTable;
#
# 			double output_2_0_BA = -0.024377500642867433 * output_1_0 + -0.12898665245118013 * output_1_1 + 0.10448405274294766 * output_1_2 + -0.2838199305100527 * output_1_3 + 0.15319313950261668 * output_1_4 + 0.11252487908991089 * output_1_5 + -0.021997541724267915 * output_1_6 + -0.17743463545716262 * output_1_7 + 0.5725164924642214 * output_1_8 + 0.1856701428268751 * output_1_9 + -0.07724777029141174 * output_1_10 + 0.2387575683086929 * output_1_11 + 0.040501626785591605 * output_1_12 + -0.05178814961273717 * output_1_13 + -0.13299058063016084 * output_1_14 + -0.03388888551986492 * output_1_15 + 0.26025081844850295 * output_1_16 + -0.009527120332155617 * output_1_17 + -0.2693890343543488 * output_1_18 + 0.22095299228141516 * output_1_19 + -5.1711823244675704e-05 * output_1_20 + 0.010915535558396491 * output_1_21 + -0.2296457033275201 * output_1_22 + -0.1578851527299389 * output_1_23 + -0.16707421090247332 * output_1_24 + 0.2132730530651983 * output_1_25 + 0.4013792724167776 * output_1_26 + -0.12310037058352868 * output_1_27 + 0.03709079309898406 * output_1_28 + -0.1774701849588782 * output_1_29 + -0.14411452968599825 * output_1_30 + 0.4943166004122759 * output_1_31 + -0.08192462271545094 * output_1_32 + -0.14037107403273416 * output_1_33 + 0.0014208328335706978 * output_1_34 + -0.07532346211929414 * output_1_35 + -2.1030356041655136e-06 * output_1_36 + -0.10464985441170446 * output_1_37 + 0.007699122222274251 * output_1_38 + -0.039648980641967896 * output_1_39 + 0.0785430730597954 * output_1_40 + 0.23673461955982134 * output_1_41 + 1.3714130388531563e-12 * output_1_42 + 0.01773334823617479 * output_1_43 + -0.02539854480416446 * output_1_44 + -0.014608551182625589 * output_1_45 + 0.16412632668090835 * output_1_46 + 0.0001734893055434987 * output_1_47 + -0.03355980840093566 * output_1_48 + 0.13551855482408803 * output_1_49 + -0.01936040405476367 * output_1_50 + 0.04859083124317069 * output_1_51 + 0.07953062293500464 * output_1_52 + 0.04756980736705146 * output_1_53 + -0.1319411174662987 * output_1_54 + 0.003842269181641254 * output_1_55 + -0.0029395234754370668 * output_1_56 + 0.00668008740046657 * output_1_57 + -0.14771890119354836 * output_1_58 + -0.051130546471209785 * output_1_59 + -0.13668608830084159 * output_1_60 + 0.03001044320199852 * output_1_61 + 0.20564016566116322 * output_1_62 + 0.02952380017259709 * output_1_63 + -0.0695900019921703 * output_1_64 + 0.15822400848968945 * output_1_65 + -0.004536444437297177 * output_1_66 + -0.04841061626397455 * output_1_67 + -3.224426092595126e-08 * output_1_68 + 0.14614960144128383 * output_1_69 + 0.135691128177224 * output_1_70 + 0.13123305085627557 * output_1_71 + 0.20886510501987748 * output_1_72 + -0.17986909890711794 * output_1_73 + 0.03823340215645954 * output_1_74 + -0.21990179166516122 * output_1_75 + 0.2510724600054968 * output_1_76 + 0.07357844980825744 * output_1_77 + 0.0001583976530932617 * output_1_78 + -7.890232946944544e-08 * output_1_79 + 0.23470092405574336 * output_1_80 + -0.05002538183215591 * output_1_81 + 0.014365174730120401 * output_1_82 + -0.006252480413442325 * output_1_83 + -0.1209534068637541 * output_1_84 + -0.004843140097286118 * output_1_85 + -0.08501982376411432 * output_1_86 + -0.09545688667004533 * output_1_87 + -0.08627550776601736 * output_1_88 + 0.15407590732115709 * output_1_89 + 1.9862511160870374e-08 * output_1_90 + 0.09786665957135221 * output_1_91 + 4.456272564614848e-05 * output_1_92 + 0.282952539868915 * output_1_93 + 0.26937278934971903 * output_1_94 + 2.3986022347417774e-05 * output_1_95 + -0.11927045469314627 * output_1_96 + -0.04635382490178657 * output_1_97 + -5.765586445899169e-07 * output_1_98 + -1.7022369526913738e-05 * output_1_99 + -0.052329830330821336;
#
# 			lTable["Estimator"] = { output_2_0_BA };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("output_1_0")[0], iTable.at("output_1_1")[0], iTable.at("output_1_2")[0], iTable.at("output_1_3")[0], iTable.at("output_1_4")[0], iTable.at("output_1_5")[0], iTable.at("output_1_6")[0], iTable.at("output_1_7")[0], iTable.at("output_1_8")[0], iTable.at("output_1_9")[0], iTable.at("output_1_10")[0], iTable.at("output_1_11")[0], iTable.at("output_1_12")[0], iTable.at("output_1_13")[0], iTable.at("output_1_14")[0], iTable.at("output_1_15")[0], iTable.at("output_1_16")[0], iTable.at("output_1_17")[0], iTable.at("output_1_18")[0], iTable.at("output_1_19")[0], iTable.at("output_1_20")[0], iTable.at("output_1_21")[0], iTable.at("output_1_22")[0], iTable.at("output_1_23")[0], iTable.at("output_1_24")[0], iTable.at("output_1_25")[0], iTable.at("output_1_26")[0], iTable.at("output_1_27")[0], iTable.at("output_1_28")[0], iTable.at("output_1_29")[0], iTable.at("output_1_30")[0], iTable.at("output_1_31")[0], iTable.at("output_1_32")[0], iTable.at("output_1_33")[0], iTable.at("output_1_34")[0], iTable.at("output_1_35")[0], iTable.at("output_1_36")[0], iTable.at("output_1_37")[0], iTable.at("output_1_38")[0], iTable.at("output_1_39")[0], iTable.at("output_1_40")[0], iTable.at("output_1_41")[0], iTable.at("output_1_42")[0], iTable.at("output_1_43")[0], iTable.at("output_1_44")[0], iTable.at("output_1_45")[0], iTable.at("output_1_46")[0], iTable.at("output_1_47")[0], iTable.at("output_1_48")[0], iTable.at("output_1_49")[0], iTable.at("output_1_50")[0], iTable.at("output_1_51")[0], iTable.at("output_1_52")[0], iTable.at("output_1_53")[0], iTable.at("output_1_54")[0], iTable.at("output_1_55")[0], iTable.at("output_1_56")[0], iTable.at("output_1_57")[0], iTable.at("output_1_58")[0], iTable.at("output_1_59")[0], iTable.at("output_1_60")[0], iTable.at("output_1_61")[0], iTable.at("output_1_62")[0], iTable.at("output_1_63")[0], iTable.at("output_1_64")[0], iTable.at("output_1_65")[0], iTable.at("output_1_66")[0], iTable.at("output_1_67")[0], iTable.at("output_1_68")[0], iTable.at("output_1_69")[0], iTable.at("output_1_70")[0], iTable.at("output_1_71")[0], iTable.at("output_1_72")[0], iTable.at("output_1_73")[0], iTable.at("output_1_74")[0], iTable.at("output_1_75")[0], iTable.at("output_1_76")[0], iTable.at("output_1_77")[0], iTable.at("output_1_78")[0], iTable.at("output_1_79")[0], iTable.at("output_1_80")[0], iTable.at("output_1_81")[0], iTable.at("output_1_82")[0], iTable.at("output_1_83")[0], iTable.at("output_1_84")[0], iTable.at("output_1_85")[0], iTable.at("output_1_86")[0], iTable.at("output_1_87")[0], iTable.at("output_1_88")[0], iTable.at("output_1_89")[0], iTable.at("output_1_90")[0], iTable.at("output_1_91")[0], iTable.at("output_1_92")[0], iTable.at("output_1_93")[0], iTable.at("output_1_94")[0], iTable.at("output_1_95")[0], iTable.at("output_1_96")[0], iTable.at("output_1_97")[0], iTable.at("output_1_98")[0], iTable.at("output_1_99")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace OutputLayer
#
#
# 	std::vector<std::string> get_input_names(){
# 		std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 		return lFeatures;
# 	}
#
# 	std::vector<std::string> get_output_names(){
# 		std::vector<std::string> lOutputs = { "Estimator" };
#
# 		return lOutputs;
# 	}
#
# 	tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 		tTable lTable_InputLayer = InputLayer::compute_features(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 		tTable lTable_HiddenLayer_1 = HiddenLayer_1::compute_model_outputs_from_table( lTable_InputLayer );
#
# 		tTable lTable_OutputLayer = OutputLayer::compute_model_outputs_from_table( lTable_HiddenLayer_1 );
#
#
# 		tTable lTable;
#
# 		std::any  lEstimator = lTable_OutputLayer[ "Estimator" ][0];
# 		lTable[ "Estimator" ] = { lEstimator };
#
# 		return lTable;
# 	}
#
# 	tTable compute_model_outputs_from_table( tTable const & iTable) {
# 		tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 		return lTable;
# 	}
#
# } // eof namespace

# %%
    def write_text_to_file(iCPPCode, oCPPFile):          
        with open(oCPPFile, "w") as text_file:
            text_file.write(iCPPCode)

    def add_cpp_main_function(iCPPCode, iCSVFile):
        lCPPCode = "#include \"Generic.i\"\n\n"
        lCPPCode = lCPPCode + iCPPCode
        lCPPCode = lCPPCode + "\tint main() {\n"
        lCPPCode = lCPPCode + "\t\tscore_csv_file(\"" + iCSVFile +"\");\n"
        lCPPCode = lCPPCode + "\treturn 0;\n}\n"
        return lCPPCode

    def compile_cpp_code_as_executable(iName):
        import subprocess
        lCommand = ["g++", "-Wall", "-Wno-unused-function", "-std=c++17" , "-g" ,  "-o", iName + ".exe",  iName + ".cpp"]
        print("EXECUTING" , "'" + " ".join(lCommand) + "'")
        result = subprocess.check_output(lCommand)
        # print(result)

    def execute_cpp_model(iName, iCSVFile):
        import subprocess
        result2 = subprocess.check_output([iName + ".exe",  iCSVFile])
        result2 = result2.decode()
        print(result2[:100])
        print(result2[-100:])
        return result2
        
    def execute_cpp_code(iCPPCode, iCSVFile):
        lName = "/tmp/sklearn2sql_cpp_" + str(id(clf));
        lCPPCode = add_cpp_main_function(iCPPCode, iCSVFile)
        write_text_to_file(lCPPCode, lName + ".cpp")
        compile_cpp_code_as_executable(lName)
        result = execute_cpp_model(lName, iCSVFile)
        write_text_to_file(str(result), lName + ".out")
        return lName + ".out"

# %%
populate_table("/tmp/boston2.csv" , ["Feature_" + str(i) for i,x in enumerate(metadata["features"])])
lCPPOutput = execute_cpp_code(lCPPCode , "/tmp/boston2.csv")
cpp_output = pd.read_csv(lCPPOutput)
# Out:
# EXECUTING 'g++ -Wall -Wno-unused-function -std=c++17 -g -o /tmp/sklearn2sql_cpp_139907596014400.exe /tmp/sklearn2sql_cpp_139907596014400.cpp'
# idx,Estimator
# 0,29.60110038383267
# 1,25.20620236974702
# 2,30.21433941864835
# 3,31.81762596413215
# 4,30.2
# 16369027012
# 502,22.47493682497401
# 503,29.65186868056715
# 504,27.43667423688055
# 505,24.09037871548294

# %%
cpp_output.sample(12, random_state=1960)
# Out:
#      idx  Estimator
# 230  230  21.467617
# 112  112  19.363871
# 125  125  20.780061
# 9      9  17.444410
# 213  213  22.409818
# 109  109  18.579589
# 127  127  16.923196
# 244  244  19.397980
# 406  406  11.170149
# 490  490  10.111982
# 245  245  18.025742
# 133  133  18.736043

# %%
skl_outputs = pd.DataFrame()
X = df[metadata['features']].values
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['idx']);

skl_output_score = pd.DataFrame(clf.predict(X), columns=['Estimator']);
skl_output = pd.concat([skl_output_key, skl_output_score] , axis=1)
skl_output.sample(12, random_state=1960)
# Out:
#      idx  Estimator
# 230  230  21.467617
# 112  112  19.363871
# 125  125  20.780061
# 9      9  17.444410
# 213  213  22.409818
# 109  109  18.579589
# 127  127  16.923196
# 244  244  19.397980
# 406  406  11.170149
# 490  490  10.111982
# 245  245  18.025742
# 133  133  18.736043

# %%
cpp_skl_join = skl_output.join(cpp_output , how='left', on='idx', lsuffix='_skl', rsuffix='_cpp')

# %%
cpp_skl_join.sample(12, random_state=1960)
# Out:
#      idx_skl  Estimator_skl  idx_cpp  Estimator_cpp
# 230      230      21.467617      230      21.467617
# 112      112      19.363871      112      19.363871
# 125      125      20.780061      125      20.780061
# 9          9      17.444410        9      17.444410
# 213      213      22.409818      213      22.409818
# 109      109      18.579589      109      18.579589
# 127      127      16.923196      127      16.923196
# 244      244      19.397980      244      19.397980
# 406      406      11.170149      406      11.170149
# 490      490      10.111982      490      10.111982
# 245      245      18.025742      245      18.025742
# 133      133      18.736043      133      18.736043

# %%
lDiff = cpp_skl_join['Estimator_skl'] - cpp_skl_join['Estimator_cpp']

# %%
lDiff.describe()
# Out:
# count    5.060000e+02
# mean    -4.335574e-16
# std      9.449357e-15
# min     -4.085621e-14
# 25%     -7.105427e-15
# 50%      0.000000e+00
# 75%      7.105427e-15
# max      3.197442e-14
# dtype: float64
