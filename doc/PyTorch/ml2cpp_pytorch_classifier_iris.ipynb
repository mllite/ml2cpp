# %% [markdown]
# # ML2CPP

# %% [markdown]
# ## Preparing the dataset

# %%
from sklearn import datasets
import numpy as np
import pandas as pd

def populate_table(tablename, feature_names):
    iris = datasets.load_iris()
    X = iris.data  
    N = X.shape[0]
    y = iris.target.reshape(N,1)
    k = np.arange(N).reshape(N, 1)
    k_X_y = np.concatenate((k, X, y) , axis=1)
    lTable=pd.DataFrame(k_X_y)
    # print(lTable.head())
    lTable.columns = ['idx'] + feature_names + ['TGT'];
    lTable['TGT'] = lTable['TGT'].apply(int)
    lTable['idx'] = lTable['idx'].apply(int)
    lTable.to_csv(tablename , float_format='%.14g')

# %%
metadata = {"primary_key" : "KEY",
            "features" : ['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm', 'petal_width_cm'],
            "targets" : ["TGT"],
            "table" : "iris"}

# %%
populate_table("/tmp/iris.csv" , metadata["features"])

# %%
df = pd.read_csv("/tmp/iris.csv")
df.sample(12, random_state=1960)
# Out:
#      Unnamed: 0  idx  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# 114         114  114              5.8             2.8              5.1
# 74           74   74              6.4             2.9              4.3
# 9             9    9              4.9             3.1              1.5
# 88           88   88              5.6             3.0              4.1
# 25           25   25              5.0             3.0              1.6
# 5             5    5              5.4             3.9              1.7
# 48           48   48              5.3             3.7              1.5
# 117         117  117              7.7             3.8              6.7
# 83           83   83              6.0             2.7              5.1
# 105         105  105              7.6             3.0              6.6
# 27           27   27              5.2             3.5              1.5
# 64           64   64              5.6             2.9              3.6
#
#      petal_width_cm  TGT
# 114             2.4    2
# 74              1.3    1
# 9               0.1    0
# 88              1.3    1
# 25              0.2    0
# 5               0.4    0
# 48              0.2    0
# 117             2.2    2
# 83              1.6    1
# 105             2.1    2
# 27              0.2    0
# 64              1.3    1

# %% [markdown]
# ## Training a Model

# %%
import torch
from torch import nn
import torch.nn.functional as F

from skorch import NeuralNetClassifier

torch.manual_seed(1234)

torch.set_default_tensor_type('torch.DoubleTensor')

num_units = 15
# Example of using Sequential
model = nn.Sequential(
    nn.Linear(4, num_units),
    nn.Dropout(),
    nn.ReLU(),
    nn.Linear(num_units , num_units * 2),
    nn.Dropout(),
    nn.Hardshrink(),
    nn.Linear(num_units * 2, 3),
    nn.Softmax())

clf = NeuralNetClassifier(
    model,
    max_epochs=10,
    lr=0.1,
)

clf.fit(df[metadata['features']].values, df[metadata['targets']].values.ravel())
# Out:
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.2246       0.1667        1.0035  0.0164
#       2        1.2813       0.6333        0.9924  0.0055
#       3        1.0901       0.6667        0.9621  0.0057
#       4        1.1053       0.6000        0.9409  0.0058
#       5        0.9949       0.6667        0.9440  0.0054
#       6        0.9680       0.6000        0.9318  0.0055
#       7        1.0221       0.6667        0.9193  0.0057
#       8        1.0283       0.6667        0.9037  0.0053
#       9        0.9534       0.6667        0.8861  0.0055
#      10        0.9599       0.4667        0.8718  0.0058
# /home/antoine/.local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/antoine/.local/lib/python3.8/site-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# <class 'skorch.classifier.NeuralNetClassifier'>[initialized](
#   module_=Sequential(
#     (0): Linear(in_features=4, out_features=15, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#     (3): Linear(in_features=15, out_features=30, bias=True)
#     (4): Dropout(p=0.5, inplace=False)
#     (5): Hardshrink(0.5)
#     (6): Linear(in_features=30, out_features=3, bias=True)
#     (7): Softmax(dim=None)
#   ),
# )

# %% [markdown]
# ## Deploying the Model

# %%
def generate_cpp_for_model(model):
    import pickle, json, requests, base64
    b64_data = base64.b64encode(pickle.dumps(model)).decode('utf-8')
    # send the model th the web service
    json_data={"Name":"model_cpp_sample", 
               "PickleData":b64_data , 
               "SQLDialect":"CPP",
               "FeatureNames" : metadata['features']}
    r = requests.post("https://sklearn2sql.herokuapp.com/model", json=json_data)
    content = r.json()
    lCPP = content["model"]["SQLGenrationResult"][0]["SQL"]
    # print(lCPP);
    return lCPP


lCPPCode = generate_cpp_for_model(clf);

# %%
print(lCPPCode)
# Out:
# namespace  {
#
# 	std::vector<std::any> get_classes(){
# 		std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 		return lClasses;
# 	}
#
# 	namespace layer_0 {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
#
# 			tTable lTable;
#
# 			lTable["output_0"] = { -0.30603992256711465 + -0.2681658279115361 * Feature_0 + -0.4212461386497293 * Feature_1 + -0.03359383959203077 * Feature_2 + -0.08562051231388146 * Feature_3 };
# 			lTable["output_1"] = { 0.32941788454291143 + -0.1095505425120481 * Feature_0 + -0.2303356406035587 * Feature_1 + -0.30119600366651533 * Feature_2 + -0.2657872127709704 * Feature_3 };
# 			lTable["output_2"] = { -0.35699247457065963 + -0.20240689541381562 * Feature_0 + 0.4367539495920659 * Feature_1 + 0.30313398266901126 * Feature_2 + -0.467653680368123 * Feature_3 };
# 			lTable["output_3"] = { 0.24378563304958692 + 0.21629098438007371 * Feature_0 + 0.12081902360022591 * Feature_1 + -0.2757904195928067 * Feature_2 + -0.19289104041757052 * Feature_3 };
# 			lTable["output_4"] = { 0.48498527682799586 + -0.19344922614856994 * Feature_0 + -0.30538286744809773 * Feature_1 + 0.24211783509366644 * Feature_2 + 0.14676445023515858 * Feature_3 };
# 			lTable["output_5"] = { -0.1666900542663432 + -0.21351254544889164 * Feature_0 + -0.16863971270268763 * Feature_1 + -0.11922646182093466 * Feature_2 + -0.1484360134871563 * Feature_3 };
# 			lTable["output_6"] = { 0.4759489114708615 + -0.42906790076143725 * Feature_0 + -0.47756888736257125 * Feature_1 + -0.02911971180542372 * Feature_2 + -0.18066654652495184 * Feature_3 };
# 			lTable["output_7"] = { -0.3672769625018286 + 0.31011983241653174 * Feature_0 + -0.07672618740123166 * Feature_1 + 0.4420118034814837 * Feature_2 + -0.22552845349261366 * Feature_3 };
# 			lTable["output_8"] = { 0.33256221981875883 + 0.2695168613628491 * Feature_0 + -0.06277426843591655 * Feature_1 + -0.22815834251099792 * Feature_2 + 0.4614064724154243 * Feature_3 };
# 			lTable["output_9"] = { -0.007924134130013916 + -0.41376432041545647 * Feature_0 + -0.37110623668244724 * Feature_1 + 0.004269431377565025 * Feature_2 + -0.22090480450321115 * Feature_3 };
# 			lTable["output_10"] = { -0.01939020365431299 + -0.044686461491604254 * Feature_0 + -0.14135334955465326 * Feature_1 + 0.557030256133043 * Feature_2 + -0.3060364396179318 * Feature_3 };
# 			lTable["output_11"] = { 0.2783232538785735 + 0.19254752591699206 * Feature_0 + -0.34554989611683706 * Feature_1 + 0.19513299208826543 * Feature_2 + 0.3094750632257207 * Feature_3 };
# 			lTable["output_12"] = { 0.40343962066736205 + -0.3390279939027925 * Feature_0 + -0.4239322663637089 * Feature_1 + -0.3404359431519729 * Feature_2 + 0.032701828262553356 * Feature_3 };
# 			lTable["output_13"] = { -0.10427855890651949 + -0.44537107276281257 * Feature_0 + 0.3528056298968056 * Feature_1 + 0.02062431724088637 * Feature_2 + -0.47232843691825904 * Feature_3 };
# 			lTable["output_14"] = { -0.07806215405295855 + 0.3895624692330535 * Feature_0 + 0.2261334193611373 * Feature_1 + 0.061341526155648994 * Feature_2 + 0.421476221424925 * Feature_3 };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace layer_0
#
#
# 	namespace layer_1 {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any output_0, std::any output_1, std::any output_2, std::any output_3, std::any output_4, std::any output_5, std::any output_6, std::any output_7, std::any output_8, std::any output_9, std::any output_10, std::any output_11, std::any output_12, std::any output_13, std::any output_14) {
#
# 			tTable lTable;
#
# 			lTable["output_0"] = { output_0 };
# 			lTable["output_1"] = { output_1 };
# 			lTable["output_2"] = { output_2 };
# 			lTable["output_3"] = { output_3 };
# 			lTable["output_4"] = { output_4 };
# 			lTable["output_5"] = { output_5 };
# 			lTable["output_6"] = { output_6 };
# 			lTable["output_7"] = { output_7 };
# 			lTable["output_8"] = { output_8 };
# 			lTable["output_9"] = { output_9 };
# 			lTable["output_10"] = { output_10 };
# 			lTable["output_11"] = { output_11 };
# 			lTable["output_12"] = { output_12 };
# 			lTable["output_13"] = { output_13 };
# 			lTable["output_14"] = { output_14 };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("output_0")[0], iTable.at("output_1")[0], iTable.at("output_2")[0], iTable.at("output_3")[0], iTable.at("output_4")[0], iTable.at("output_5")[0], iTable.at("output_6")[0], iTable.at("output_7")[0], iTable.at("output_8")[0], iTable.at("output_9")[0], iTable.at("output_10")[0], iTable.at("output_11")[0], iTable.at("output_12")[0], iTable.at("output_13")[0], iTable.at("output_14")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace layer_1
#
#
# 	namespace layer_2 {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any output_0, std::any output_1, std::any output_2, std::any output_3, std::any output_4, std::any output_5, std::any output_6, std::any output_7, std::any output_8, std::any output_9, std::any output_10, std::any output_11, std::any output_12, std::any output_13, std::any output_14) {
#
# 			tTable lTable;
#
# 			lTable["output_0"] = { relu(output_0) };
# 			lTable["output_1"] = { relu(output_1) };
# 			lTable["output_2"] = { relu(output_2) };
# 			lTable["output_3"] = { relu(output_3) };
# 			lTable["output_4"] = { relu(output_4) };
# 			lTable["output_5"] = { relu(output_5) };
# 			lTable["output_6"] = { relu(output_6) };
# 			lTable["output_7"] = { relu(output_7) };
# 			lTable["output_8"] = { relu(output_8) };
# 			lTable["output_9"] = { relu(output_9) };
# 			lTable["output_10"] = { relu(output_10) };
# 			lTable["output_11"] = { relu(output_11) };
# 			lTable["output_12"] = { relu(output_12) };
# 			lTable["output_13"] = { relu(output_13) };
# 			lTable["output_14"] = { relu(output_14) };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("output_0")[0], iTable.at("output_1")[0], iTable.at("output_2")[0], iTable.at("output_3")[0], iTable.at("output_4")[0], iTable.at("output_5")[0], iTable.at("output_6")[0], iTable.at("output_7")[0], iTable.at("output_8")[0], iTable.at("output_9")[0], iTable.at("output_10")[0], iTable.at("output_11")[0], iTable.at("output_12")[0], iTable.at("output_13")[0], iTable.at("output_14")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace layer_2
#
#
# 	namespace layer_3 {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14", "output_15", "output_16", "output_17", "output_18", "output_19", "output_20", "output_21", "output_22", "output_23", "output_24", "output_25", "output_26", "output_27", "output_28", "output_29" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any output_0, std::any output_1, std::any output_2, std::any output_3, std::any output_4, std::any output_5, std::any output_6, std::any output_7, std::any output_8, std::any output_9, std::any output_10, std::any output_11, std::any output_12, std::any output_13, std::any output_14) {
#
# 			tTable lTable;
#
# 			lTable["output_0"] = { -0.1981277352418271 + -0.19172981130154146 * output_0 + 0.005799876636229329 * output_1 + -0.039074100087084604 * output_2 + 0.11328702483860431 * output_3 + 0.11022735289425412 * output_4 + 0.13282353031327188 * output_5 + 0.09353893217318798 * output_6 + -0.026404699854199624 * output_7 + -0.001961360547764432 * output_8 + 0.19779190863297358 * output_9 + 0.1778911895314293 * output_10 + 0.21455121758104287 * output_11 + 0.2077611643560709 * output_12 + 0.19125767860778958 * output_13 + 0.0738801276104458 * output_14 };
# 			lTable["output_1"] = { -0.08136982023587075 + -0.015984967282158258 * output_0 + -0.20506224991086827 * output_1 + 0.1621241575859242 * output_2 + 0.04160752684283984 * output_3 + 0.14147614840853506 * output_4 + -0.13323801476156316 * output_5 + 0.013708854430655781 * output_6 + 0.0800117443381224 * output_7 + 0.2413488050023971 * output_8 + 0.24566328294115403 * output_9 + -0.2432631919142624 * output_10 + -0.16127719409421853 * output_11 + 0.24992947040763402 * output_12 + -0.10628474878353641 * output_13 + -0.20207511581006543 * output_14 };
# 			lTable["output_2"] = { -0.04887281908614515 + -0.0633478947872688 * output_0 + 0.11209453229143235 * output_1 + -0.10878873940847915 * output_2 + 0.04236949069535695 * output_3 + -0.1242710609018385 * output_4 + -0.23300159865268819 * output_5 + 0.016049693863309733 * output_6 + 0.04509436435371665 * output_7 + 0.2522515002807603 * output_8 + -0.08590403909617114 * output_9 + -0.06701612091450629 * output_10 + 0.11934694440142611 * output_11 + 0.228103160593029 * output_12 + 0.19536055206647746 * output_13 + 0.22333180800486818 * output_14 };
# 			lTable["output_26"] = { 0.1087395985826527 + -0.22237665540076074 * output_0 + -0.17651880822748356 * output_1 + -0.02726105320747602 * output_2 + 0.12309655125437842 * output_3 + 0.19655687055601143 * output_4 + 0.027202356879711564 * output_5 + -0.01833329088433247 * output_6 + -0.244429819158018 * output_7 + 0.1244358090412339 * output_8 + 0.11348997215770024 * output_9 + -0.12477816539217584 * output_10 + 0.05339835540628856 * output_11 + -0.13849845082427703 * output_12 + 0.17516243064707793 * output_13 + 0.0031535678328788973 * output_14 };
# 			lTable["output_27"] = { 0.25299158597359417 + 0.19758778590606618 * output_0 + 0.12266945088135123 * output_1 + 0.2290734451693437 * output_2 + -0.14785594392211399 * output_3 + -0.016845777872003007 * output_4 + -0.24501862381124345 * output_5 + -0.08468733011790197 * output_6 + -0.2190036370228152 * output_7 + 0.24782504187211535 * output_8 + -0.033909201894434915 * output_9 + -0.13121183972904776 * output_10 + -0.19172516433448364 * output_11 + 0.021227149708440474 * output_12 + 0.1784535123847647 * output_13 + -0.19863928789092333 * output_14 };
# 			lTable["output_28"] = { -0.024156964692770906 + 0.24787259292352437 * output_0 + -0.03632309937342182 * output_1 + 0.23045779929893342 * output_2 + 0.18649414994572813 * output_3 + -0.22504381601964596 * output_4 + -0.08675910903513256 * output_5 + -0.09999033227306536 * output_6 + -0.15759250652094606 * output_7 + 0.2616272989031926 * output_8 + 0.09384492022246915 * output_9 + 0.10465361598012735 * output_10 + 0.12804648570148972 * output_11 + -0.09628284992127858 * output_12 + -0.24593698844496872 * output_13 + -0.10593968373177759 * output_14 };
# 			lTable["output_29"] = { 0.1855821542080191 + -0.24976690211051017 * output_0 + -0.05274852379202799 * output_1 + 0.07716661803932082 * output_2 + -0.08691778265361763 * output_3 + 0.2564600542715595 * output_4 + -0.0008293923218515298 * output_5 + 0.16709192901315217 * output_6 + -0.0336890803124648 * output_7 + -0.16426383014353954 * output_8 + 0.05475942725167454 * output_9 + -0.019510541651285546 * output_10 + 0.15155631178401457 * output_11 + 0.11703037039318598 * output_12 + 0.16923114780429843 * output_13 + -0.03565106336733097 * output_14 };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("output_0")[0], iTable.at("output_1")[0], iTable.at("output_2")[0], iTable.at("output_3")[0], iTable.at("output_4")[0], iTable.at("output_5")[0], iTable.at("output_6")[0], iTable.at("output_7")[0], iTable.at("output_8")[0], iTable.at("output_9")[0], iTable.at("output_10")[0], iTable.at("output_11")[0], iTable.at("output_12")[0], iTable.at("output_13")[0], iTable.at("output_14")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace layer_3
#
#
# 	namespace layer_4 {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14", "output_15", "output_16", "output_17", "output_18", "output_19", "output_20", "output_21", "output_22", "output_23", "output_24", "output_25", "output_26", "output_27", "output_28", "output_29" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14", "output_15", "output_16", "output_17", "output_18", "output_19", "output_20", "output_21", "output_22", "output_23", "output_24", "output_25", "output_26", "output_27", "output_28", "output_29" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any output_0, std::any output_1, std::any output_2, std::any output_3, std::any output_4, std::any output_5, std::any output_6, std::any output_7, std::any output_8, std::any output_9, std::any output_10, std::any output_11, std::any output_12, std::any output_13, std::any output_14, std::any output_15, std::any output_16, std::any output_17, std::any output_18, std::any output_19, std::any output_20, std::any output_21, std::any output_22, std::any output_23, std::any output_24, std::any output_25, std::any output_26, std::any output_27, std::any output_28, std::any output_29) {
#
# 			tTable lTable;
#
# 			lTable["output_0"] = { output_0 };
# 			lTable["output_1"] = { output_1 };
# 			lTable["output_2"] = { output_2 };
# 			lTable["output_3"] = { output_3 };
# 			lTable["output_4"] = { output_4 };
# 			lTable["output_5"] = { output_5 };
# 			lTable["output_6"] = { output_6 };
# 			lTable["output_7"] = { output_7 };
# 			lTable["output_8"] = { output_8 };
# 			lTable["output_9"] = { output_9 };
# 			lTable["output_10"] = { output_10 };
# 			lTable["output_11"] = { output_11 };
# 			lTable["output_12"] = { output_12 };
# 			lTable["output_13"] = { output_13 };
# 			lTable["output_14"] = { output_14 };
# 			lTable["output_15"] = { output_15 };
# 			lTable["output_16"] = { output_16 };
# 			lTable["output_17"] = { output_17 };
# 			lTable["output_18"] = { output_18 };
# 			lTable["output_19"] = { output_19 };
# 			lTable["output_20"] = { output_20 };
# 			lTable["output_21"] = { output_21 };
# 			lTable["output_22"] = { output_22 };
# 			lTable["output_23"] = { output_23 };
# 			lTable["output_24"] = { output_24 };
# 			lTable["output_25"] = { output_25 };
# 			lTable["output_26"] = { output_26 };
# 			lTable["output_27"] = { output_27 };
# 			lTable["output_28"] = { output_28 };
# 			lTable["output_29"] = { output_29 };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("output_0")[0], iTable.at("output_1")[0], iTable.at("output_2")[0], iTable.at("output_3")[0], iTable.at("output_4")[0], iTable.at("output_5")[0], iTable.at("output_6")[0], iTable.at("output_7")[0], iTable.at("output_8")[0], iTable.at("output_9")[0], iTable.at("output_10")[0], iTable.at("output_11")[0], iTable.at("output_12")[0], iTable.at("output_13")[0], iTable.at("output_14")[0], iTable.at("output_15")[0], iTable.at("output_16")[0], iTable.at("output_17")[0], iTable.at("output_18")[0], iTable.at("output_19")[0], iTable.at("output_20")[0], iTable.at("output_21")[0], iTable.at("output_22")[0], iTable.at("output_23")[0], iTable.at("output_24")[0], iTable.at("output_25")[0], iTable.at("output_26")[0], iTable.at("output_27")[0], iTable.at("output_28")[0], iTable.at("output_29")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace layer_4
#
#
# 	namespace layer_5 {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14", "output_15", "output_16", "output_17", "output_18", "output_19", "output_20", "output_21", "output_22", "output_23", "output_24", "output_25", "output_26", "output_27", "output_28", "output_29" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14", "output_15", "output_16", "output_17", "output_18", "output_19", "output_20", "output_21", "output_22", "output_23", "output_24", "output_25", "output_26", "output_27", "output_28", "output_29" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any output_0, std::any output_1, std::any output_2, std::any output_3, std::any output_4, std::any output_5, std::any output_6, std::any output_7, std::any output_8, std::any output_9, std::any output_10, std::any output_11, std::any output_12, std::any output_13, std::any output_14, std::any output_15, std::any output_16, std::any output_17, std::any output_18, std::any output_19, std::any output_20, std::any output_21, std::any output_22, std::any output_23, std::any output_24, std::any output_25, std::any output_26, std::any output_27, std::any output_28, std::any output_29) {
#
# 			tTable lTable;
#
# 			lTable["output_0"] = { hardshrink(output_0) };
# 			lTable["output_1"] = { hardshrink(output_1) };
# 			lTable["output_2"] = { hardshrink(output_2) };
# 			lTable["output_3"] = { hardshrink(output_3) };
# 			lTable["output_4"] = { hardshrink(output_4) };
# 			lTable["output_5"] = { hardshrink(output_5) };
# 			lTable["output_6"] = { hardshrink(output_6) };
# 			lTable["output_7"] = { hardshrink(output_7) };
# 			lTable["output_8"] = { hardshrink(output_8) };
# 			lTable["output_9"] = { hardshrink(output_9) };
# 			lTable["output_10"] = { hardshrink(output_10) };
# 			lTable["output_11"] = { hardshrink(output_11) };
# 			lTable["output_12"] = { hardshrink(output_12) };
# 			lTable["output_13"] = { hardshrink(output_13) };
# 			lTable["output_14"] = { hardshrink(output_14) };
# 			lTable["output_15"] = { hardshrink(output_15) };
# 			lTable["output_16"] = { hardshrink(output_16) };
# 			lTable["output_17"] = { hardshrink(output_17) };
# 			lTable["output_18"] = { hardshrink(output_18) };
# 			lTable["output_19"] = { hardshrink(output_19) };
# 			lTable["output_20"] = { hardshrink(output_20) };
# 			lTable["output_21"] = { hardshrink(output_21) };
# 			lTable["output_22"] = { hardshrink(output_22) };
# 			lTable["output_23"] = { hardshrink(output_23) };
# 			lTable["output_24"] = { hardshrink(output_24) };
# 			lTable["output_25"] = { hardshrink(output_25) };
# 			lTable["output_26"] = { hardshrink(output_26) };
# 			lTable["output_27"] = { hardshrink(output_27) };
# 			lTable["output_28"] = { hardshrink(output_28) };
# 			lTable["output_29"] = { hardshrink(output_29) };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("output_0")[0], iTable.at("output_1")[0], iTable.at("output_2")[0], iTable.at("output_3")[0], iTable.at("output_4")[0], iTable.at("output_5")[0], iTable.at("output_6")[0], iTable.at("output_7")[0], iTable.at("output_8")[0], iTable.at("output_9")[0], iTable.at("output_10")[0], iTable.at("output_11")[0], iTable.at("output_12")[0], iTable.at("output_13")[0], iTable.at("output_14")[0], iTable.at("output_15")[0], iTable.at("output_16")[0], iTable.at("output_17")[0], iTable.at("output_18")[0], iTable.at("output_19")[0], iTable.at("output_20")[0], iTable.at("output_21")[0], iTable.at("output_22")[0], iTable.at("output_23")[0], iTable.at("output_24")[0], iTable.at("output_25")[0], iTable.at("output_26")[0], iTable.at("output_27")[0], iTable.at("output_28")[0], iTable.at("output_29")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace layer_5
#
#
# 	namespace layer_6 {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "output_0", "output_1", "output_2", "output_3", "output_4", "output_5", "output_6", "output_7", "output_8", "output_9", "output_10", "output_11", "output_12", "output_13", "output_14", "output_15", "output_16", "output_17", "output_18", "output_19", "output_20", "output_21", "output_22", "output_23", "output_24", "output_25", "output_26", "output_27", "output_28", "output_29" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "output_0", "output_1", "output_2" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any output_0, std::any output_1, std::any output_2, std::any output_3, std::any output_4, std::any output_5, std::any output_6, std::any output_7, std::any output_8, std::any output_9, std::any output_10, std::any output_11, std::any output_12, std::any output_13, std::any output_14, std::any output_15, std::any output_16, std::any output_17, std::any output_18, std::any output_19, std::any output_20, std::any output_21, std::any output_22, std::any output_23, std::any output_24, std::any output_25, std::any output_26, std::any output_27, std::any output_28, std::any output_29) {
#
# 			tTable lTable;
#
# 			lTable["output_0"] = { 0.054448181026203746 + 0.09896837873227085 * output_0 + 0.11538351389756919 * output_1 + -0.08054873296304244 * output_2 + -0.14170411079141704 * output_3 + 0.07556829510941565 * output_4 + 0.15121216356939587 * output_5 + 0.15958815793989778 * output_6 + -0.009137959692217222 * output_7 + -0.06097301847127765 * output_8 + -0.04794463973612288 * output_9 + 0.13154460539860527 * output_10 + -0.027757754376230043 * output_11 + 0.0802793476290629 * output_12 + -0.1451186930797832 * output_13 + -0.13031428720020444 * output_14 + 0.023089518372226565 * output_15 + 0.10429309401439651 * output_16 + 0.14329470730117783 * output_17 + -0.22629718227191312 * output_18 + -0.09288658501965143 * output_19 + 0.02300054509265247 * output_20 + 0.05341583207959417 * output_21 + -0.010464018433695828 * output_22 + -0.012139199670275418 * output_23 + -0.15711633050333415 * output_24 + -0.1249693255091637 * output_25 + 0.09383423248991743 * output_26 + 0.1538761636545581 * output_27 + 0.009570885485873783 * output_28 + -0.08722202212191286 * output_29 };
# 			lTable["output_1"] = { -0.09151974291213612 + 0.144317460007181 * output_0 + -0.016163761682668604 * output_1 + -0.04461965696269799 * output_2 + 0.0042655888939509435 * output_3 + 0.14124670816410514 * output_4 + -0.09974188483236601 * output_5 + -0.13042038206419826 * output_6 + -0.09041557553711901 * output_7 + -0.0007047774662534197 * output_8 + 0.07630922541928215 * output_9 + -0.1711577492422826 * output_10 + -0.0850558608955134 * output_11 + 0.11560187199104134 * output_12 + 0.080848947725742 * output_13 + 0.07352465894338459 * output_14 + -0.04768780963681077 * output_15 + 0.07462807158878597 * output_16 + -0.02269724032622802 * output_17 + -0.08986057606000902 * output_18 + 0.035125111698876506 * output_19 + -0.042374229831024096 * output_20 + -0.010746202950663593 * output_21 + -0.03264649733591394 * output_22 + 0.01926392042163378 * output_23 + 0.04651217941155773 * output_24 + -0.11269230159019127 * output_25 + -0.08590015097675874 * output_26 + 0.05406061701766186 * output_27 + -0.11339805034140765 * output_28 + 0.031909022869823604 * output_29 };
# 			lTable["output_2"] = { -0.016807750798464412 + 0.11530700732659864 * output_0 + -0.07586439160709506 * output_1 + 0.009282651936649653 * output_2 + 0.19446115400559258 * output_3 + 0.12498572387525742 * output_4 + -0.13248419640174636 * output_5 + -0.1807019426938199 * output_6 + -0.05276475099305779 * output_7 + 0.024170125056324994 * output_8 + -0.07057776195376918 * output_9 + -0.025784577568430875 * output_10 + -0.04957372367789166 * output_11 + -0.0256400530869965 * output_12 + 0.0830016159467619 * output_13 + -0.11067880396449509 * output_14 + -0.1446002083206868 * output_15 + -0.012847417028184809 * output_16 + -0.09012245769185175 * output_17 + -0.017749237706985388 * output_18 + -0.023837148456272165 * output_19 + 0.003866994798824475 * output_20 + -0.03268348798431412 * output_21 + -0.07509760301393324 * output_22 + -0.15975636293637852 * output_23 + 0.11441879248891731 * output_24 + -0.08482114892947443 * output_25 + 0.03748076949346366 * output_26 + 0.1266364507805715 * output_27 + 0.045512465755929946 * output_28 + 0.16887168565503213 * output_29 };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("output_0")[0], iTable.at("output_1")[0], iTable.at("output_2")[0], iTable.at("output_3")[0], iTable.at("output_4")[0], iTable.at("output_5")[0], iTable.at("output_6")[0], iTable.at("output_7")[0], iTable.at("output_8")[0], iTable.at("output_9")[0], iTable.at("output_10")[0], iTable.at("output_11")[0], iTable.at("output_12")[0], iTable.at("output_13")[0], iTable.at("output_14")[0], iTable.at("output_15")[0], iTable.at("output_16")[0], iTable.at("output_17")[0], iTable.at("output_18")[0], iTable.at("output_19")[0], iTable.at("output_20")[0], iTable.at("output_21")[0], iTable.at("output_22")[0], iTable.at("output_23")[0], iTable.at("output_24")[0], iTable.at("output_25")[0], iTable.at("output_26")[0], iTable.at("output_27")[0], iTable.at("output_28")[0], iTable.at("output_29")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace layer_6
#
#
# 	namespace layer_7 {
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "output_0", "output_1", "output_2" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "output_0", "output_1", "output_2" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_features(std::any output_0, std::any output_1, std::any output_2) {
#
# 			tTable lTable;
#
# 			lTable["output_0"] = { output_0 };
# 			lTable["output_1"] = { output_1 };
# 			lTable["output_2"] = { output_2 };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_features(iTable.at("output_0")[0], iTable.at("output_1")[0], iTable.at("output_2")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace layer_7
#
#
# 	std::vector<std::string> get_input_names(){
# 		std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 		return lFeatures;
# 	}
#
# 	std::vector<std::string> get_output_names(){
# 		std::vector<std::string> lOutputs = {
# 			"Score_0", "Score_1", "Score_2",
# 			"Proba_0", "Proba_1", "Proba_2",
# 			"LogProba_0", "LogProba_1", "LogProba_2",
# 			"Decision", "DecisionProba" };
#
# 		return lOutputs;
# 	}
#
# 	tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 		auto lClasses = get_classes();
#
# 		tTable lTable_layer_0 = layer_0::compute_features(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 		tTable lTable_layer_1 = layer_1::compute_model_outputs_from_table( lTable_layer_0 );
#
# 		tTable lTable_layer_2 = layer_2::compute_model_outputs_from_table( lTable_layer_1 );
#
# 		tTable lTable_layer_3 = layer_3::compute_model_outputs_from_table( lTable_layer_2 );
#
# 		tTable lTable_layer_4 = layer_4::compute_model_outputs_from_table( lTable_layer_3 );
#
# 		tTable lTable_layer_5 = layer_5::compute_model_outputs_from_table( lTable_layer_4 );
#
# 		tTable lTable_layer_6 = layer_6::compute_model_outputs_from_table( lTable_layer_5 );
#
# 		tTable lTable_layer_7 = layer_7::compute_model_outputs_from_table( lTable_layer_6 );
#
# 		tTable lScores = tTable();
#
# 		lScores["Score"] = { lTable_layer_7["output_0"][0], lTable_layer_7["output_1"][0], lTable_layer_7["output_2"][0] };
#
# 		lScores["Proba"] = { std::any(), std::any(), std::any() };
#
# 		tTable lSoftMaxTable = soft_max( lScores);
#
#
# 		tTable lTable = lSoftMaxTable;
#
# 		int lBestClass = get_arg_max( lTable["Proba"] );
# 		auto lDecision = lClasses[lBestClass];
# 		lTable["Decision"] = { lDecision } ;
# 		lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 		recompute_log_probas( lTable );
#
# 		return lTable;
# 	}
#
# 	tTable compute_model_outputs_from_table( tTable const & iTable) {
# 		tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 		return lTable;
# 	}
#
# } // eof namespace

# %%
    def write_text_to_file(iCPPCode, oCPPFile):          
        with open(oCPPFile, "w") as text_file:
            text_file.write(iCPPCode)

    def add_cpp_main_function(iCPPCode, iCSVFile):
        lCPPCode = "#include \"Generic.i\"\n\n"
        lCPPCode = lCPPCode + iCPPCode
        lCPPCode = lCPPCode + "\tint main() {\n"
        lCPPCode = lCPPCode + "\t\tscore_csv_file(\"" + iCSVFile +"\");\n"
        lCPPCode = lCPPCode + "\treturn 0;\n}\n"
        return lCPPCode

    def compile_cpp_code_as_executable(iName):
        import subprocess
        lCommand = ["g++", "-Wall", "-Wno-unused-function", "-std=c++17" , "-g" ,  "-o", iName + ".exe",  iName + ".cpp"]
        print("EXECUTING" , "'" + " ".join(lCommand) + "'")
        result = subprocess.check_output(lCommand)
        # print(result)

    def execute_cpp_model(iName, iCSVFile):
        import subprocess
        result2 = subprocess.check_output([iName + ".exe",  iCSVFile])
        result2 = result2.decode()
        print(result2[:1000])
        print(result2[-1000:])
        return result2
        
    def execute_cpp_code(iCPPCode, iCSVFile):
        lName = "/tmp/sklearn2sql_cpp_" + str(id(clf));
        lCPPCode = add_cpp_main_function(iCPPCode, iCSVFile)
        write_text_to_file(lCPPCode, lName + ".cpp")
        compile_cpp_code_as_executable(lName)
        result = execute_cpp_model(lName, iCSVFile)
        write_text_to_file(str(result), lName + ".out")
        return lName + ".out"

# %%
populate_table("/tmp/iris2.csv" , ["Feature_0", "Feature_1", "Feature_2", "Feature_3"])
lCPPOutput = execute_cpp_code(lCPPCode , "/tmp/iris2.csv")
cpp_output = pd.read_csv(lCPPOutput)
# Out:
# EXECUTING 'g++ -Wall -Wno-unused-function -std=c++17 -g -o /tmp/sklearn2sql_cpp_140025616790960.exe /tmp/sklearn2sql_cpp_140025616790960.cpp'
# idx,Score_0,Score_1,Score_2,Proba_0,Proba_1,Proba_2,LogProba_0,LogProba_1,LogProba_2,Decision,DecisionProba
# 0,,,,0.45019637268157,0.30069463258808,0.24910899473035,-0.79807140766864,-1.20166003887067,-1.38986474845242,0,0.45019637268157
# 1,,,,0.43615671867620,0.30582560886671,0.25801767245709,-0.82975365371348,-1.18474024515206,-1.35472719851069,0,0.43615671867620
# 2,,,,0.45033926969533,0.29348284744739,0.25617788285728,-0.79775404762594,-1.22593608282759,-1.36188322089122,0,0.45033926969533
# 3,,,,0.43990095721080,0.29669170360601,0.26340733918320,-0.82120567465621,-1.21506171430750,-1.33405362679918,0,0.43990095721080
# 4,,,,0.45549589055204,0.28307489364809,0.26142921579986,-0.78636858416246,-1.26204377448433,-1.34159171739680,0,0.45549589055204
skl_outputs = pd.DataFrame()
X = df[metadata['features']].values
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['idx']);

skl_output_score = pd.DataFrame(columns=['Score_0', 'Score_1', 'Score_2']);
skl_output_proba = pd.DataFrame(clf.predict_proba(X), columns=['Proba_0', 'Proba_1', 'Proba_2'])
skl_output_log_proba = pd.DataFrame(columns=['LogProba_0', 'LogProba_1', 'LogProba_2'])
skl_output_decision = pd.DataFrame(clf.predict(X), columns=['Decision'])
skl_output = pd.concat([skl_output_key, skl_output_score, skl_output_proba, skl_output_log_proba, skl_output_decision] , axis=1)
skl_output.sample(12, random_state=1960)
# Out:
# /home/antoine/.local/lib/python3.8/site-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
#      idx Score_0 Score_1 Score_2   Proba_0   Proba_1   Proba_2 LogProba_0  \
# 114  114     NaN     NaN     NaN  0.178223  0.396729  0.425048        NaN
# 74    74     NaN     NaN     NaN  0.224922  0.387287  0.387791        NaN
# 9      9     NaN     NaN     NaN  0.434680  0.306157  0.259163        NaN
# 88    88     NaN     NaN     NaN  0.217610  0.385556  0.396834        NaN
# 25    25     NaN     NaN     NaN  0.428909  0.309034  0.262057        NaN
# 5      5     NaN     NaN     NaN  0.448880  0.292971  0.258149        NaN
# 48    48     NaN     NaN     NaN  0.450293  0.292024  0.257683        NaN
# 117  117     NaN     NaN     NaN  0.103386  0.486306  0.410308        NaN
# 83    83     NaN     NaN     NaN  0.176137  0.418436  0.405427        NaN
# 105  105     NaN     NaN     NaN  0.101550  0.479929  0.418521        NaN
# 27    27     NaN     NaN     NaN  0.448079  0.302051  0.249870        NaN
# 64    64     NaN     NaN     NaN  0.251009  0.372099  0.376892        NaN
#
#     LogProba_1 LogProba_2  Decision
# 114        NaN        NaN         2
# 74         NaN        NaN         2
# 9          NaN        NaN         0
# 88         NaN        NaN         2
# 25         NaN        NaN         0
# 5          NaN        NaN         0
# 48         NaN        NaN         0
# 117        NaN        NaN         1
# 83         NaN        NaN         1
# 105        NaN        NaN         1
# 27         NaN        NaN         0
# 64         NaN        NaN         2

# %%
cpp_skl_join = skl_output.join(cpp_output , how='left', on='idx', lsuffix='_skl', rsuffix='_cpp')

# %%
cpp_skl_join.sample(12, random_state=1960)
# Out:
#      idx_skl Score_0_skl Score_1_skl Score_2_skl  Proba_0_skl  Proba_1_skl  \
# 114      114         NaN         NaN         NaN     0.178223     0.396729
# 74        74         NaN         NaN         NaN     0.224922     0.387287
# 9          9         NaN         NaN         NaN     0.434680     0.306157
# 88        88         NaN         NaN         NaN     0.217610     0.385556
# 25        25         NaN         NaN         NaN     0.428909     0.309034
# 5          5         NaN         NaN         NaN     0.448880     0.292971
# 48        48         NaN         NaN         NaN     0.450293     0.292024
# 117      117         NaN         NaN         NaN     0.103386     0.486306
# 83        83         NaN         NaN         NaN     0.176137     0.418436
# 105      105         NaN         NaN         NaN     0.101550     0.479929
# 27        27         NaN         NaN         NaN     0.448079     0.302051
# 64        64         NaN         NaN         NaN     0.251009     0.372099
#
#      Proba_2_skl LogProba_0_skl LogProba_1_skl LogProba_2_skl  ...  \
# 114     0.425048            NaN            NaN            NaN  ...
# 74      0.387791            NaN            NaN            NaN  ...
# 9       0.259163            NaN            NaN            NaN  ...
# 88      0.396834            NaN            NaN            NaN  ...
# 25      0.262057            NaN            NaN            NaN  ...
# 5       0.258149            NaN            NaN            NaN  ...
# 48      0.257683            NaN            NaN            NaN  ...
# 117     0.410308            NaN            NaN            NaN  ...
# 83      0.405427            NaN            NaN            NaN  ...
# 105     0.418521            NaN            NaN            NaN  ...
# 27      0.249870            NaN            NaN            NaN  ...
# 64      0.376892            NaN            NaN            NaN  ...
#
#      Score_1_cpp  Score_2_cpp  Proba_0_cpp  Proba_1_cpp  Proba_2_cpp  \
# 114          NaN          NaN     0.178223     0.396729     0.425048
# 74           NaN          NaN     0.224922     0.387287     0.387791
# 9            NaN          NaN     0.434680     0.306157     0.259163
# 88           NaN          NaN     0.217610     0.385556     0.396834
# 25           NaN          NaN     0.428909     0.309034     0.262057
# 5            NaN          NaN     0.448880     0.292971     0.258149
# 48           NaN          NaN     0.450293     0.292024     0.257683
# 117          NaN          NaN     0.103386     0.486306     0.410308
# 83           NaN          NaN     0.176137     0.418436     0.405427
# 105          NaN          NaN     0.101550     0.479929     0.418521
# 27           NaN          NaN     0.448079     0.302051     0.249870
# 64           NaN          NaN     0.251009     0.372099     0.376892
#
#      LogProba_0_cpp  LogProba_1_cpp  LogProba_2_cpp  Decision_cpp  \
# 114       -1.724719       -0.924501       -0.855554             2
# 74        -1.492002       -0.948589       -0.947289             2
# 9         -0.833145       -1.183657       -1.350299             0
# 88        -1.525051       -0.953069       -0.924237             2
# 25        -0.846511       -1.174303       -1.339193             0
# 5         -0.801000       -1.227680       -1.354220             0
# 48        -0.797857       -1.230920       -1.356024             0
# 117       -2.269290       -0.720917       -0.890846             1
# 83        -1.736494       -0.871230       -0.902815             1
# 105       -2.287208       -0.734117       -0.871028             1
# 27        -0.802786       -1.197158       -1.386814             0
# 64        -1.382268       -0.988595       -0.975796             2
#
#      DecisionProba
# 114       0.425048
# 74        0.387791
# 9         0.434680
# 88        0.396834
# 25        0.428909
# 5         0.448880
# 48        0.450293
# 117       0.486306
# 83        0.418436
# 105       0.479929
# 27        0.448079
# 64        0.376892
#
# [12 rows x 23 columns]

# %%
condition = (cpp_skl_join.Decision_cpp != cpp_skl_join.Decision_skl)
cpp_skl_join[condition]
# Out:
# Empty DataFrame
# Columns: [idx_skl, Score_0_skl, Score_1_skl, Score_2_skl, Proba_0_skl, Proba_1_skl, Proba_2_skl, LogProba_0_skl, LogProba_1_skl, LogProba_2_skl, Decision_skl, idx_cpp, Score_0_cpp, Score_1_cpp, Score_2_cpp, Proba_0_cpp, Proba_1_cpp, Proba_2_cpp, LogProba_0_cpp, LogProba_1_cpp, LogProba_2_cpp, Decision_cpp, DecisionProba]
# Index: []
#
# [0 rows x 23 columns]
