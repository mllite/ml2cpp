# %% [markdown]
# # ML2CPP

# %% [markdown]
# ## Preparing the dataset

# %%
from sklearn import datasets
import numpy as np
import pandas as pd

boston = datasets.load_boston()

def populate_table(tablename, feature_names):
    X = boston.data  
    y = boston.target
    N = X.shape[0]
    y = y.reshape(N,1)
    k = np.arange(N).reshape(N, 1)
    k_X_y = np.concatenate((k, X, y) , axis=1)
    lTable=pd.DataFrame(k_X_y)
    # print(lTable.head())
    lTable.columns = ['idx'] + feature_names + ['TGT'];
    lTable['TGT'] = lTable['TGT'].apply(int)
    lTable['idx'] = lTable['idx'].apply(int)
    lTable.to_csv(tablename , float_format='%.14g')

# %%
metadata = {"primary_key" : "KEY",
            "features" : list(boston.feature_names),
            "targets" : ["TGT"],
            "table" : "iris"}

# %%
populate_table("/tmp/boston.csv" , metadata["features"])

# %%
df = pd.read_csv("/tmp/boston.csv")
df.sample(12, random_state=1960)
# Out:
#      Unnamed: 0  idx      CRIM    ZN  INDUS  CHAS    NOX     RM    AGE  \
# 230         230  230   0.53700   0.0   6.20     0  0.504  5.981   68.1
# 112         112  112   0.12329   0.0  10.01     0  0.547  5.913   92.9
# 125         125  125   0.16902   0.0  25.65     0  0.581  5.986   88.4
# 9             9    9   0.17004  12.5   7.87     0  0.524  6.004   85.9
# 213         213  213   0.14052   0.0  10.59     0  0.489  6.375   32.3
# 109         109  109   0.26363   0.0   8.56     0  0.520  6.229   91.2
# 127         127  127   0.25915   0.0  21.89     0  0.624  5.693   96.0
# 244         244  244   0.20608  22.0   5.86     0  0.431  5.593   76.5
# 406         406  406  20.71620   0.0  18.10     0  0.659  4.138  100.0
# 490         490  490   0.20746   0.0  27.74     0  0.609  5.093   98.0
# 245         245  245   0.19133  22.0   5.86     0  0.431  5.605   70.2
# 133         133  133   0.32982   0.0  21.89     0  0.624  5.822   95.4
#
#         DIS  RAD  TAX  PTRATIO       B  LSTAT  TGT
# 230  3.6715    8  307     17.4  378.35  11.65   24
# 112  2.3534    6  432     17.8  394.95  16.21   18
# 125  1.9929    2  188     19.1  385.02  14.81   21
# 9    6.5921    5  311     15.2  386.71  17.10   18
# 213  3.9454    4  277     18.6  385.81   9.38   28
# 109  2.5451    5  384     20.9  391.23  15.55   19
# 127  1.7883    4  437     21.2  392.11  17.19   16
# 244  7.9549    7  330     19.1  372.49  12.50   17
# 406  1.1781   24  666     20.2  370.22  23.34   11
# 490  1.8226    4  711     20.1  318.43  29.68    8
# 245  7.9549    7  330     19.1  389.13  18.46   18
# 133  2.4699    4  437     21.2  388.69  15.03   18

# %% [markdown]
# ## Training a Model

# %%
# train any scikit model on the iris dataset
from sklearn.ensemble import ExtraTreesRegressor
clf = ExtraTreesRegressor(n_estimators = 32, max_depth=4, random_state=1960)
clf.fit(df[metadata['features']].values, df[metadata['targets']].values)
# Out:
# <ipython-input-5-57e59ad8a6bb>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(df[metadata['features']].values, df[metadata['targets']].values)
# ExtraTreesRegressor(max_depth=4, n_estimators=32, random_state=1960)

# %% [markdown]
# ## Deploying the Model

# %%
def generate_cpp_for_model(model):
    import pickle, json, requests, base64
    b64_data = base64.b64encode(pickle.dumps(model)).decode('utf-8')
    # send the model th the web service
    json_data={"Name":"model_cpp_sample", 
               "PickleData":b64_data , 
               "SQLDialect":"CPP",
               "FeatureNames" : metadata['features']}
    r = requests.post("https://sklearn2sql.herokuapp.com/model", json=json_data)
    content = r.json()
    lCPP = content["model"]["SQLGenrationResult"][0]["SQL"]
    # print(lCPP);
    return lCPP


lCPPCode = generate_cpp_for_model(clf);

# %%
print(lCPPCode)
# Out:
# namespace  {
#
# 	namespace EXT_SubModel_0 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {23.25 }} ,
# 				{ 5 ,  {38.5 }} ,
# 				{ 7 ,  {29.06666667 }} ,
# 				{ 8 ,  {39.6 }} ,
# 				{ 11 ,  {18.75925926 }} ,
# 				{ 12 ,  {21.5952381 }} ,
# 				{ 14 ,  {17.28037383 }} ,
# 				{ 15 ,  {12.53030303 }} ,
# 				{ 19 ,  {32. }} ,
# 				{ 20 ,  {44.4 }} ,
# 				{ 22 ,  {45.1 }} ,
# 				{ 23 ,  {49.5 }} ,
# 				{ 25 ,  {21. }} ,
# 				{ 26 ,  {17. }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 7.3545654987914615) ? ( (Feature_12 <= 7.764249281410326) ? ( (Feature_5 <= 6.446660354177247) ? ( (Feature_8 <= 22.348256264975415) ? ( 4 ) : ( 5 ) ) : ( (Feature_3 <= 0.5227563253244182) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_2 <= 15.622063856949534) ? ( (Feature_5 <= 5.886226273766936) ? ( 11 ) : ( 12 ) ) : ( (Feature_0 <= 9.101715305804424) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_9 <= 603.6862074801168) ? ( (Feature_5 <= 7.628667089554094) ? ( (Feature_5 <= 7.42293940954389) ? ( 19 ) : ( 20 ) ) : ( (Feature_1 <= 48.18073167613741) ? ( 22 ) : ( 23 ) ) ) : ( (Feature_12 <= 9.946354345248515) ? ( 25 ) : ( 26 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_0
#
#
# 	namespace EXT_SubModel_1 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {30. }} ,
# 				{ 5 ,  {45.8 }} ,
# 				{ 7 ,  {23.13559322 }} ,
# 				{ 8 ,  {15.46666667 }} ,
# 				{ 11 ,  {50. }} ,
# 				{ 12 ,  {49. }} ,
# 				{ 14 ,  {47.33333333 }} ,
# 				{ 15 ,  {39. }} ,
# 				{ 19 ,  {26.5 }} ,
# 				{ 20 ,  {35.85714286 }} ,
# 				{ 21 ,  {50. }} ,
# 				{ 24 ,  {29.25 }} ,
# 				{ 25 ,  {21.67320261 }} ,
# 				{ 27 ,  {19.11111111 }} ,
# 				{ 28 ,  {13.2519084 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_10 <= 17.76612335971742) ? ( (Feature_5 <= 7.841621475086362) ? ( (Feature_12 <= 7.5078176669126755) ? ( (Feature_5 <= 7.55897102965773) ? ( 4 ) : ( 5 ) ) : ( (Feature_4 <= 0.8230656767290847) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_10 <= 17.387994551762528) ? ( (Feature_12 <= 3.707380837300628) ? ( 11 ) : ( 12 ) ) : ( (Feature_11 <= 385.7071428077273) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_12 <= 4.104057275177343) ? ( (Feature_9 <= 648.1493877238358) ? ( (Feature_11 <= 389.7814836630861) ? ( 19 ) : ( 20 ) ) : ( 21 ) ) : ( (Feature_12 <= 14.32447229820902) ? ( (Feature_2 <= 3.80989092913871) ? ( 24 ) : ( 25 ) ) : ( (Feature_10 <= 19.241698371106672) ? ( 27 ) : ( 28 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_1
#
#
# 	namespace EXT_SubModel_2 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {19.76086957 }} ,
# 				{ 5 ,  {22.2 }} ,
# 				{ 7 ,  {14. }} ,
# 				{ 8 ,  {16. }} ,
# 				{ 11 ,  {23.55555556 }} ,
# 				{ 12 ,  {30.66666667 }} ,
# 				{ 14 ,  {49.6 }} ,
# 				{ 15 ,  {43.76470588 }} ,
# 				{ 19 ,  {50. }} ,
# 				{ 20 ,  {25.5 }} ,
# 				{ 22 ,  {18.87383178 }} ,
# 				{ 23 ,  {12.65714286 }} ,
# 				{ 26 ,  {19. }} ,
# 				{ 27 ,  {15. }} ,
# 				{ 29 ,  {12. }} ,
# 				{ 30 ,  {8.7826087 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_2 <= 7.461324460215486) ? ( (Feature_5 <= 6.112523323367855) ? ( (Feature_6 <= 91.5045037651071) ? ( (Feature_5 <= 6.080139290946562) ? ( 4 ) : ( 5 ) ) : ( (Feature_1 <= 11.475848074292694) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_5 <= 7.560132374529902) ? ( (Feature_5 <= 6.560450158302634) ? ( 11 ) : ( 12 ) ) : ( (Feature_10 <= 14.587230453148699) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_0 <= 14.583824856095848) ? ( (Feature_12 <= 6.451183897544535) ? ( (Feature_12 <= 4.417068704316337) ? ( 19 ) : ( 20 ) ) : ( (Feature_12 <= 21.635134368135326) ? ( 22 ) : ( 23 ) ) ) : ( (Feature_4 <= 0.634964816292088) ? ( (Feature_6 <= 94.03368889076341) ? ( 26 ) : ( 27 ) ) : ( (Feature_7 <= 1.2328967568261069) ? ( 29 ) : ( 30 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_2
#
#
# 	namespace EXT_SubModel_3 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {22.408 }} ,
# 				{ 5 ,  {27.3125 }} ,
# 				{ 7 ,  {17.40740741 }} ,
# 				{ 8 ,  {14.11538462 }} ,
# 				{ 11 ,  {23. }} ,
# 				{ 12 ,  {15.72727273 }} ,
# 				{ 14 ,  {13.875 }} ,
# 				{ 15 ,  {9.2972973 }} ,
# 				{ 19 ,  {32.4375 }} ,
# 				{ 20 ,  {42.33333333 }} ,
# 				{ 22 ,  {44.34375 }} ,
# 				{ 23 ,  {21. }} ,
# 				{ 26 ,  {30.6 }} ,
# 				{ 27 ,  {26. }} ,
# 				{ 29 ,  {10. }} ,
# 				{ 30 ,  {16. }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.905117343475842) ? ( (Feature_12 <= 21.71615231420842) ? ( (Feature_12 <= 14.80650195926008) ? ( (Feature_3 <= 0.9164534355124707) ? ( 4 ) : ( 5 ) ) : ( (Feature_8 <= 15.053285670025874) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_4 <= 0.6015588426136931) ? ( (Feature_6 <= 25.879536786890608) ? ( 11 ) : ( 12 ) ) : ( (Feature_9 <= 542.8992559890725) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_12 <= 8.528712472003008) ? ( (Feature_5 <= 7.372660037374048) ? ( (Feature_6 <= 95.18833623525448) ? ( 19 ) : ( 20 ) ) : ( (Feature_9 <= 517.5107765963817) ? ( 22 ) : ( 23 ) ) ) : ( (Feature_4 <= 0.6588360484211832) ? ( (Feature_3 <= 0.7111930147331176) ? ( 26 ) : ( 27 ) ) : ( (Feature_5 <= 7.138483154785875) ? ( 29 ) : ( 30 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_3
#
#
# 	namespace EXT_SubModel_4 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {45.78571429 }} ,
# 				{ 5 ,  {39.33333333 }} ,
# 				{ 7 ,  {30.73076923 }} ,
# 				{ 8 ,  {49. }} ,
# 				{ 11 ,  {20. }} ,
# 				{ 12 ,  {15.08333333 }} ,
# 				{ 14 ,  {22.26436782 }} ,
# 				{ 15 ,  {36.4 }} ,
# 				{ 19 ,  {23.41322314 }} ,
# 				{ 20 ,  {38. }} ,
# 				{ 22 ,  {18.94642857 }} ,
# 				{ 23 ,  {10. }} ,
# 				{ 26 ,  {18.61904762 }} ,
# 				{ 27 ,  {14.2 }} ,
# 				{ 29 ,  {13.14492754 }} ,
# 				{ 30 ,  {9.30434783 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_10 <= 18.22254974135353) ? ( (Feature_12 <= 6.548015660818199) ? ( (Feature_12 <= 3.970761176506431) ? ( (Feature_10 <= 15.862539341609246) ? ( 4 ) : ( 5 ) ) : ( (Feature_4 <= 0.6139032679749505) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_5 <= 5.7794618747231254) ? ( (Feature_12 <= 15.253400395811587) ? ( 11 ) : ( 12 ) ) : ( (Feature_5 <= 7.055925814397422) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_12 <= 15.645101311775711) ? ( (Feature_12 <= 12.512973870085414) ? ( (Feature_3 <= 0.47019883919050864) ? ( 19 ) : ( 20 ) ) : ( (Feature_0 <= 37.23729974000885) ? ( 22 ) : ( 23 ) ) ) : ( (Feature_9 <= 551.4780299423626) ? ( (Feature_0 <= 0.5203060348474793) ? ( 26 ) : ( 27 ) ) : ( (Feature_12 <= 24.47854701808378) ? ( 29 ) : ( 30 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_4
#
#
# 	namespace EXT_SubModel_5 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {23. }} ,
# 				{ 5 ,  {19. }} ,
# 				{ 7 ,  {36.51785714 }} ,
# 				{ 8 ,  {30.56 }} ,
# 				{ 11 ,  {20.64285714 }} ,
# 				{ 12 ,  {15.46666667 }} ,
# 				{ 14 ,  {31. }} ,
# 				{ 15 ,  {50. }} ,
# 				{ 19 ,  {23.33962264 }} ,
# 				{ 20 ,  {31.6 }} ,
# 				{ 22 ,  {26. }} ,
# 				{ 23 ,  {50. }} ,
# 				{ 26 ,  {19.78947368 }} ,
# 				{ 27 ,  {17.13333333 }} ,
# 				{ 29 ,  {16.24528302 }} ,
# 				{ 30 ,  {9.89583333 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_10 <= 18.24420117156491) ? ( (Feature_2 <= 6.507609402796889) ? ( (Feature_5 <= 6.550595199433988) ? ( (Feature_9 <= 420.5841255567894) ? ( 4 ) : ( 5 ) ) : ( (Feature_12 <= 6.536278053424129) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_5 <= 6.480716748287422) ? ( (Feature_4 <= 0.6150969711745534) ? ( 11 ) : ( 12 ) ) : ( (Feature_5 <= 7.636884891068027) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_12 <= 11.86821113547408) ? ( (Feature_3 <= 0.7621785014691662) ? ( (Feature_6 <= 93.95458521319301) ? ( 19 ) : ( 20 ) ) : ( (Feature_6 <= 84.6180212710442) ? ( 22 ) : ( 23 ) ) ) : ( (Feature_4 <= 0.6155599252783128) ? ( (Feature_4 <= 0.49036333274930016) ? ( 26 ) : ( 27 ) ) : ( (Feature_12 <= 19.23070926152461) ? ( 29 ) : ( 30 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_5
#
#
# 	namespace EXT_SubModel_6 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {24.74 }} ,
# 				{ 5 ,  {35. }} ,
# 				{ 7 ,  {22.32926829 }} ,
# 				{ 8 ,  {20.03030303 }} ,
# 				{ 11 ,  {20.88888889 }} ,
# 				{ 12 ,  {16.65671642 }} ,
# 				{ 14 ,  {14.04761905 }} ,
# 				{ 15 ,  {9.75 }} ,
# 				{ 19 ,  {32.95121951 }} ,
# 				{ 20 ,  {44.66666667 }} ,
# 				{ 22 ,  {27.66666667 }} ,
# 				{ 23 ,  {17.75 }} ,
# 				{ 26 ,  {49.18181818 }} ,
# 				{ 27 ,  {42.75 }} ,
# 				{ 28 ,  {21. }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.8969808963422725) ? ( (Feature_12 <= 14.402783600507506) ? ( (Feature_12 <= 8.514169041548278) ? ( (Feature_8 <= 10.037368575128433) ? ( 4 ) : ( 5 ) ) : ( (Feature_12 <= 11.685853477279927) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_9 <= 575.017194462948) ? ( (Feature_6 <= 70.90407168885193) ? ( 11 ) : ( 12 ) ) : ( (Feature_12 <= 22.958258521464096) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_5 <= 7.6482766398431625) ? ( (Feature_12 <= 10.204023068242295) ? ( (Feature_5 <= 7.422199632065202) ? ( 19 ) : ( 20 ) ) : ( (Feature_2 <= 6.186545590248367) ? ( 22 ) : ( 23 ) ) ) : ( (Feature_8 <= 13.731836959594785) ? ( (Feature_10 <= 16.531776672942556) ? ( 26 ) : ( 27 ) ) : ( 28 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_6
#
#
# 	namespace EXT_SubModel_7 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {30.33333333 }} ,
# 				{ 5 ,  {19.82608696 }} ,
# 				{ 7 ,  {26.13592233 }} ,
# 				{ 8 ,  {33.92307692 }} ,
# 				{ 11 ,  {33.18181818 }} ,
# 				{ 12 ,  {20.04761905 }} ,
# 				{ 14 ,  {15.28571429 }} ,
# 				{ 15 ,  {12.09195402 }} ,
# 				{ 19 ,  {40.57142857 }} ,
# 				{ 20 ,  {50. }} ,
# 				{ 21 ,  {50. }} ,
# 				{ 24 ,  {17. }} ,
# 				{ 25 ,  {15. }} ,
# 				{ 26 ,  {21. }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 7.228017928692353) ? ( (Feature_2 <= 15.463657615016903) ? ( (Feature_5 <= 6.356132643106513) ? ( (Feature_9 <= 202.71042109919267) ? ( 4 ) : ( 5 ) ) : ( (Feature_5 <= 7.080539223025823) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_12 <= 16.27830501142797) ? ( (Feature_12 <= 7.946303505133589) ? ( 11 ) : ( 12 ) ) : ( (Feature_9 <= 563.4983455480534) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_8 <= 12.378574267671711) ? ( (Feature_2 <= 8.439334095253415) ? ( (Feature_5 <= 8.569999523499401) ? ( 19 ) : ( 20 ) ) : ( 21 ) ) : ( (Feature_5 <= 7.835986141415064) ? ( (Feature_0 <= 18.085481823896252) ? ( 24 ) : ( 25 ) ) : ( 26 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_7
#
#
# 	namespace EXT_SubModel_8 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {21.13461538 }} ,
# 				{ 5 ,  {28.70967742 }} ,
# 				{ 7 ,  {31. }} ,
# 				{ 8 ,  {33.36842105 }} ,
# 				{ 11 ,  {47.4 }} ,
# 				{ 12 ,  {43.92307692 }} ,
# 				{ 13 ,  {50. }} ,
# 				{ 17 ,  {24.17857143 }} ,
# 				{ 18 ,  {35.33333333 }} ,
# 				{ 19 ,  {50. }} ,
# 				{ 22 ,  {11.25 }} ,
# 				{ 23 ,  {20.125 }} ,
# 				{ 25 ,  {19.7 }} ,
# 				{ 26 ,  {13.65925926 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_10 <= 18.08850697156553) ? ( (Feature_5 <= 7.419359009514672) ? ( (Feature_5 <= 6.961308883838653) ? ( (Feature_5 <= 6.586421458396931) ? ( 4 ) : ( 5 ) ) : ( (Feature_8 <= 2.0921850982551393) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_2 <= 9.927327772541108) ? ( (Feature_10 <= 14.898547414177353) ? ( 11 ) : ( 12 ) ) : ( 13 ) ) ) : ( (Feature_12 <= 9.82205030939839) ? ( (Feature_6 <= 91.84314735040215) ? ( (Feature_3 <= 0.23597488842717135) ? ( 17 ) : ( 18 ) ) : ( 19 ) ) : ( (Feature_6 <= 77.90705017178858) ? ( (Feature_11 <= 267.9944363945199) ? ( 22 ) : ( 23 ) ) : ( (Feature_12 <= 14.123825161572938) ? ( 25 ) : ( 26 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_8
#
#
# 	namespace EXT_SubModel_9 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {27.7 }} ,
# 				{ 5 ,  {24.73333333 }} ,
# 				{ 6 ,  {50. }} ,
# 				{ 9 ,  {20.50819672 }} ,
# 				{ 10 ,  {22.46610169 }} ,
# 				{ 12 ,  {18.32727273 }} ,
# 				{ 13 ,  {13.67424242 }} ,
# 				{ 17 ,  {38.725 }} ,
# 				{ 18 ,  {48.5 }} ,
# 				{ 20 ,  {32.94871795 }} ,
# 				{ 21 ,  {20.25 }} ,
# 				{ 24 ,  {13.5 }} ,
# 				{ 25 ,  {7.5 }} ,
# 				{ 26 ,  {27. }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.777159728681296) ? ( (Feature_12 <= 6.482941019555623) ? ( (Feature_0 <= 4.688262134023641) ? ( (Feature_9 <= 260.26126584841927) ? ( 4 ) : ( 5 ) ) : ( 6 ) ) : ( (Feature_12 <= 13.602590851962223) ? ( (Feature_5 <= 6.0139171068277815) ? ( 9 ) : ( 10 ) ) : ( (Feature_9 <= 397.2366960538722) ? ( 12 ) : ( 13 ) ) ) ) : ( (Feature_12 <= 18.477165642223834) ? ( (Feature_12 <= 5.028978474575112) ? ( (Feature_2 <= 17.017910939880572) ? ( 17 ) : ( 18 ) ) : ( (Feature_2 <= 9.030193711017027) ? ( 20 ) : ( 21 ) ) ) : ( (Feature_0 <= 13.363467560031843) ? ( (Feature_12 <= 21.995096400318722) ? ( 24 ) : ( 25 ) ) : ( 26 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_9
#
#
# 	namespace EXT_SubModel_10 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {30.44444444 }} ,
# 				{ 5 ,  {44. }} ,
# 				{ 6 ,  {50. }} ,
# 				{ 9 ,  {24.92 }} ,
# 				{ 10 ,  {32.5 }} ,
# 				{ 12 ,  {46. }} ,
# 				{ 13 ,  {21. }} ,
# 				{ 17 ,  {20.73943662 }} ,
# 				{ 18 ,  {16.92424242 }} ,
# 				{ 20 ,  {26.34782609 }} ,
# 				{ 21 ,  {44.5 }} ,
# 				{ 24 ,  {12.5 }} ,
# 				{ 25 ,  {21.8974359 }} ,
# 				{ 27 ,  {10.57777778 }} ,
# 				{ 28 ,  {13.72340426 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_12 <= 6.004054239079983) ? ( (Feature_12 <= 3.950201768123261) ? ( (Feature_2 <= 9.909022942084821) ? ( (Feature_5 <= 7.137002591116954) ? ( 4 ) : ( 5 ) ) : ( 6 ) ) : ( (Feature_5 <= 7.982058422446971) ? ( (Feature_5 <= 6.655291043669904) ? ( 9 ) : ( 10 ) ) : ( (Feature_9 <= 527.0359838963655) ? ( 12 ) : ( 13 ) ) ) ) : ( (Feature_9 <= 661.166467712804) ? ( (Feature_5 <= 6.40980567809468) ? ( (Feature_12 <= 14.854133574887776) ? ( 17 ) : ( 18 ) ) : ( (Feature_5 <= 7.732655072483966) ? ( 20 ) : ( 21 ) ) ) : ( (Feature_12 <= 15.245979104878966) ? ( (Feature_11 <= 83.66174267955851) ? ( 24 ) : ( 25 ) ) : ( (Feature_7 <= 1.8274761703602418) ? ( 27 ) : ( 28 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_10
#
#
# 	namespace EXT_SubModel_11 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {12.28571429 }} ,
# 				{ 5 ,  {20.9695122 }} ,
# 				{ 7 ,  {28.53571429 }} ,
# 				{ 8 ,  {8. }} ,
# 				{ 11 ,  {47.75 }} ,
# 				{ 12 ,  {28.4 }} ,
# 				{ 14 ,  {18.28985507 }} ,
# 				{ 15 ,  {11.82258065 }} ,
# 				{ 19 ,  {32.77777778 }} ,
# 				{ 20 ,  {43.11111111 }} ,
# 				{ 22 ,  {48. }} ,
# 				{ 23 ,  {43.66666667 }} ,
# 				{ 25 ,  {21. }} ,
# 				{ 27 ,  {17. }} ,
# 				{ 28 ,  {15. }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 7.2536841848925935) ? ( (Feature_6 <= 83.25381152721788) ? ( (Feature_5 <= 6.4794022250540255) ? ( (Feature_11 <= 143.29494155791724) ? ( 4 ) : ( 5 ) ) : ( (Feature_12 <= 21.388447991365027) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_12 <= 5.8436516949045725) ? ( (Feature_12 <= 4.7492508215294675) ? ( 11 ) : ( 12 ) ) : ( (Feature_12 <= 20.727179566942922) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_8 <= 13.707815180396576) ? ( (Feature_5 <= 7.7953128709997195) ? ( (Feature_5 <= 7.434386686985836) ? ( 19 ) : ( 20 ) ) : ( (Feature_8 <= 5.841959179771114) ? ( 22 ) : ( 23 ) ) ) : ( (Feature_6 <= 92.38306913405938) ? ( 25 ) : ( (Feature_11 <= 387.1129153930842) ? ( 27 ) : ( 28 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_11
#
#
# 	namespace EXT_SubModel_12 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {22.13768116 }} ,
# 				{ 5 ,  {28.23076923 }} ,
# 				{ 7 ,  {19.73846154 }} ,
# 				{ 8 ,  {14.08333333 }} ,
# 				{ 11 ,  {47.75 }} ,
# 				{ 12 ,  {23.87096774 }} ,
# 				{ 14 ,  {16.41176471 }} ,
# 				{ 15 ,  {13.38053097 }} ,
# 				{ 19 ,  {33.72727273 }} ,
# 				{ 20 ,  {42.83333333 }} ,
# 				{ 22 ,  {49.71428571 }} ,
# 				{ 23 ,  {42.85714286 }} ,
# 				{ 25 ,  {21. }} ,
# 				{ 27 ,  {15. }} ,
# 				{ 28 ,  {17. }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 7.085658321906619) ? ( (Feature_2 <= 16.101140321729893) ? ( (Feature_12 <= 12.408294023949027) ? ( (Feature_5 <= 6.617754718325851) ? ( 4 ) : ( 5 ) ) : ( (Feature_0 <= 0.796429125373768) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_12 <= 12.678841929656617) ? ( (Feature_12 <= 4.756124438270657) ? ( 11 ) : ( 12 ) ) : ( (Feature_9 <= 567.6511138261534) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_9 <= 615.9277763724922) ? ( (Feature_5 <= 7.898538554363791) ? ( (Feature_5 <= 7.362203777485514) ? ( 19 ) : ( 20 ) ) : ( (Feature_10 <= 15.334933506094385) ? ( 22 ) : ( 23 ) ) ) : ( (Feature_12 <= 8.06824356389341) ? ( 25 ) : ( (Feature_5 <= 7.390954639812519) ? ( 27 ) : ( 28 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_12
#
#
# 	namespace EXT_SubModel_13 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {40.3 }} ,
# 				{ 5 ,  {50. }} ,
# 				{ 7 ,  {22. }} ,
# 				{ 8 ,  {31.33333333 }} ,
# 				{ 11 ,  {24.28828829 }} ,
# 				{ 12 ,  {35.47297297 }} ,
# 				{ 14 ,  {24.92857143 }} ,
# 				{ 15 ,  {20.89795918 }} ,
# 				{ 19 ,  {20.64705882 }} ,
# 				{ 20 ,  {18.49019608 }} ,
# 				{ 22 ,  {18.44444444 }} ,
# 				{ 23 ,  {13.85714286 }} ,
# 				{ 26 ,  {13.25862069 }} ,
# 				{ 27 ,  {9.18181818 }} ,
# 				{ 29 ,  {14. }} ,
# 				{ 30 ,  {17.65517241 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_12 <= 11.843548483667782) ? ( (Feature_10 <= 14.604268693148349) ? ( (Feature_12 <= 8.168734301953865) ? ( (Feature_10 <= 13.592327152823128) ? ( 4 ) : ( 5 ) ) : ( (Feature_5 <= 6.413145607109356) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_12 <= 9.471360573410607) ? ( (Feature_5 <= 6.738298661914964) ? ( 11 ) : ( 12 ) ) : ( (Feature_12 <= 9.749431266597043) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_9 <= 575.597518464363) ? ( (Feature_0 <= 0.7264409302655301) ? ( (Feature_6 <= 71.97969511524795) ? ( 19 ) : ( 20 ) ) : ( (Feature_12 <= 16.229743008929674) ? ( 22 ) : ( 23 ) ) ) : ( (Feature_7 <= 2.1544816540385834) ? ( (Feature_12 <= 24.62957650285521) ? ( 26 ) : ( 27 ) ) : ( (Feature_11 <= 219.40788599709563) ? ( 29 ) : ( 30 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_13
#
#
# 	namespace EXT_SubModel_14 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {50. }} ,
# 				{ 5 ,  {19.10273973 }} ,
# 				{ 7 ,  {13.58333333 }} ,
# 				{ 8 ,  {9. }} ,
# 				{ 10 ,  {23. }} ,
# 				{ 12 ,  {14.33333333 }} ,
# 				{ 13 ,  {9.08333333 }} ,
# 				{ 17 ,  {32.09090909 }} ,
# 				{ 18 ,  {24.40880503 }} ,
# 				{ 20 ,  {43.19047619 }} ,
# 				{ 21 ,  {36.94871795 }} ,
# 				{ 24 ,  {30. }} ,
# 				{ 25 ,  {17.61111111 }} ,
# 				{ 27 ,  {12.60526316 }} ,
# 				{ 28 ,  {16.66666667 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_5 <= 6.081593087024298) ? ( (Feature_12 <= 28.30650697946478) ? ( (Feature_12 <= 19.358308520192903) ? ( (Feature_12 <= 4.506481545635976) ? ( 4 ) : ( 5 ) ) : ( (Feature_0 <= 15.035484871465258) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_6 <= 70.10152314439003) ? ( 10 ) : ( (Feature_9 <= 566.7442343904377) ? ( 12 ) : ( 13 ) ) ) ) : ( (Feature_12 <= 13.255471281546587) ? ( (Feature_5 <= 7.007050853174037) ? ( (Feature_12 <= 4.331169939099097) ? ( 17 ) : ( 18 ) ) : ( (Feature_10 <= 14.781935006273681) ? ( 20 ) : ( 21 ) ) ) : ( (Feature_8 <= 23.199919327720963) ? ( (Feature_10 <= 14.423695936000469) ? ( 24 ) : ( 25 ) ) : ( (Feature_7 <= 2.2425013765726707) ? ( 27 ) : ( 28 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# ...
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_29
#
#
# 	namespace EXT_SubModel_30 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {35.89473684 }} ,
# 				{ 5 ,  {49.5 }} ,
# 				{ 7 ,  {29.75 }} ,
# 				{ 8 ,  {46. }} ,
# 				{ 11 ,  {24.6875 }} ,
# 				{ 12 ,  {21.87719298 }} ,
# 				{ 14 ,  {29.07692308 }} ,
# 				{ 15 ,  {37.57142857 }} ,
# 				{ 19 ,  {22.42731278 }} ,
# 				{ 20 ,  {42.75 }} ,
# 				{ 22 ,  {47. }} ,
# 				{ 23 ,  {21. }} ,
# 				{ 26 ,  {19. }} ,
# 				{ 27 ,  {14.64285714 }} ,
# 				{ 29 ,  {9.95238095 }} ,
# 				{ 30 ,  {13.375 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_2 <= 5.840448580320614) ? ( (Feature_10 <= 15.737227964555458) ? ( (Feature_7 <= 5.848246057952815) ? ( (Feature_5 <= 7.890097240764744) ? ( 4 ) : ( 5 ) ) : ( (Feature_5 <= 7.579798899425641) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_5 <= 6.743237168095497) ? ( (Feature_2 <= 2.5442959655010995) ? ( 11 ) : ( 12 ) ) : ( (Feature_5 <= 7.0859333563565405) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_12 <= 16.712385929062776) ? ( (Feature_5 <= 8.290499277001432) ? ( (Feature_5 <= 8.025657277253067) ? ( 19 ) : ( 20 ) ) : ( (Feature_8 <= 10.046354809797535) ? ( 22 ) : ( 23 ) ) ) : ( (Feature_4 <= 0.6707698935501837) ? ( (Feature_10 <= 19.310306583109682) ? ( 26 ) : ( 27 ) ) : ( (Feature_7 <= 1.8836503696665046) ? ( 29 ) : ( 30 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_30
#
#
# 	namespace EXT_SubModel_31 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 4 ,  {17.5 }} ,
# 				{ 5 ,  {24.30737705 }} ,
# 				{ 7 ,  {44.90909091 }} ,
# 				{ 8 ,  {37.71428571 }} ,
# 				{ 11 ,  {50. }} ,
# 				{ 12 ,  {48. }} ,
# 				{ 13 ,  {50. }} ,
# 				{ 17 ,  {50. }} ,
# 				{ 18 ,  {21.59375 }} ,
# 				{ 20 ,  {21. }} ,
# 				{ 21 ,  {50. }} ,
# 				{ 24 ,  {20.37037037 }} ,
# 				{ 25 ,  {15.79166667 }} ,
# 				{ 27 ,  {12.83333333 }} ,
# 				{ 28 ,  {10.04878049 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = (Feature_10 <= 19.737664983187692) ? ( (Feature_5 <= 8.345453975972179) ? ( (Feature_5 <= 7.346754900733295) ? ( (Feature_5 <= 5.694389297475809) ? ( 4 ) : ( 5 ) ) : ( (Feature_12 <= 4.771242513155313) ? ( 7 ) : ( 8 ) ) ) : ( (Feature_9 <= 290.0869881473887) ? ( (Feature_6 <= 91.37547006075462) ? ( 11 ) : ( 12 ) ) : ( 13 ) ) ) : ( (Feature_12 <= 10.72820531772003) ? ( (Feature_3 <= 0.9750245180796014) ? ( (Feature_12 <= 3.5093860627330913) ? ( 17 ) : ( 18 ) ) : ( (Feature_0 <= 4.102939811436654) ? ( 20 ) : ( 21 ) ) ) : ( (Feature_12 <= 19.036670423992934) ? ( (Feature_12 <= 13.80137043136217) ? ( 24 ) : ( 25 ) ) : ( (Feature_12 <= 22.68921696427278) ? ( 27 ) : ( 28 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = { "Estimator" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			std::any  lEstimator = lNodeValue [ 0 ];
# 			lTable[ "Estimator" ] = { lEstimator };
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace EXT_SubModel_31
#
#
# 	std::vector<std::string> get_input_names(){
# 		std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3", "Feature_4", "Feature_5", "Feature_6", "Feature_7", "Feature_8", "Feature_9", "Feature_10", "Feature_11", "Feature_12" };
#
# 		return lFeatures;
# 	}
#
# 	std::vector<std::string> get_output_names(){
# 		std::vector<std::string> lOutputs = { "Estimator" };
#
# 		return lOutputs;
# 	}
#
# 	tTable compute_regression(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3, std::any Feature_4, std::any Feature_5, std::any Feature_6, std::any Feature_7, std::any Feature_8, std::any Feature_9, std::any Feature_10, std::any Feature_11, std::any Feature_12) {
# 		std::vector<tTable> lTreeScores = {
# 			EXT_SubModel_0::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_1::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_2::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_3::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_4::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_5::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_6::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_7::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_8::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_9::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_10::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_11::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_12::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_13::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_14::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_15::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_16::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_17::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_18::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_19::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_20::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_21::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_22::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_23::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_24::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_25::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_26::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_27::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_28::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_29::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_30::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12),
# 			EXT_SubModel_31::compute_regression(Feature_0, Feature_1, Feature_2, Feature_3, Feature_4, Feature_5, Feature_6, Feature_7, Feature_8, Feature_9, Feature_10, Feature_11, Feature_12)
# 		};
#
# 		tTable lAggregatedTable = aggregate_ext_scores(lTreeScores, {"Estimator"});
#
#
# 		tTable lTable;
#
# 		std::any  lEstimator = lAggregatedTable["Estimator"][0];
# 		lTable[ "Estimator" ] = { lEstimator };
#
# 		return lTable;
# 	}
#
# 	tTable compute_model_outputs_from_table( tTable const & iTable) {
# 		tTable lTable = compute_regression(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0], iTable.at("Feature_4")[0], iTable.at("Feature_5")[0], iTable.at("Feature_6")[0], iTable.at("Feature_7")[0], iTable.at("Feature_8")[0], iTable.at("Feature_9")[0], iTable.at("Feature_10")[0], iTable.at("Feature_11")[0], iTable.at("Feature_12")[0]);
#
# 		return lTable;
# 	}
#
# } // eof namespace

# %%
    def write_text_to_file(iCPPCode, oCPPFile):          
        with open(oCPPFile, "w") as text_file:
            text_file.write(iCPPCode)

    def add_cpp_main_function(iCPPCode, iCSVFile):
        lCPPCode = "#include \"Generic.i\"\n\n"
        lCPPCode = lCPPCode + iCPPCode
        lCPPCode = lCPPCode + "\tint main() {\n"
        lCPPCode = lCPPCode + "\t\tscore_csv_file(\"" + iCSVFile +"\");\n"
        lCPPCode = lCPPCode + "\treturn 0;\n}\n"
        return lCPPCode

    def compile_cpp_code_as_executable(iName):
        import subprocess
        lCommand = ["g++", "-Wall", "-Wno-unused-function", "-std=c++17" , "-g" ,  "-o", iName + ".exe",  iName + ".cpp"]
        print("EXECUTING" , "'" + " ".join(lCommand) + "'")
        result = subprocess.check_output(lCommand)
        # print(result)

    def execute_cpp_model(iName, iCSVFile):
        import subprocess
        result2 = subprocess.check_output([iName + ".exe",  iCSVFile])
        result2 = result2.decode()
        print(result2[:100])
        print(result2[-100:])
        return result2
        
    def execute_cpp_code(iCPPCode, iCSVFile):
        lName = "/tmp/sklearn2sql_cpp_" + str(id(clf));
        lCPPCode = add_cpp_main_function(iCPPCode, iCSVFile)
        write_text_to_file(lCPPCode, lName + ".cpp")
        compile_cpp_code_as_executable(lName)
        result = execute_cpp_model(lName, iCSVFile)
        write_text_to_file(str(result), lName + ".out")
        return lName + ".out"

# %%
populate_table("/tmp/boston2.csv" , ["Feature_" + str(i) for i,x in enumerate(metadata["features"])])
lCPPOutput = execute_cpp_code(lCPPCode , "/tmp/boston2.csv")
cpp_output = pd.read_csv(lCPPOutput)
# Out:
# EXECUTING 'g++ -Wall -Wno-unused-function -std=c++17 -g -o /tmp/sklearn2sql_cpp_140419336291712.exe /tmp/sklearn2sql_cpp_140419336291712.cpp'
# idx,Estimator
# 0,26.03957130500000
# 1,23.07171333093750
# 2,32.60170822968750
# 3,30.35457474625000
# 4,30.9
# 50453343750
# 502,22.26868182906250
# 503,26.46573158875000
# 504,24.76448424406250
# 505,22.03380828593751

# %%
cpp_output.sample(12, random_state=1960)
# Out:
#      idx  Estimator
# 230  230  21.665933
# 112  112  19.214661
# 125  125  18.868197
# 9      9  19.430104
# 213  213  22.977870
# 109  109  18.534328
# 127  127  16.717981
# 244  244  20.000532
# 406  406  11.915148
# 490  490  12.476331
# 245  245  18.879069
# 133  133  17.943670

# %%
skl_outputs = pd.DataFrame()
X = df[metadata['features']].values
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['idx']);

skl_output_score = pd.DataFrame(clf.predict(X), columns=['Estimator']);
skl_output = pd.concat([skl_output_key, skl_output_score] , axis=1)
skl_output.sample(12, random_state=1960)
# Out:
#      idx  Estimator
# 230  230  21.665933
# 112  112  19.214661
# 125  125  18.868197
# 9      9  19.430104
# 213  213  22.977870
# 109  109  18.534328
# 127  127  16.717981
# 244  244  20.000532
# 406  406  11.915148
# 490  490  12.476331
# 245  245  18.879069
# 133  133  17.943670

# %%
cpp_skl_join = skl_output.join(cpp_output , how='left', on='idx', lsuffix='_skl', rsuffix='_cpp')

# %%
cpp_skl_join.sample(12, random_state=1960)
# Out:
#      idx_skl  Estimator_skl  idx_cpp  Estimator_cpp
# 230      230      21.665933      230      21.665933
# 112      112      19.214661      112      19.214661
# 125      125      18.868197      125      18.868197
# 9          9      19.430104        9      19.430104
# 213      213      22.977870      213      22.977870
# 109      109      18.534328      109      18.534328
# 127      127      16.717981      127      16.717981
# 244      244      20.000532      244      20.000532
# 406      406      11.915148      406      11.915148
# 490      490      12.476331      490      12.476331
# 245      245      18.879069      245      18.879069
# 133      133      17.943670      133      17.943670

# %%
lDiff = cpp_skl_join['Estimator_skl'] - cpp_skl_join['Estimator_cpp']

# %%
lDiff.describe()
# Out:
# count    5.060000e+02
# mean    -4.502204e-10
# std      4.572397e-10
# min     -1.771820e-09
# 25%     -7.620873e-10
# 50%     -4.928635e-10
# 75%     -1.768043e-10
# max      8.804619e-10
# dtype: float64
