# %% [markdown]
# # ML2CPP

# %% [markdown]
# ## Preparing the dataset

# %%
from sklearn import datasets
import numpy as np
import pandas as pd

def populate_table(tablename, feature_names):
    iris = datasets.load_iris()
    X = iris.data  
    N = X.shape[0]
    y = iris.target.reshape(N,1)
    k = np.arange(N).reshape(N, 1)
    k_X_y = np.concatenate((k, X, y) , axis=1)
    lTable=pd.DataFrame(k_X_y)
    # print(lTable.head())
    lTable.columns = ['idx'] + feature_names + ['TGT'];
    lTable['TGT'] = lTable['TGT'].apply(int)
    lTable['idx'] = lTable['idx'].apply(int)
    lTable.to_csv(tablename , float_format='%.14g')

# %%
metadata = {"primary_key" : "KEY",
            "features" : ['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm', 'petal_width_cm'],
            "targets" : ["TGT"],
            "table" : "iris"}

# %%
populate_table("/tmp/iris.csv" , metadata["features"])

# %%
df = pd.read_csv("/tmp/iris.csv")
df.sample(12, random_state=1960)
# Out:
#      Unnamed: 0  idx  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# 114         114  114              5.8             2.8              5.1
# 74           74   74              6.4             2.9              4.3
# 9             9    9              4.9             3.1              1.5
# 88           88   88              5.6             3.0              4.1
# 25           25   25              5.0             3.0              1.6
# 5             5    5              5.4             3.9              1.7
# 48           48   48              5.3             3.7              1.5
# 117         117  117              7.7             3.8              6.7
# 83           83   83              6.0             2.7              5.1
# 105         105  105              7.6             3.0              6.6
# 27           27   27              5.2             3.5              1.5
# 64           64   64              5.6             2.9              3.6
#
#      petal_width_cm  TGT
# 114             2.4    2
# 74              1.3    1
# 9               0.1    0
# 88              1.3    1
# 25              0.2    0
# 5               0.4    0
# 48              0.2    0
# 117             2.2    2
# 83              1.6    1
# 105             2.1    2
# 27              0.2    0
# 64              1.3    1

# %% [markdown]
# ## Training a Model

# %%
# train any scikit model on the iris dataset
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators = 512, random_state=1960)
clf.fit(df[metadata['features']].values, df[metadata['targets']].values)
# Out:
# <ipython-input-5-5dab23b7065a>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(df[metadata['features']].values, df[metadata['targets']].values)
# RandomForestClassifier(n_estimators=512, random_state=1960)

# %% [markdown]
# ## Deploying the Model

# %%
def generate_cpp_for_model(model):
    import pickle, json, requests, base64
    b64_data = base64.b64encode(pickle.dumps(model)).decode('utf-8')
    # send the model th the web service
    json_data={"Name":"model_cpp_sample", 
               "PickleData":b64_data , 
               "SQLDialect":"CPP",
               "FeatureNames" : metadata['features']}
    r = requests.post("https://sklearn2sql.herokuapp.com/model", json=json_data)
    content = r.json()
    lCPP = content["model"]["SQLGenrationResult"][0]["SQL"]
    # print(lCPP);
    return lCPP


lCPPCode = generate_cpp_for_model(clf);

# %%
print(lCPPCode)
# Out:
# namespace  {
#
# 	namespace RF_Tree_0 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 2 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 16 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 17 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 18 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_0 <= 5.450000047683716) ? ( (Feature_3 <= 0.7000000029802322) ? ( 2 ) : ( (Feature_3 <= 1.600000023841858) ? ( 4 ) : ( 5 ) ) ) : ( (Feature_2 <= 4.75) ? ( (Feature_3 <= 0.6500000059604645) ? ( 8 ) : ( 9 ) ) : ( (Feature_3 <= 1.699999988079071) ? ( (Feature_1 <= 3.049999952316284) ? ( (Feature_3 <= 1.550000011920929) ? ( 13 ) : ( (Feature_0 <= 6.599999904632568) ? ( 15 ) : ( 16 ) ) ) : ( 17 ) ) : ( 18 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_0
#
#
# 	namespace RF_Tree_1 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 3 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 15 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 17 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 18 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.449999988079071) ? ( 1 ) : ( (Feature_2 <= 4.75) ? ( 3 ) : ( (Feature_3 <= 1.75) ? ( (Feature_1 <= 2.350000023841858) ? ( 6 ) : ( (Feature_1 <= 2.850000023841858) ? ( 8 ) : ( (Feature_1 <= 3.049999952316284) ? ( (Feature_3 <= 1.6500000357627869) ? ( 11 ) : ( 12 ) ) : ( 13 ) ) ) ) : ( (Feature_1 <= 3.149999976158142) ? ( 15 ) : ( (Feature_2 <= 4.950000047683716) ? ( 17 ) : ( 18 ) ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_1
#
#
# 	namespace RF_Tree_2 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 16 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.75) ? ( 1 ) : ( (Feature_3 <= 1.6500000357627869) ? ( (Feature_1 <= 2.649999976158142) ? ( (Feature_0 <= 5.900000095367432) ? ( 5 ) : ( (Feature_2 <= 4.950000047683716) ? ( 7 ) : ( 8 ) ) ) : ( 9 ) ) : ( (Feature_2 <= 4.8500001430511475) ? ( (Feature_0 <= 5.400000095367432) ? ( 12 ) : ( (Feature_1 <= 3.100000023841858) ? ( 14 ) : ( 15 ) ) ) : ( 16 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_2
#
#
# 	namespace RF_Tree_3 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 9 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.800000011920929) ? ( 1 ) : ( (Feature_2 <= 4.75) ? ( (Feature_3 <= 1.6500000357627869) ? ( 4 ) : ( 5 ) ) : ( (Feature_2 <= 4.950000047683716) ? ( (Feature_1 <= 2.600000023841858) ? ( 8 ) : ( 9 ) ) : ( 10 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_3
#
#
# 	namespace RF_Tree_4 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 9 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.449999988079071) ? ( 1 ) : ( (Feature_0 <= 6.6499998569488525) ? ( (Feature_3 <= 1.699999988079071) ? ( (Feature_2 <= 4.950000047683716) ? ( 5 ) : ( (Feature_1 <= 2.649999976158142) ? ( 7 ) : ( 8 ) ) ) : ( 9 ) ) : ( (Feature_2 <= 5.25) ? ( 11 ) : ( 12 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_4
#
#
# 	namespace RF_Tree_5 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 2 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 14 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 15 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 18 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 20 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 21 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 22 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_0 <= 5.450000047683716) ? ( (Feature_2 <= 2.599999964237213) ? ( 2 ) : ( (Feature_0 <= 4.950000047683716) ? ( (Feature_3 <= 1.350000023841858) ? ( 5 ) : ( 6 ) ) : ( 7 ) ) ) : ( (Feature_2 <= 4.8500001430511475) ? ( (Feature_3 <= 0.6500000059604645) ? ( 10 ) : ( (Feature_0 <= 5.950000047683716) ? ( 12 ) : ( (Feature_3 <= 1.699999988079071) ? ( 14 ) : ( 15 ) ) ) ) : ( (Feature_1 <= 2.75) ? ( (Feature_0 <= 5.900000095367432) ? ( 18 ) : ( (Feature_3 <= 1.75) ? ( 20 ) : ( 21 ) ) ) : ( 22 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_5
#
#
# 	namespace RF_Tree_6 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 10 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.800000011920929) ? ( 1 ) : ( (Feature_2 <= 4.75) ? ( (Feature_3 <= 1.600000023841858) ? ( 4 ) : ( 5 ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_0 <= 6.5) ? ( 8 ) : ( (Feature_0 <= 7.049999952316284) ? ( 10 ) : ( 11 ) ) ) : ( 12 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_6
#
#
# 	namespace RF_Tree_7 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.449999988079071) ? ( 1 ) : ( (Feature_3 <= 1.8499999642372131) ? ( (Feature_2 <= 5.299999952316284) ? ( (Feature_2 <= 5.049999952316284) ? ( (Feature_0 <= 4.950000047683716) ? ( (Feature_1 <= 2.450000047683716) ? ( 7 ) : ( 8 ) ) : ( 9 ) ) : ( (Feature_3 <= 1.550000011920929) ? ( 11 ) : ( 12 ) ) ) : ( 13 ) ) : ( 14 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_7
#
#
# 	namespace RF_Tree_8 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.800000011920929) ? ( 1 ) : ( (Feature_0 <= 6.1499998569488525) ? ( (Feature_3 <= 1.3499999642372131) ? ( 4 ) : ( (Feature_2 <= 4.900000095367432) ? ( 6 ) : ( 7 ) ) ) : ( (Feature_2 <= 4.75) ? ( 9 ) : ( (Feature_2 <= 5.049999952316284) ? ( (Feature_3 <= 1.75) ? ( 12 ) : ( 13 ) ) : ( 14 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_8
#
#
# 	namespace RF_Tree_9 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 6 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.800000011920929) ? ( 1 ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 5.049999952316284) ? ( (Feature_0 <= 4.950000047683716) ? ( 5 ) : ( 6 ) ) : ( 7 ) ) : ( 8 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_9
#
#
# 	namespace RF_Tree_10 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 2 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 3 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 16 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 17 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 18 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_0 <= 5.450000047683716) ? ( (Feature_2 <= 2.449999988079071) ? ( 2 ) : ( 3 ) ) : ( (Feature_3 <= 1.699999988079071) ? ( (Feature_2 <= 5.0) ? ( (Feature_1 <= 3.9000000953674316) ? ( 7 ) : ( 8 ) ) : ( (Feature_2 <= 5.349999904632568) ? ( (Feature_3 <= 1.550000011920929) ? ( 11 ) : ( 12 ) ) : ( 13 ) ) ) : ( (Feature_2 <= 4.8500001430511475) ? ( (Feature_0 <= 5.950000047683716) ? ( 16 ) : ( 17 ) ) : ( 18 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_10
#
#
# 	namespace RF_Tree_11 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 10 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.449999988079071) ? ( 1 ) : ( (Feature_2 <= 4.8500001430511475) ? ( (Feature_3 <= 1.699999988079071) ? ( 4 ) : ( (Feature_0 <= 6.049999952316284) ? ( 6 ) : ( 7 ) ) ) : ( (Feature_3 <= 1.699999988079071) ? ( (Feature_2 <= 5.349999904632568) ? ( 10 ) : ( 11 ) ) : ( 12 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_11
#
#
# 	namespace RF_Tree_12 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 3 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.800000011920929) ? ( 1 ) : ( (Feature_2 <= 4.75) ? ( 3 ) : ( (Feature_2 <= 5.049999952316284) ? ( (Feature_0 <= 6.5) ? ( (Feature_2 <= 4.950000047683716) ? ( (Feature_1 <= 2.600000023841858) ? ( 8 ) : ( (Feature_1 <= 3.100000023841858) ? ( 10 ) : ( 11 ) ) ) : ( 12 ) ) : ( 13 ) ) : ( 14 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_12
#
#
# 	namespace RF_Tree_13 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 16 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 17 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 18 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.449999988079071) ? ( 1 ) : ( (Feature_2 <= 4.75) ? ( (Feature_3 <= 1.6500000357627869) ? ( 4 ) : ( 5 ) ) : ( (Feature_2 <= 5.049999952316284) ? ( (Feature_1 <= 2.899999976158142) ? ( (Feature_3 <= 1.649999976158142) ? ( (Feature_1 <= 2.350000023841858) ? ( 10 ) : ( 11 ) ) : ( 12 ) ) : ( 13 ) ) : ( (Feature_3 <= 1.699999988079071) ? ( (Feature_0 <= 6.049999952316284) ? ( 16 ) : ( 17 ) ) : ( 18 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_13
#
#
# 	namespace RF_Tree_14 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 9 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 16 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.449999988079071) ? ( 1 ) : ( (Feature_2 <= 4.8500001430511475) ? ( (Feature_3 <= 1.600000023841858) ? ( 4 ) : ( (Feature_0 <= 5.400000095367432) ? ( 6 ) : ( (Feature_0 <= 5.950000047683716) ? ( 8 ) : ( 9 ) ) ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_1 <= 2.549999952316284) ? ( 12 ) : ( (Feature_3 <= 1.550000011920929) ? ( 14 ) : ( 15 ) ) ) : ( 16 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_14
#
#
# 	namespace RF_Tree_15 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 10 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 14 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 15 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 16 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.599999964237213) ? ( 1 ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 4.950000047683716) ? ( (Feature_3 <= 1.6500000357627869) ? ( 5 ) : ( 6 ) ) : ( (Feature_3 <= 1.550000011920929) ? ( 8 ) : ( (Feature_2 <= 5.450000047683716) ? ( 10 ) : ( 11 ) ) ) ) : ( (Feature_0 <= 5.950000047683716) ? ( (Feature_2 <= 4.950000047683716) ? ( 14 ) : ( 15 ) ) : ( 16 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_15
#
#
# 	namespace RF_Tree_16 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 4 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 8 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 15 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 18 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 19 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 20 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.449999988079071) ? ( 1 ) : ( (Feature_3 <= 1.6500000357627869) ? ( (Feature_3 <= 1.449999988079071) ? ( 4 ) : ( (Feature_0 <= 6.400000095367432) ? ( (Feature_1 <= 2.899999976158142) ? ( (Feature_2 <= 4.75) ? ( 8 ) : ( (Feature_3 <= 1.550000011920929) ? ( 10 ) : ( 11 ) ) ) : ( 12 ) ) : ( 13 ) ) ) : ( (Feature_1 <= 3.149999976158142) ? ( 15 ) : ( (Feature_3 <= 2.0) ? ( (Feature_0 <= 6.549999952316284) ? ( 18 ) : ( 19 ) ) : ( 20 ) ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_16
#
#
# 	namespace RF_Tree_17 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 5 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 9 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 10 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 12 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 14 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_3 <= 0.75) ? ( 1 ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 5.349999904632568) ? ( (Feature_0 <= 4.950000047683716) ? ( 5 ) : ( (Feature_1 <= 2.25) ? ( (Feature_0 <= 6.099999904632568) ? ( (Feature_2 <= 4.5) ? ( 9 ) : ( 10 ) ) : ( 11 ) ) : ( 12 ) ) ) : ( 13 ) ) : ( 14 ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# 			int lNodeIndex = get_decision_tree_node_index(Feature_0, Feature_1, Feature_2, Feature_3);
#
# 			std::vector<double> lNodeValue = Decision_Tree_Node_data[ lNodeIndex ];
#
#
# 			tTable lTable;
#
# 			lTable["Score"] = {
# 				std::any(),
# 				std::any(),
# 				std::any()
# 			} ;
# 			lTable["Proba"] = {
# 				lNodeValue [ 0 ],
# 				lNodeValue [ 1 ],
# 				lNodeValue [ 2 ]
# 			} ;
# 			int lBestClass = get_arg_max( lTable["Proba"] );
# 			auto lDecision = lClasses[lBestClass];
# 			lTable["Decision"] = { lDecision } ;
# 			lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 			recompute_log_probas( lTable );
#
# 			return lTable;
# 		}
#
# 		tTable compute_model_outputs_from_table( tTable const & iTable) {
# 			tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 			return lTable;
# 		}
#
# 	} // eof namespace RF_Tree_17
#
#
# 	namespace RF_Tree_18 {
#
# 		typedef std::vector<double> tNodeData;
# 		std::map<int, tNodeData> Decision_Tree_Node_data = {
# 				{ 1 ,  {1.0, 0.0, 0.0 }} ,
# 				{ 6 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 7 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 8 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 11 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 13 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 15 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 16 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 19 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 20 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 21 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 24 ,  {0.0, 1.0, 0.0 }} ,
# 				{ 25 ,  {0.0, 0.0, 1.0 }} ,
# 				{ 26 ,  {0.0, 0.0, 1.0 }}
# 		};
#
#
# 		int get_decision_tree_node_index(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			int lNodeIndex = (Feature_2 <= 2.449999988079071) ? ( 1 ) : ( (Feature_0 <= 6.25) ? ( (Feature_0 <= 5.75) ? ( (Feature_0 <= 4.950000047683716) ? ( (Feature_3 <= 1.350000023841858) ? ( 6 ) : ( 7 ) ) : ( 8 ) ) : ( (Feature_1 <= 2.950000047683716) ? ( (Feature_2 <= 4.849999904632568) ? ( 11 ) : ( (Feature_0 <= 5.900000095367432) ? ( 13 ) : ( (Feature_1 <= 2.649999976158142) ? ( 15 ) : ( 16 ) ) ) ) : ( (Feature_1 <= 3.100000023841858) ? ( (Feature_3 <= 1.649999976158142) ? ( 19 ) : ( 20 ) ) : ( 21 ) ) ) ) : ( (Feature_3 <= 1.75) ? ( (Feature_2 <= 5.400000095367432) ? ( 24 ) : ( 25 ) ) : ( 26 ) ) );
#
# 			return lNodeIndex;
# 		}
#
#
# 		std::vector<std::string> get_input_names(){
# 			std::vector<std::string> lFeatures = { "Feature_0", "Feature_1", "Feature_2", "Feature_3" };
#
# 			return lFeatures;
# 		}
#
# 		std::vector<std::any> get_classes(){
# 			std::vector<std::any> lClasses = { 0, 1, 2 };
#
# 			return lClasses;
# 		}
#
# 		std::vector<std::string> get_output_names(){
# 			std::vector<std::string> lOutputs = {
# 				"Score_0", "Score_1", "Score_2",
# 				"Proba_0", "Proba_1", "Proba_2",
# 				"LogProba_0", "LogProba_1", "LogProba_2",
# 				"Decision", "DecisionProba" };
#
# 			return lOutputs;
# 		}
#
# 		tTable compute_classification_scores(std::any Feature_0, std::any Feature_1, std::any Feature_2, std::any Feature_3) {
# 			auto lClasses = get_classes();
#
# ...
# 			RF_Tree_344::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_345::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_346::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_347::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_348::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_349::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_350::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_351::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_352::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_353::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_354::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_355::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_356::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_357::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_358::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_359::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_360::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_361::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_362::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_363::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_364::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_365::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_366::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_367::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_368::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_369::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_370::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_371::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_372::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_373::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_374::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_375::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_376::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_377::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_378::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_379::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_380::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_381::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_382::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_383::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_384::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_385::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_386::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_387::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_388::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_389::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_390::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_391::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_392::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_393::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_394::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_395::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_396::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_397::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_398::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_399::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_400::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_401::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_402::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_403::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_404::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_405::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_406::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_407::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_408::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_409::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_410::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_411::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_412::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_413::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_414::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_415::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_416::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_417::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_418::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_419::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_420::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_421::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_422::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_423::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_424::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_425::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_426::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_427::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_428::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_429::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_430::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_431::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_432::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_433::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_434::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_435::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_436::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_437::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_438::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_439::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_440::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_441::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_442::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_443::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_444::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_445::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_446::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_447::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_448::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_449::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_450::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_451::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_452::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_453::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_454::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_455::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_456::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_457::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_458::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_459::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_460::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_461::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_462::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_463::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_464::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_465::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_466::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_467::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_468::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_469::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_470::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_471::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_472::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_473::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_474::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_475::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_476::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_477::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_478::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_479::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_480::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_481::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_482::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_483::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_484::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_485::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_486::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_487::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_488::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_489::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_490::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_491::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_492::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_493::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_494::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_495::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_496::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_497::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_498::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_499::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_500::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_501::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_502::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_503::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_504::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_505::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_506::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_507::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_508::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_509::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_510::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3),
# 			RF_Tree_511::compute_classification_scores(Feature_0, Feature_1, Feature_2, Feature_3)
# 		};
#
# 		tTable lAggregatedTable = aggregate_rf_scores(lTreeScores, {"Proba", "Score"});
#
#
# 		tTable lTable = lAggregatedTable;
#
# 		int lBestClass = get_arg_max( lTable["Proba"] );
# 		auto lDecision = lClasses[lBestClass];
# 		lTable["Decision"] = { lDecision } ;
# 		lTable["DecisionProba"] = { lTable["Proba"][lBestClass] };
#
# 		recompute_log_probas( lTable );
#
# 		return lTable;
# 	}
#
# 	tTable compute_model_outputs_from_table( tTable const & iTable) {
# 		tTable lTable = compute_classification_scores(iTable.at("Feature_0")[0], iTable.at("Feature_1")[0], iTable.at("Feature_2")[0], iTable.at("Feature_3")[0]);
#
# 		return lTable;
# 	}
#
# } // eof namespace

# %%
    def write_text_to_file(iCPPCode, oCPPFile):          
        with open(oCPPFile, "w") as text_file:
            text_file.write(iCPPCode)

    def add_cpp_main_function(iCPPCode, iCSVFile):
        lCPPCode = "#include \"Generic.i\"\n\n"
        lCPPCode = lCPPCode + iCPPCode
        lCPPCode = lCPPCode + "\tint main() {\n"
        lCPPCode = lCPPCode + "\t\tscore_csv_file(\"" + iCSVFile +"\");\n"
        lCPPCode = lCPPCode + "\treturn 0;\n}\n"
        return lCPPCode

    def compile_cpp_code_as_executable(iName):
        import subprocess
        lCommand = ["g++", "-Wall", "-Wno-unused-function", "-std=c++17" , "-g" ,  "-o", iName + ".exe",  iName + ".cpp"]
        print("EXECUTING" , "'" + " ".join(lCommand) + "'")
        result = subprocess.check_output(lCommand)
        # print(result)

    def execute_cpp_model(iName, iCSVFile):
        import subprocess
        result2 = subprocess.check_output([iName + ".exe",  iCSVFile])
        result2 = result2.decode()
        print(result2[:1000])
        print(result2[-1000:])
        return result2
        
    def execute_cpp_code(iCPPCode, iCSVFile):
        lName = "/tmp/sklearn2sql_cpp_" + str(id(clf));
        lCPPCode = add_cpp_main_function(iCPPCode, iCSVFile)
        write_text_to_file(lCPPCode, lName + ".cpp")
        compile_cpp_code_as_executable(lName)
        result = execute_cpp_model(lName, iCSVFile)
        write_text_to_file(str(result), lName + ".out")
        return lName + ".out"

# %%
populate_table("/tmp/iris2.csv" , ["Feature_0", "Feature_1", "Feature_2", "Feature_3"])
lCPPOutput = execute_cpp_code(lCPPCode , "/tmp/iris2.csv")
cpp_output = pd.read_csv(lCPPOutput)
# Out:
# EXECUTING 'g++ -Wall -Wno-unused-function -std=c++17 -g -o /tmp/sklearn2sql_cpp_140200213267696.exe /tmp/sklearn2sql_cpp_140200213267696.cpp'
# idx,Score_0,Score_1,Score_2,Proba_0,Proba_1,Proba_2,LogProba_0,LogProba_1,LogProba_2,Decision,DecisionProba
# 0,,,,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,-inf,-inf,0,1.00000000000000
# 1,,,,0.99804687500000,0.00195312500000,0.00000000000000,-0.00195503483580,-6.23832462503951,-inf,0,0.99804687500000
# 2,,,,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,-inf,-inf,0,1.00000000000000
# 3,,,,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,-inf,-inf,0,1.00000000000000
# 4,,,,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,-inf,-inf,0,1.00000000000000
# 5,,,,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,-inf,-inf,0,1.00000000000000
# 6,,,,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,-inf,-inf,0,1.00000000000000
# 7,,,,1.00000000000000,0.00000000000000,0.00000000000000,0.00000000000000,-inf,-inf,0,1.00000000000000
# 8,,,,1.00000000000000,0.00000000000000,0.00000000000000,0.0000
# 500000,0.99023437500000,-inf,-4.62888671260541,-0.00981362144832,2,0.99023437500000
# 142,,,,0.00000000000000,0.01562500000000,0.98437500000000,-inf,-4.15888308335967,-0.01574835696814,2,0.98437500000000
# 143,,,,0.00000000000000,0.00000000000000,1.00000000000000,-inf,-inf,0.00000000000000,2,1.00000000000000
# 144,,,,0.00000000000000,0.00195312500000,0.99804687500000,-inf,-6.23832462503951,-0.00195503483580,2,0.99804687500000
# 145,,,,0.00000000000000,0.00390625000000,0.99609375000000,-inf,-5.54517744447956,-0.00391389932114,2,0.99609375000000
# 146,,,,0.00000000000000,0.01953125000000,0.98046875000000,-inf,-3.93573953204546,-0.01972450534778,2,0.98046875000000
# 147,,,,0.00000000000000,0.00000000000000,1.00000000000000,-inf,-inf,0.00000000000000,2,1.00000000000000
# 148,,,,0.00000000000000,0.00976562500000,0.99023437500000,-inf,-4.62888671260541,-0.00981362144832,2,0.99023437500000
# 149,,,,0.00000000000000,0.03125000000000,0.96875000000000,-inf,-3.46573590279973,-0.03174869831458,2,0.96875000000000

# %%
cpp_output.sample(12, random_state=1960)
# Out:
#      idx  Score_0  Score_1  Score_2   Proba_0   Proba_1   Proba_2  LogProba_0  \
# 114  114      NaN      NaN      NaN  0.000000  0.000000  1.000000        -inf
# 74    74      NaN      NaN      NaN  0.000000  1.000000  0.000000        -inf
# 9      9      NaN      NaN      NaN  1.000000  0.000000  0.000000    0.000000
# 88    88      NaN      NaN      NaN  0.000000  1.000000  0.000000        -inf
# 25    25      NaN      NaN      NaN  0.996094  0.003906  0.000000   -0.003914
# 5      5      NaN      NaN      NaN  1.000000  0.000000  0.000000    0.000000
# 48    48      NaN      NaN      NaN  1.000000  0.000000  0.000000    0.000000
# 117  117      NaN      NaN      NaN  0.000000  0.000000  1.000000        -inf
# 83    83      NaN      NaN      NaN  0.000000  0.697266  0.302734        -inf
# 105  105      NaN      NaN      NaN  0.000000  0.000000  1.000000        -inf
# 27    27      NaN      NaN      NaN  1.000000  0.000000  0.000000    0.000000
# 64    64      NaN      NaN      NaN  0.000000  1.000000  0.000000        -inf
#
#      LogProba_1  LogProba_2  Decision  DecisionProba
# 114        -inf      0.0000         2       1.000000
# 74     0.000000        -inf         1       1.000000
# 9          -inf        -inf         0       1.000000
# 88     0.000000        -inf         1       1.000000
# 25    -5.545177        -inf         0       0.996094
# 5          -inf        -inf         0       1.000000
# 48         -inf        -inf         0       1.000000
# 117        -inf      0.0000         2       1.000000
# 83    -0.360589     -1.1949         1       0.697266
# 105        -inf      0.0000         2       1.000000
# 27         -inf        -inf         0       1.000000
# 64     0.000000        -inf         1       1.000000

# %%
skl_outputs = pd.DataFrame()
X = df[metadata['features']].values
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['idx']);

skl_output_score = pd.DataFrame(columns=['Score_0', 'Score_1', 'Score_2']);
skl_output_proba = pd.DataFrame(clf.predict_proba(X), columns=['Proba_0', 'Proba_1', 'Proba_2'])
skl_output_log_proba = pd.DataFrame(clf.predict_log_proba(X), columns=['LogProba_0', 'LogProba_1', 'LogProba_2'])
skl_output_decision = pd.DataFrame(clf.predict(X), columns=['Decision'])
skl_output = pd.concat([skl_output_key, skl_output_score, skl_output_proba, skl_output_log_proba, skl_output_decision] , axis=1)
skl_output.sample(12, random_state=1960)
# Out:
# /home/antoine/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:721: RuntimeWarning: divide by zero encountered in log
#   return np.log(proba)
#      idx Score_0 Score_1 Score_2   Proba_0   Proba_1   Proba_2  LogProba_0  \
# 114  114     NaN     NaN     NaN  0.000000  0.000000  1.000000        -inf
# 74    74     NaN     NaN     NaN  0.000000  1.000000  0.000000        -inf
# 9      9     NaN     NaN     NaN  1.000000  0.000000  0.000000    0.000000
# 88    88     NaN     NaN     NaN  0.000000  1.000000  0.000000        -inf
# 25    25     NaN     NaN     NaN  0.996094  0.003906  0.000000   -0.003914
# 5      5     NaN     NaN     NaN  1.000000  0.000000  0.000000    0.000000
# 48    48     NaN     NaN     NaN  1.000000  0.000000  0.000000    0.000000
# 117  117     NaN     NaN     NaN  0.000000  0.000000  1.000000        -inf
# 83    83     NaN     NaN     NaN  0.000000  0.699219  0.300781        -inf
# 105  105     NaN     NaN     NaN  0.000000  0.000000  1.000000        -inf
# 27    27     NaN     NaN     NaN  1.000000  0.000000  0.000000    0.000000
# 64    64     NaN     NaN     NaN  0.000000  1.000000  0.000000        -inf
#
#      LogProba_1  LogProba_2  Decision
# 114        -inf    0.000000         2
# 74     0.000000        -inf         1
# 9          -inf        -inf         0
# 88     0.000000        -inf         1
# 25    -5.545177        -inf         0
# 5          -inf        -inf         0
# 48         -inf        -inf         0
# 117        -inf    0.000000         2
# 83    -0.357792   -1.201372         1
# 105        -inf    0.000000         2
# 27         -inf        -inf         0
# 64     0.000000        -inf         1

# %%
cpp_skl_join = skl_output.join(cpp_output , how='left', on='idx', lsuffix='_skl', rsuffix='_cpp')

# %%
cpp_skl_join.sample(12, random_state=1960)
# Out:
#      idx_skl Score_0_skl Score_1_skl Score_2_skl  Proba_0_skl  Proba_1_skl  \
# 114      114         NaN         NaN         NaN     0.000000     0.000000
# 74        74         NaN         NaN         NaN     0.000000     1.000000
# 9          9         NaN         NaN         NaN     1.000000     0.000000
# 88        88         NaN         NaN         NaN     0.000000     1.000000
# 25        25         NaN         NaN         NaN     0.996094     0.003906
# 5          5         NaN         NaN         NaN     1.000000     0.000000
# 48        48         NaN         NaN         NaN     1.000000     0.000000
# 117      117         NaN         NaN         NaN     0.000000     0.000000
# 83        83         NaN         NaN         NaN     0.000000     0.699219
# 105      105         NaN         NaN         NaN     0.000000     0.000000
# 27        27         NaN         NaN         NaN     1.000000     0.000000
# 64        64         NaN         NaN         NaN     0.000000     1.000000
#
#      Proba_2_skl  LogProba_0_skl  LogProba_1_skl  LogProba_2_skl  ...  \
# 114     1.000000            -inf            -inf        0.000000  ...
# 74      0.000000            -inf        0.000000            -inf  ...
# 9       0.000000        0.000000            -inf            -inf  ...
# 88      0.000000            -inf        0.000000            -inf  ...
# 25      0.000000       -0.003914       -5.545177            -inf  ...
# 5       0.000000        0.000000            -inf            -inf  ...
# 48      0.000000        0.000000            -inf            -inf  ...
# 117     1.000000            -inf            -inf        0.000000  ...
# 83      0.300781            -inf       -0.357792       -1.201372  ...
# 105     1.000000            -inf            -inf        0.000000  ...
# 27      0.000000        0.000000            -inf            -inf  ...
# 64      0.000000            -inf        0.000000            -inf  ...
#
#      Score_1_cpp  Score_2_cpp  Proba_0_cpp  Proba_1_cpp  Proba_2_cpp  \
# 114          NaN          NaN     0.000000     0.000000     1.000000
# 74           NaN          NaN     0.000000     1.000000     0.000000
# 9            NaN          NaN     1.000000     0.000000     0.000000
# 88           NaN          NaN     0.000000     1.000000     0.000000
# 25           NaN          NaN     0.996094     0.003906     0.000000
# 5            NaN          NaN     1.000000     0.000000     0.000000
# 48           NaN          NaN     1.000000     0.000000     0.000000
# 117          NaN          NaN     0.000000     0.000000     1.000000
# 83           NaN          NaN     0.000000     0.697266     0.302734
# 105          NaN          NaN     0.000000     0.000000     1.000000
# 27           NaN          NaN     1.000000     0.000000     0.000000
# 64           NaN          NaN     0.000000     1.000000     0.000000
#
#      LogProba_0_cpp  LogProba_1_cpp  LogProba_2_cpp  Decision_cpp  \
# 114            -inf            -inf          0.0000             2
# 74             -inf        0.000000            -inf             1
# 9          0.000000            -inf            -inf             0
# 88             -inf        0.000000            -inf             1
# 25        -0.003914       -5.545177            -inf             0
# 5          0.000000            -inf            -inf             0
# 48         0.000000            -inf            -inf             0
# 117            -inf            -inf          0.0000             2
# 83             -inf       -0.360589         -1.1949             1
# 105            -inf            -inf          0.0000             2
# 27         0.000000            -inf            -inf             0
# 64             -inf        0.000000            -inf             1
#
#      DecisionProba
# 114       1.000000
# 74        1.000000
# 9         1.000000
# 88        1.000000
# 25        0.996094
# 5         1.000000
# 48        1.000000
# 117       1.000000
# 83        0.697266
# 105       1.000000
# 27        1.000000
# 64        1.000000
#
# [12 rows x 23 columns]

# %%
condition = (cpp_skl_join.Decision_cpp != cpp_skl_join.Decision_skl)
cpp_skl_join[condition]
# Out:
# Empty DataFrame
# Columns: [idx_skl, Score_0_skl, Score_1_skl, Score_2_skl, Proba_0_skl, Proba_1_skl, Proba_2_skl, LogProba_0_skl, LogProba_1_skl, LogProba_2_skl, Decision_skl, idx_cpp, Score_0_cpp, Score_1_cpp, Score_2_cpp, Proba_0_cpp, Proba_1_cpp, Proba_2_cpp, LogProba_0_cpp, LogProba_1_cpp, LogProba_2_cpp, Decision_cpp, DecisionProba]
# Index: []
#
# [0 rows x 23 columns]
